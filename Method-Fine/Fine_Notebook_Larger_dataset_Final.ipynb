# %%
import os
import json
import csv
import random
import pickle
import cv2
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms

from PIL import Image
from torch.utils.data import Dataset, DataLoader
from scipy.ndimage import label
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve
from skimage.morphology import rectangle, dilation, erosion

import matplotlib.pyplot as plt
import cv2

from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, array_to_img, img_to_array
from PIL import Image
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dataset

# %%
class GlaucomaDataset(Dataset):

    def __init__(self, root_dir, split='train', output_size=(256, 256)):
        self.output_size = output_size
        self.root_dir = root_dir
        self.split = split
        self.images = []
        self.segs = []
        self.boundaries = []
#         self.image_names = []
        self.structuring_element = rectangle(19, 19)  # Define a rectangular structuring element of size 19x19

        # Load data index
        dsi_path = "/kaggle/input/osi-larger-images/larger_train_dsi_images"
        for direct in self.root_dir:
            if direct == "../input/glaucoma-datasets/REFUGE/val":
                dsi_path = "/kaggle/input/osi-larger-images/larger_val_dsi_images"
            elif direct == "../input/glaucoma-datasets/ORIGA":
                dsi_path = "/kaggle/input/osi-larger-images/ORIGA_train_dsi_images"
            elif split == "val" and direct == "../input/glaucoma-datasets/REFUGE/test":
                dsi_path = "/kaggle/input/osi-larger-images/larger_test_dsi_images"
                
            self.image_filenames = []   
            for path in os.listdir(os.path.join(dsi_path)):
                if not path.startswith('.'):
                    self.image_filenames.append(path)

            for k in range(len(self.image_filenames)):
                print(f'Loading {split} image {k + 1}/{len(self.image_filenames)}...', end='\r')
                img_name = os.path.join(dsi_path, self.image_filenames[k])
                img = np.array(Image.open(img_name))
                img = transforms.functional.to_tensor(img)
                img = transforms.functional.resize(img, output_size, interpolation=transforms.InterpolationMode.BILINEAR)
#                 name = self.image_filenames[k]
                self.images.append(img)
#                 self.image_names.append(name)  #Name required to create DSI image data later

            if split != 'test':
                for k in range(len(self.image_filenames)):
                    print(f'Loading {split} segmentation {k + 1}/{len(self.image_filenames)}...', end='\r')
                    seg_name = os.path.join(direct, "Masks_Cropped", self.image_filenames[k][:-3] + "png")
                    mask = np.array(Image.open(seg_name, mode='r'))
                    # Compute OD and OC
                    od = (mask == 1.).astype(np.float32)
                    oc = (mask == 2.).astype(np.float32)
                    od = torch.from_numpy(od[None, :, :])
                    oc = torch.from_numpy(oc[None, :, :])
                    od = transforms.functional.resize(od, output_size, interpolation=transforms.InterpolationMode.NEAREST)
                    oc = transforms.functional.resize(oc, output_size, interpolation=transforms.InterpolationMode.NEAREST)
                    self.segs.append(torch.cat([od, oc], dim=0))

                    # Compute boundary for OD and OC
                    od_boundary = self.compute_boundary(od)
                    oc_boundary = self.compute_boundary(oc)
                    boundary = torch.cat([od_boundary, oc_boundary], dim=0)
                    self.boundaries.append(boundary)

            print(f'Successfully loaded {split} dataset.' + ' ' * 50)
            
    def compute_boundary(self, mask):
        dilated_mask = dilation(mask.squeeze().numpy(), self.structuring_element)
        eroded_mask = erosion(mask.squeeze().numpy(), self.structuring_element)
        boundary = dilated_mask - eroded_mask
        boundary = torch.from_numpy(boundary[None, :, :]).float()
        return boundary

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]
        if self.split == 'test':
            return img
        else:
            seg = self.segs[idx]
            boundary = self.boundaries[idx]
#             img_name = self.image_names[idx]
            return img, seg, boundary

# %% [markdown]
# # Metrics

# %%
EPS = 1e-7

def compute_dice_coef(input, target):
    '''
    Compute dice score metric.
    '''
    batch_size = input.shape[0]
    return sum([dice_coef_sample(input[k,:,:], target[k,:,:]) for k in range(batch_size)])/batch_size

def dice_coef_sample(input, target):
    iflat = input.contiguous().view(-1)
    tflat = target.contiguous().view(-1)
    intersection = (iflat * tflat).sum()
    return (2. * intersection) / (iflat.sum() + tflat.sum())


def vertical_diameter(binary_segmentation):
    '''
    Get the vertical diameter from a binary segmentation.
    The vertical diameter is defined as the "fattest" area of the binary_segmentation parameter.
    '''

    # get the sum of the pixels in the vertical axis
    vertical_axis_diameter = np.sum(binary_segmentation, axis=1)

    # pick the maximum value
    diameter = np.max(vertical_axis_diameter, axis=1)

    # return it
    return diameter



def vertical_cup_to_disc_ratio(od, oc):
    '''
    Compute the vertical cup-to-disc ratio from a given labelling map.
    '''
    # compute the cup diameter
    cup_diameter = vertical_diameter(oc)
    # compute the disc diameter
    disc_diameter = vertical_diameter(od)

    return cup_diameter / (disc_diameter + EPS)

def compute_vCDR_error(pred_od, pred_oc, gt_od, gt_oc):
    '''
    Compute vCDR prediction error, along with predicted vCDR and ground truth vCDR.
    '''
    pred_vCDR = vertical_cup_to_disc_ratio(pred_od, pred_oc)
    gt_vCDR = vertical_cup_to_disc_ratio(gt_od, gt_oc)
    vCDR_err = np.mean(np.abs(gt_vCDR - pred_vCDR))
    return vCDR_err, pred_vCDR, gt_vCDR


def classif_eval(classif_preds, classif_gts):
    '''
    Compute AUC classification score.
    '''
    auc = roc_auc_score(classif_gts, classif_preds)
    return auc

# %% [markdown]
# # Post Processing

# %%
def refine_seg(pred):
    '''
    Only retain the biggest connected component of a segmentation map.
    '''
    np_pred = pred.numpy()
        
    largest_ccs = []
    for i in range(np_pred.shape[0]):
        labeled, ncomponents = label(np_pred[i,:,:])
        bincounts = np.bincount(labeled.flat)[1:]
        if len(bincounts) == 0:
            largest_cc = labeled == 0
        else:
            largest_cc = labeled == np.argmax(bincounts)+1
        largest_cc = torch.tensor(largest_cc, dtype=torch.float32)
        largest_ccs.append(largest_cc)
    largest_ccs = torch.stack(largest_ccs)
    
    return largest_ccs

# %% [markdown]
# # Network

# %%
class UNet(nn.Module):
    def __init__(self, n_channels=1, n_classes=4): #Channel = 1 since OSI are greysacle
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.epoch = 0

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        self.down4 = Down(512, 1024)
        self.down5 = Down(1024, 2048)
        factor = 2 
        self.down6 = Down(2048, 4096 // factor)
        self.up1 = Up(4096, 2048 // factor)
        self.up2 = Up(2048, 1024 // factor)
        self.up3 = Up(1024, 512 // factor)
        self.up4 = Up(512, 256 // factor)
        self.up5 = Up(256, 128 // factor)
        self.up6 = Up(128, 64)
        self.output_layer = OutConv(64, n_classes)



    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x6 = self.down5(x5)
        x7 = self.down6(x6)
        out = self.up1(x7, x6)
        out = self.up2(out, x5)
        out = self.up3(out, x4)
        out = self.up4(out, x3)
        out = self.up5(out, x2)
        out = self.up6(out, x1)
        out = self.output_layer(out)
        out = torch.sigmoid(out)
        return out

    
class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
            
        )
        

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
            
        )
        

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()

        # Use the normal convolutions to reduce the number of channels
        self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        


    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)
        


class OutConv(nn.Module):
    '''
    Simple convolution.
    '''
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        

    def forward(self, x):
        return self.conv(x)

# %% [markdown]
# # Settings

# %%
#Data Directories
root_dirs = ["../input/glaucoma-datasets/REFUGE/train","../input/glaucoma-datasets/REFUGE/val", "../input/glaucoma-datasets/ORIGA"]
val_dir = ["../input/glaucoma-datasets/REFUGE/test"]

# %%
#Params
lr = 1e-4
batch_size = 8
num_workers = 4
total_epoch = 80

# %% [markdown]
# # Load Data

# %%
#DataLoaders
train_set = GlaucomaDataset(root_dirs, 
                          split='train')

val_set = GlaucomaDataset(val_dir, 
                        split='val')

train_loader = DataLoader(train_set, 
                          batch_size=batch_size, 
                          shuffle=True, 
                          num_workers=num_workers,
                          pin_memory=True,
                         )
val_loader = DataLoader(val_set, 
                        batch_size=batch_size, 
                        shuffle=False, 
                        num_workers=num_workers,
                        pin_memory=True,
                        )
# Out:
# Successfully loaded train dataset.
# Successfully loaded train dataset.
# Successfully loaded train dataset.
# Successfully loaded val dataset.

# %% [markdown]
# # Custom Loss Function

# %%
# Custom Dice Loss Function
class DiceLoss(nn.Module):
    def __init__(self, weight_obj=0.5, weight_bnd=0.5):
        super(DiceLoss, self).__init__()
        self.weight_obj = weight_obj
        self.weight_bnd = weight_bnd

    def dice_coef(self, pred, target):
        smooth = 1e-5
        intersection = (pred * target).sum()
        return (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)

    def forward(self, preds, targets):
        loss = 0.0

        for k in range(2):  # We have 2 objects (OD and OC)
            # Object region
            pred_obj = preds[:, k, :, :]
            target_obj = targets[:, k, :, :]
            dice_obj = self.dice_coef(pred_obj, target_obj)
            loss += self.weight_obj * (1 - dice_obj)

            # Boundary region
            pred_bnd = preds[:, k + 2, :, :]
            target_bnd = targets[:, k + 2, :, :]
            dice_bnd = self.dice_coef(pred_bnd, target_bnd)
            loss += self.weight_bnd * (1 - dice_bnd)

        return loss

# %% [markdown]
# # Init Model

# %%
# Device
device = torch.device("cuda:0")
model = UNet(n_channels=1, n_classes=4).to(device)
dice_loss_fn = DiceLoss(weight_obj=0.5, weight_bnd=0.5)
optimizer = optim.RMSprop(model.parameters(), lr=lr)

# %% [markdown]
# # Train

# %%
# Define parameters
nb_train_batches = len(train_loader)
nb_val_batches = len(val_loader)
nb_iter = 0
best_val_auc = 0.
iters = list(range(1, 10))
val_losses = []
train_losses = []
train_accuracy = []
val_accuracy = []


while model.epoch < total_epoch:
    # Accumulators
    train_vCDRs, val_vCDRs = [], []
    train_loss, val_loss = 0., 0.
    train_dsc_od, val_dsc_od = 0., 0.
    train_dsc_oc, val_dsc_oc = 0., 0.
    train_vCDR_error, val_vCDR_error = 0., 0.
    
    # TRAINING

    model.train()
    train_data = iter(train_loader)
    for k in range(nb_train_batches):
        # Load data
        imgs, seg_gts, boundaries = next(train_data)
        imgs, seg_gts, boundaries = imgs.to(device), seg_gts.to(device), boundaries.to(device)

        # Combine seg_gts and boundaries into a single tensor for targets
        targets = torch.cat((seg_gts, boundaries), dim=1)

        # Forward pass
        logits = model(imgs)
        loss = dice_loss_fn(logits, targets)
 
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item() / nb_train_batches
        
        train_losses.append(train_loss)
        
        with torch.no_grad():
            # Compute segmentation metric for OD and OC regions
            pred_od = refine_seg((logits[:,0,:,:]>=0.5).type(torch.int8).cpu()).to(device)
            pred_oc = refine_seg((logits[:,1,:,:]>=0.5).type(torch.int8).cpu()).to(device)
            gt_od = seg_gts[:,0,:,:].type(torch.int8)
            gt_oc = seg_gts[:,1,:,:].type(torch.int8)

            
            dsc_od = compute_dice_coef(pred_od, gt_od)
            dsc_oc = compute_dice_coef(pred_oc, gt_oc)
            train_dsc_od += dsc_od.item() / nb_train_batches
            train_dsc_oc += dsc_oc.item() / nb_train_batches
            
            # Compute and store vCDRs
            vCDR_error, pred_vCDR, gt_vCDR = compute_vCDR_error(pred_od.cpu().numpy(), pred_oc.cpu().numpy(), gt_od.cpu().numpy(), gt_oc.cpu().numpy())
            train_vCDRs += pred_vCDR.tolist()
            train_vCDR_error += vCDR_error  / nb_train_batches
            

            
        # Increase iterations
        nb_iter += 1
        
        
        print('Epoch {}, iter {}/{}, loss {:.6f}'.format(model.epoch+1, k+1, nb_train_batches, loss.item()) + ' '*20, 
              end='\r')
    

    # VALIDATION 

    model.eval()
    with torch.no_grad():
        val_data = iter(val_loader)
        for k in range(nb_val_batches):
            # Loads data
            imgs, seg_gts, boundaries = next(val_data)
            imgs, seg_gts, boundaries = imgs.to(device), seg_gts.to(device), boundaries.to(device)
            
            # Combine seg_gts and boundaries into a single tensor for targets
            targets = torch.cat((seg_gts, boundaries), dim=1)
            
            # Forward pass
            logits = model(imgs)
            val_loss += dice_loss_fn(logits, targets).item() / nb_val_batches
            
            val_losses.append(val_loss)

            # Std out
            print('Validation iter {}/{}'.format(k+1, nb_val_batches) + ' '*50, 
                  end='\r')
            
            # Compute segmentation metric for OD and OC regions
            pred_od = refine_seg((logits[:,0,:,:]>=0.5).type(torch.int8).cpu()).to(device)
            pred_oc = refine_seg((logits[:,1,:,:]>=0.5).type(torch.int8).cpu()).to(device)
            gt_od = seg_gts[:,0,:,:].type(torch.int8)
            gt_oc = seg_gts[:,1,:,:].type(torch.int8)

            
            dsc_od = compute_dice_coef(pred_od, gt_od)
            dsc_oc = compute_dice_coef(pred_oc, gt_oc)
            val_dsc_od += dsc_od.item() / nb_val_batches
            val_dsc_oc += dsc_oc.item() / nb_val_batches
            
            
            vCDR_error, pred_vCDR, gt_vCDR = compute_vCDR_error(pred_od.cpu().numpy(), pred_oc.cpu().numpy(), gt_od.cpu().numpy(), gt_oc.cpu().numpy())
            val_vCDRs += pred_vCDR.tolist()
            val_vCDR_error += vCDR_error / nb_val_batches

            
    print('VALIDATION epoch {}'.format(model.epoch+1)+' '*50)
    print('LOSSES: {:.4f} (train), {:.4f} (val)'.format(train_loss, val_loss))
    print('OD segmentation (Dice Score): {:.4f} (train), {:.4f} (val)'.format(train_dsc_od, val_dsc_od))
    print('OC segmentation (Dice Score): {:.4f} (train), {:.4f} (val)'.format(train_dsc_oc, val_dsc_oc))
    print('vCDR error: {:.4f} (train), {:.4f} (val)'.format(train_vCDR_error, val_vCDR_error))
    
#     Save model if best validation AUC is reached
    if dsc_od + dsc_oc > best_val_auc:
        torch.save(model.state_dict(), '/kaggle/working/OD_OC_Fine_Model_Larger_with_val.pth')
        best_val_auc = dsc_od + dsc_oc
        print('Best validation AUC reached. Saved model weights.')
    print('_'*50)
    
    
    # End of epoch
    model.epoch += 1
# Out:
# VALIDATION epoch 1
# LOSSES: 0.6591 (train), 0.7281 (val)
# OD segmentation (Dice Score): 0.9413 (train), 0.9074 (val)
# OC segmentation (Dice Score): 0.9095 (train), 0.8248 (val)
# vCDR error: 0.0444 (train), 0.0887 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 2
# LOSSES: 0.4947 (train), 0.6126 (val)
# OD segmentation (Dice Score): 0.9624 (train), 0.9256 (val)
# OC segmentation (Dice Score): 0.9503 (train), 0.8766 (val)
# vCDR error: 0.0277 (train), 0.0629 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 3
# LOSSES: 0.3824 (train), 0.6909 (val)
# OD segmentation (Dice Score): 0.9675 (train), 0.8841 (val)
# OC segmentation (Dice Score): 0.9603 (train), 0.6317 (val)
# vCDR error: 0.0237 (train), 0.1191 (val)
# __________________________________________________
# VALIDATION epoch 4
# LOSSES: 0.2986 (train), 0.4791 (val)
# OD segmentation (Dice Score): 0.9690 (train), 0.9234 (val)
# OC segmentation (Dice Score): 0.9607 (train), 0.8738 (val)
# vCDR error: 0.0244 (train), 0.0628 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 5
# LOSSES: 0.2388 (train), 0.4297 (val)
# OD segmentation (Dice Score): 0.9689 (train), 0.9242 (val)
# OC segmentation (Dice Score): 0.9607 (train), 0.8747 (val)
# vCDR error: 0.0238 (train), 0.0652 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 6
# LOSSES: 0.1947 (train), 0.3991 (val)
# OD segmentation (Dice Score): 0.9701 (train), 0.9236 (val)
# OC segmentation (Dice Score): 0.9629 (train), 0.8730 (val)
# vCDR error: 0.0232 (train), 0.0638 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 7
# LOSSES: 0.1669 (train), 0.3853 (val)
# OD segmentation (Dice Score): 0.9703 (train), 0.9247 (val)
# OC segmentation (Dice Score): 0.9629 (train), 0.8772 (val)
# vCDR error: 0.0236 (train), 0.0624 (val)
# __________________________________________________
# VALIDATION epoch 8
# LOSSES: 0.1464 (train), 0.3950 (val)
# OD segmentation (Dice Score): 0.9705 (train), 0.9229 (val)
# OC segmentation (Dice Score): 0.9635 (train), 0.8784 (val)
# vCDR error: 0.0230 (train), 0.0622 (val)
# __________________________________________________
# VALIDATION epoch 9
# LOSSES: 0.1329 (train), 0.7361 (val)
# OD segmentation (Dice Score): 0.9711 (train), 0.8024 (val)
# OC segmentation (Dice Score): 0.9637 (train), 0.6447 (val)
# vCDR error: 0.0233 (train), 0.1566 (val)
# __________________________________________________
# VALIDATION epoch 10
# LOSSES: 0.1244 (train), 0.3522 (val)
# OD segmentation (Dice Score): 0.9712 (train), 0.9244 (val)
# OC segmentation (Dice Score): 0.9630 (train), 0.8775 (val)
# vCDR error: 0.0233 (train), 0.0629 (val)
# __________________________________________________
# VALIDATION epoch 11
# LOSSES: 0.1179 (train), 0.3466 (val)
# OD segmentation (Dice Score): 0.9715 (train), 0.9251 (val)
# OC segmentation (Dice Score): 0.9643 (train), 0.8771 (val)
# vCDR error: 0.0229 (train), 0.0618 (val)
# __________________________________________________
# VALIDATION epoch 12
# LOSSES: 0.1137 (train), 0.3508 (val)
# OD segmentation (Dice Score): 0.9717 (train), 0.9242 (val)
# OC segmentation (Dice Score): 0.9647 (train), 0.8757 (val)
# vCDR error: 0.0228 (train), 0.0630 (val)
# __________________________________________________
# VALIDATION epoch 13
# LOSSES: 0.1113 (train), 0.3516 (val)
# OD segmentation (Dice Score): 0.9718 (train), 0.9231 (val)
# OC segmentation (Dice Score): 0.9647 (train), 0.8723 (val)
# vCDR error: 0.0225 (train), 0.0654 (val)
# __________________________________________________
# VALIDATION epoch 14
# LOSSES: 0.1095 (train), 0.3402 (val)
# OD segmentation (Dice Score): 0.9719 (train), 0.9263 (val)
# OC segmentation (Dice Score): 0.9648 (train), 0.8783 (val)
# vCDR error: 0.0229 (train), 0.0614 (val)
# __________________________________________________
# VALIDATION epoch 15
# LOSSES: 0.1103 (train), 0.3482 (val)
# OD segmentation (Dice Score): 0.9715 (train), 0.9232 (val)
# OC segmentation (Dice Score): 0.9644 (train), 0.8732 (val)
# vCDR error: 0.0233 (train), 0.0659 (val)
# __________________________________________________
# VALIDATION epoch 16
# LOSSES: 0.1064 (train), 0.3430 (val)
# OD segmentation (Dice Score): 0.9723 (train), 0.9248 (val)
# OC segmentation (Dice Score): 0.9656 (train), 0.8774 (val)
# vCDR error: 0.0226 (train), 0.0637 (val)
# __________________________________________________
# VALIDATION epoch 17
# LOSSES: 0.1067 (train), 0.3380 (val)
# OD segmentation (Dice Score): 0.9722 (train), 0.9265 (val)
# OC segmentation (Dice Score): 0.9653 (train), 0.8785 (val)
# vCDR error: 0.0223 (train), 0.0608 (val)
# __________________________________________________
# VALIDATION epoch 18
# LOSSES: 0.1070 (train), 0.3455 (val)
# OD segmentation (Dice Score): 0.9721 (train), 0.9239 (val)
# OC segmentation (Dice Score): 0.9653 (train), 0.8749 (val)
# vCDR error: 0.0223 (train), 0.0658 (val)
# __________________________________________________
# VALIDATION epoch 19
# LOSSES: 0.1046 (train), 0.3402 (val)
# OD segmentation (Dice Score): 0.9727 (train), 0.9253 (val)
# OC segmentation (Dice Score): 0.9660 (train), 0.8774 (val)
# vCDR error: 0.0224 (train), 0.0628 (val)
# __________________________________________________
# VALIDATION epoch 20
# LOSSES: 0.1046 (train), 0.3420 (val)
# OD segmentation (Dice Score): 0.9727 (train), 0.9249 (val)
# OC segmentation (Dice Score): 0.9658 (train), 0.8769 (val)
# vCDR error: 0.0219 (train), 0.0618 (val)
# __________________________________________________
# VALIDATION epoch 21
# LOSSES: 0.1048 (train), 0.3399 (val)
# OD segmentation (Dice Score): 0.9726 (train), 0.9256 (val)
# OC segmentation (Dice Score): 0.9658 (train), 0.8773 (val)
# vCDR error: 0.0222 (train), 0.0615 (val)
# __________________________________________________
# VALIDATION epoch 22
# LOSSES: 0.1038 (train), 0.3480 (val)
# OD segmentation (Dice Score): 0.9728 (train), 0.9229 (val)
# OC segmentation (Dice Score): 0.9661 (train), 0.8741 (val)
# vCDR error: 0.0221 (train), 0.0627 (val)
# __________________________________________________
# VALIDATION epoch 23
# LOSSES: 0.1035 (train), 0.3455 (val)
# OD segmentation (Dice Score): 0.9729 (train), 0.9237 (val)
# OC segmentation (Dice Score): 0.9662 (train), 0.8735 (val)
# vCDR error: 0.0221 (train), 0.0653 (val)
# __________________________________________________
# VALIDATION epoch 24
# LOSSES: 0.1026 (train), 0.3465 (val)
# OD segmentation (Dice Score): 0.9730 (train), 0.9242 (val)
# OC segmentation (Dice Score): 0.9665 (train), 0.8740 (val)
# vCDR error: 0.0218 (train), 0.0649 (val)
# __________________________________________________
# VALIDATION epoch 25
# LOSSES: 0.1019 (train), 0.3371 (val)
# OD segmentation (Dice Score): 0.9732 (train), 0.9266 (val)
# OC segmentation (Dice Score): 0.9671 (train), 0.8786 (val)
# vCDR error: 0.0214 (train), 0.0611 (val)
# __________________________________________________
# VALIDATION epoch 26
# LOSSES: 0.1015 (train), 0.3381 (val)
# OD segmentation (Dice Score): 0.9733 (train), 0.9262 (val)
# OC segmentation (Dice Score): 0.9670 (train), 0.8781 (val)
# vCDR error: 0.0219 (train), 0.0619 (val)
# __________________________________________________
# VALIDATION epoch 27
# LOSSES: 0.1006 (train), 0.3531 (val)
# OD segmentation (Dice Score): 0.9735 (train), 0.9227 (val)
# OC segmentation (Dice Score): 0.9675 (train), 0.8720 (val)
# vCDR error: 0.0215 (train), 0.0651 (val)
# __________________________________________________
# VALIDATION epoch 28
# LOSSES: 0.1004 (train), 0.3409 (val)
# OD segmentation (Dice Score): 0.9735 (train), 0.9242 (val)
# OC segmentation (Dice Score): 0.9675 (train), 0.8784 (val)
# vCDR error: 0.0217 (train), 0.0607 (val)
# __________________________________________________
# VALIDATION epoch 29
# LOSSES: 0.0992 (train), 0.3427 (val)
# OD segmentation (Dice Score): 0.9737 (train), 0.9257 (val)
# OC segmentation (Dice Score): 0.9680 (train), 0.8768 (val)
# vCDR error: 0.0214 (train), 0.0621 (val)
# __________________________________________________
# VALIDATION epoch 30
# LOSSES: 0.0975 (train), 0.3474 (val)
# OD segmentation (Dice Score): 0.9741 (train), 0.9241 (val)
# OC segmentation (Dice Score): 0.9685 (train), 0.8754 (val)
# vCDR error: 0.0211 (train), 0.0634 (val)
# __________________________________________________
# VALIDATION epoch 31
# LOSSES: 0.0971 (train), 0.3546 (val)
# OD segmentation (Dice Score): 0.9741 (train), 0.9215 (val)
# OC segmentation (Dice Score): 0.9689 (train), 0.8690 (val)
# vCDR error: 0.0210 (train), 0.0658 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 32
# LOSSES: 0.0957 (train), 0.3359 (val)
# OD segmentation (Dice Score): 0.9744 (train), 0.9266 (val)
# OC segmentation (Dice Score): 0.9694 (train), 0.8789 (val)
# vCDR error: 0.0206 (train), 0.0606 (val)
# __________________________________________________
# VALIDATION epoch 33
# LOSSES: 0.0949 (train), 0.3427 (val)
# OD segmentation (Dice Score): 0.9746 (train), 0.9255 (val)
# OC segmentation (Dice Score): 0.9697 (train), 0.8767 (val)
# vCDR error: 0.0202 (train), 0.0609 (val)
# __________________________________________________
# VALIDATION epoch 34
# LOSSES: 0.0934 (train), 0.3428 (val)
# OD segmentation (Dice Score): 0.9749 (train), 0.9244 (val)
# OC segmentation (Dice Score): 0.9702 (train), 0.8759 (val)
# vCDR error: 0.0204 (train), 0.0628 (val)
# __________________________________________________
# VALIDATION epoch 35
# LOSSES: 0.0917 (train), 0.3382 (val)
# OD segmentation (Dice Score): 0.9752 (train), 0.9266 (val)
# OC segmentation (Dice Score): 0.9709 (train), 0.8783 (val)
# vCDR error: 0.0196 (train), 0.0614 (val)
# __________________________________________________
# VALIDATION epoch 36
# LOSSES: 0.0905 (train), 0.3382 (val)
# OD segmentation (Dice Score): 0.9754 (train), 0.9263 (val)
# OC segmentation (Dice Score): 0.9715 (train), 0.8771 (val)
# vCDR error: 0.0191 (train), 0.0609 (val)
# __________________________________________________
# VALIDATION epoch 37
# LOSSES: 0.0889 (train), 0.3433 (val)
# OD segmentation (Dice Score): 0.9756 (train), 0.9242 (val)
# OC segmentation (Dice Score): 0.9722 (train), 0.8752 (val)
# vCDR error: 0.0191 (train), 0.0636 (val)
# __________________________________________________
# VALIDATION epoch 38
# LOSSES: 0.0877 (train), 0.3508 (val)
# OD segmentation (Dice Score): 0.9759 (train), 0.9238 (val)
# OC segmentation (Dice Score): 0.9726 (train), 0.8737 (val)
# vCDR error: 0.0185 (train), 0.0657 (val)
# __________________________________________________
# VALIDATION epoch 39
# LOSSES: 0.0861 (train), 0.3535 (val)
# OD segmentation (Dice Score): 0.9761 (train), 0.9237 (val)
# OC segmentation (Dice Score): 0.9731 (train), 0.8732 (val)
# vCDR error: 0.0178 (train), 0.0643 (val)
# __________________________________________________
# VALIDATION epoch 40
# LOSSES: 0.0846 (train), 0.3408 (val)
# OD segmentation (Dice Score): 0.9765 (train), 0.9262 (val)
# OC segmentation (Dice Score): 0.9738 (train), 0.8765 (val)
# vCDR error: 0.0177 (train), 0.0613 (val)
# __________________________________________________
# VALIDATION epoch 41
# LOSSES: 0.0835 (train), 0.3367 (val)
# OD segmentation (Dice Score): 0.9767 (train), 0.9262 (val)
# OC segmentation (Dice Score): 0.9740 (train), 0.8786 (val)
# vCDR error: 0.0174 (train), 0.0609 (val)
# __________________________________________________
# VALIDATION epoch 42
# LOSSES: 0.0816 (train), 0.3710 (val)
# OD segmentation (Dice Score): 0.9771 (train), 0.9185 (val)
# OC segmentation (Dice Score): 0.9748 (train), 0.8626 (val)
# vCDR error: 0.0171 (train), 0.0727 (val)
# __________________________________________________
# VALIDATION epoch 43
# LOSSES: 0.0807 (train), 0.3394 (val)
# OD segmentation (Dice Score): 0.9772 (train), 0.9260 (val)
# OC segmentation (Dice Score): 0.9751 (train), 0.8778 (val)
# vCDR error: 0.0172 (train), 0.0613 (val)
# __________________________________________________
# VALIDATION epoch 44
# LOSSES: 0.0796 (train), 0.3770 (val)
# OD segmentation (Dice Score): 0.9774 (train), 0.9180 (val)
# OC segmentation (Dice Score): 0.9755 (train), 0.8619 (val)
# vCDR error: 0.0167 (train), 0.0776 (val)
# __________________________________________________
# VALIDATION epoch 45
# LOSSES: 0.0789 (train), 0.3363 (val)
# OD segmentation (Dice Score): 0.9777 (train), 0.9272 (val)
# OC segmentation (Dice Score): 0.9759 (train), 0.8767 (val)
# vCDR error: 0.0158 (train), 0.0621 (val)
# __________________________________________________
# VALIDATION epoch 46
# LOSSES: 0.0775 (train), 0.3451 (val)
# OD segmentation (Dice Score): 0.9779 (train), 0.9260 (val)
# OC segmentation (Dice Score): 0.9762 (train), 0.8746 (val)
# vCDR error: 0.0166 (train), 0.0638 (val)
# __________________________________________________
# VALIDATION epoch 47
# LOSSES: 0.0764 (train), 0.3361 (val)
# OD segmentation (Dice Score): 0.9780 (train), 0.9266 (val)
# OC segmentation (Dice Score): 0.9766 (train), 0.8788 (val)
# vCDR error: 0.0159 (train), 0.0604 (val)
# __________________________________________________
# VALIDATION epoch 48
# LOSSES: 0.0747 (train), 0.3402 (val)
# OD segmentation (Dice Score): 0.9784 (train), 0.9267 (val)
# OC segmentation (Dice Score): 0.9772 (train), 0.8782 (val)
# vCDR error: 0.0156 (train), 0.0609 (val)
# __________________________________________________
# VALIDATION epoch 49
# LOSSES: 0.0734 (train), 0.3542 (val)
# OD segmentation (Dice Score): 0.9787 (train), 0.9240 (val)
# OC segmentation (Dice Score): 0.9776 (train), 0.8743 (val)
# vCDR error: 0.0156 (train), 0.0651 (val)
# __________________________________________________
# VALIDATION epoch 50
# LOSSES: 0.0727 (train), 0.3369 (val)
# OD segmentation (Dice Score): 0.9789 (train), 0.9260 (val)
# OC segmentation (Dice Score): 0.9780 (train), 0.8784 (val)
# vCDR error: 0.0153 (train), 0.0629 (val)
# __________________________________________________
# VALIDATION epoch 51
# LOSSES: 0.0718 (train), 0.3437 (val)
# OD segmentation (Dice Score): 0.9790 (train), 0.9245 (val)
# OC segmentation (Dice Score): 0.9783 (train), 0.8755 (val)
# vCDR error: 0.0152 (train), 0.0674 (val)
# __________________________________________________
# VALIDATION epoch 52
# LOSSES: 0.0714 (train), 0.3465 (val)
# OD segmentation (Dice Score): 0.9791 (train), 0.9243 (val)
# OC segmentation (Dice Score): 0.9787 (train), 0.8753 (val)
# vCDR error: 0.0151 (train), 0.0636 (val)
# __________________________________________________
# VALIDATION epoch 53
# LOSSES: 0.0691 (train), 0.3470 (val)
# OD segmentation (Dice Score): 0.9796 (train), 0.9245 (val)
# OC segmentation (Dice Score): 0.9793 (train), 0.8762 (val)
# vCDR error: 0.0147 (train), 0.0611 (val)
# __________________________________________________
# VALIDATION epoch 54
# LOSSES: 0.0692 (train), 0.3483 (val)
# OD segmentation (Dice Score): 0.9796 (train), 0.9237 (val)
# OC segmentation (Dice Score): 0.9793 (train), 0.8741 (val)
# vCDR error: 0.0146 (train), 0.0639 (val)
# __________________________________________________
# VALIDATION epoch 55
# LOSSES: 0.0677 (train), 0.3557 (val)
# OD segmentation (Dice Score): 0.9799 (train), 0.9218 (val)
# OC segmentation (Dice Score): 0.9797 (train), 0.8726 (val)
# vCDR error: 0.0145 (train), 0.0668 (val)
# __________________________________________________
# VALIDATION epoch 56
# LOSSES: 0.0666 (train), 0.3511 (val)
# OD segmentation (Dice Score): 0.9802 (train), 0.9229 (val)
# OC segmentation (Dice Score): 0.9802 (train), 0.8724 (val)
# vCDR error: 0.0145 (train), 0.0682 (val)
# __________________________________________________
# VALIDATION epoch 57
# LOSSES: 0.0655 (train), 0.3497 (val)
# OD segmentation (Dice Score): 0.9804 (train), 0.9236 (val)
# OC segmentation (Dice Score): 0.9803 (train), 0.8746 (val)
# vCDR error: 0.0143 (train), 0.0646 (val)
# __________________________________________________
# VALIDATION epoch 58
# LOSSES: 0.0655 (train), 0.3600 (val)
# OD segmentation (Dice Score): 0.9804 (train), 0.9215 (val)
# OC segmentation (Dice Score): 0.9805 (train), 0.8700 (val)
# vCDR error: 0.0142 (train), 0.0698 (val)
# __________________________________________________
# VALIDATION epoch 59
# LOSSES: 0.0647 (train), 0.3441 (val)
# OD segmentation (Dice Score): 0.9806 (train), 0.9256 (val)
# OC segmentation (Dice Score): 0.9807 (train), 0.8769 (val)
# vCDR error: 0.0139 (train), 0.0607 (val)
# __________________________________________________
# VALIDATION epoch 60
# LOSSES: 0.0647 (train), 0.3421 (val)
# OD segmentation (Dice Score): 0.9807 (train), 0.9262 (val)
# OC segmentation (Dice Score): 0.9809 (train), 0.8782 (val)
# vCDR error: 0.0141 (train), 0.0608 (val)
# __________________________________________________
# VALIDATION epoch 61
# LOSSES: 0.0637 (train), 0.3540 (val)
# OD segmentation (Dice Score): 0.9808 (train), 0.9222 (val)
# OC segmentation (Dice Score): 0.9811 (train), 0.8716 (val)
# vCDR error: 0.0137 (train), 0.0638 (val)
# __________________________________________________
# VALIDATION epoch 62
# LOSSES: 0.0626 (train), 0.3593 (val)
# OD segmentation (Dice Score): 0.9810 (train), 0.9214 (val)
# OC segmentation (Dice Score): 0.9815 (train), 0.8695 (val)
# vCDR error: 0.0132 (train), 0.0702 (val)
# __________________________________________________
# VALIDATION epoch 63
# LOSSES: 0.0624 (train), 0.3504 (val)
# OD segmentation (Dice Score): 0.9812 (train), 0.9228 (val)
# OC segmentation (Dice Score): 0.9816 (train), 0.8729 (val)
# vCDR error: 0.0138 (train), 0.0674 (val)
# __________________________________________________
# VALIDATION epoch 64
# LOSSES: 0.0610 (train), 0.3524 (val)
# OD segmentation (Dice Score): 0.9815 (train), 0.9231 (val)
# OC segmentation (Dice Score): 0.9820 (train), 0.8730 (val)
# vCDR error: 0.0134 (train), 0.0672 (val)
# __________________________________________________
# VALIDATION epoch 65
# LOSSES: 0.0610 (train), 0.3650 (val)
# OD segmentation (Dice Score): 0.9816 (train), 0.9212 (val)
# OC segmentation (Dice Score): 0.9819 (train), 0.8682 (val)
# vCDR error: 0.0132 (train), 0.0700 (val)
# __________________________________________________
# VALIDATION epoch 66
# LOSSES: 0.0596 (train), 0.3503 (val)
# OD segmentation (Dice Score): 0.9819 (train), 0.9229 (val)
# OC segmentation (Dice Score): 0.9825 (train), 0.8737 (val)
# vCDR error: 0.0127 (train), 0.0654 (val)
# __________________________________________________
# VALIDATION epoch 67
# LOSSES: 0.0586 (train), 0.3392 (val)
# OD segmentation (Dice Score): 0.9821 (train), 0.9261 (val)
# OC segmentation (Dice Score): 0.9828 (train), 0.8783 (val)
# vCDR error: 0.0120 (train), 0.0612 (val)
# __________________________________________________
# VALIDATION epoch 68
# LOSSES: 0.0578 (train), 0.3389 (val)
# OD segmentation (Dice Score): 0.9823 (train), 0.9267 (val)
# OC segmentation (Dice Score): 0.9830 (train), 0.8787 (val)
# vCDR error: 0.0129 (train), 0.0604 (val)
# __________________________________________________
# VALIDATION epoch 69
# LOSSES: 0.0576 (train), 0.3405 (val)
# OD segmentation (Dice Score): 0.9823 (train), 0.9256 (val)
# OC segmentation (Dice Score): 0.9831 (train), 0.8776 (val)
# vCDR error: 0.0125 (train), 0.0619 (val)
# __________________________________________________
# VALIDATION epoch 70
# LOSSES: 0.0575 (train), 0.3440 (val)
# OD segmentation (Dice Score): 0.9825 (train), 0.9245 (val)
# OC segmentation (Dice Score): 0.9831 (train), 0.8777 (val)
# vCDR error: 0.0127 (train), 0.0613 (val)
# __________________________________________________
# VALIDATION epoch 71
# LOSSES: 0.0571 (train), 0.3615 (val)
# OD segmentation (Dice Score): 0.9826 (train), 0.9205 (val)
# OC segmentation (Dice Score): 0.9832 (train), 0.8699 (val)
# vCDR error: 0.0127 (train), 0.0702 (val)
# __________________________________________________
# VALIDATION epoch 72
# LOSSES: 0.0561 (train), 0.3431 (val)
# OD segmentation (Dice Score): 0.9828 (train), 0.9243 (val)
# OC segmentation (Dice Score): 0.9837 (train), 0.8775 (val)
# vCDR error: 0.0124 (train), 0.0601 (val)
# __________________________________________________
# VALIDATION epoch 73
# LOSSES: 0.0553 (train), 0.3397 (val)
# OD segmentation (Dice Score): 0.9830 (train), 0.9250 (val)
# OC segmentation (Dice Score): 0.9837 (train), 0.8792 (val)
# vCDR error: 0.0120 (train), 0.0622 (val)
# __________________________________________________
# VALIDATION epoch 74
# LOSSES: 0.0545 (train), 0.3434 (val)
# OD segmentation (Dice Score): 0.9832 (train), 0.9255 (val)
# OC segmentation (Dice Score): 0.9841 (train), 0.8771 (val)
# vCDR error: 0.0122 (train), 0.0631 (val)
# __________________________________________________
# VALIDATION epoch 75
# LOSSES: 0.0543 (train), 0.3406 (val)
# OD segmentation (Dice Score): 0.9833 (train), 0.9265 (val)
# OC segmentation (Dice Score): 0.9841 (train), 0.8781 (val)
# vCDR error: 0.0120 (train), 0.0612 (val)
# __________________________________________________
# VALIDATION epoch 76
# LOSSES: 0.0540 (train), 0.3583 (val)
# OD segmentation (Dice Score): 0.9834 (train), 0.9211 (val)
# OC segmentation (Dice Score): 0.9842 (train), 0.8698 (val)
# vCDR error: 0.0124 (train), 0.0703 (val)
# __________________________________________________
# VALIDATION epoch 77
# LOSSES: 0.0531 (train), 0.3441 (val)
# OD segmentation (Dice Score): 0.9836 (train), 0.9261 (val)
# OC segmentation (Dice Score): 0.9846 (train), 0.8780 (val)
# vCDR error: 0.0121 (train), 0.0610 (val)
# __________________________________________________
# VALIDATION epoch 78
# LOSSES: 0.0530 (train), 0.3458 (val)
# OD segmentation (Dice Score): 0.9836 (train), 0.9245 (val)
# OC segmentation (Dice Score): 0.9846 (train), 0.8763 (val)
# vCDR error: 0.0121 (train), 0.0631 (val)
# __________________________________________________
# VALIDATION epoch 79
# LOSSES: 0.0531 (train), 0.3481 (val)
# OD segmentation (Dice Score): 0.9830 (train), 0.9237 (val)
# OC segmentation (Dice Score): 0.9840 (train), 0.8752 (val)
# vCDR error: 0.0120 (train), 0.0645 (val)
# __________________________________________________
# VALIDATION epoch 80
# LOSSES: 0.0517 (train), 0.3364 (val)
# OD segmentation (Dice Score): 0.9840 (train), 0.9262 (val)
# OC segmentation (Dice Score): 0.9851 (train), 0.8796 (val)
# vCDR error: 0.0115 (train), 0.0605 (val)
# __________________________________________________

# %%
torch.save(model.state_dict(), '/kaggle/working/OD_OC_Fine_Model_Final_Larger.pth')

# %% [markdown]
# # Vizualize results

# %%
loaded_model = UNet(n_channels=1, n_classes=4)
loaded_model.load_state_dict(torch.load('/kaggle/working/OD_OC_Fine_Model_Final_Larger.pth', map_location=device))
loaded_model.to(device)
loaded_model.eval()
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down5): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down6): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(4096, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up4): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up5): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up6): Up(
#     (up): Upsample(scale_factor=2.0, mode='bilinear')
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (output_layer): OutConv(
#     (conv): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
images_path = "../input/osi-images/test_dsi_images"
masks_path = "../input/glaucoma-datasets/REFUGE/test/Masks_Cropped"
image_filenames = []
for path in os.listdir(images_path):
    image_filenames.append(path)

# %%
output_size = (256, 256)
def compute_boundary(mask):
        dilated_mask = dilation(mask.squeeze().numpy(), rectangle(19, 19))
        eroded_mask = erosion(mask.squeeze().numpy(), rectangle(19, 19))
        boundary = dilated_mask - eroded_mask
        boundary = torch.from_numpy(boundary[None, :, :]).float()
        return boundary
    
def get_seg_img(filename):
    img = np.array(Image.open(os.path.join(images_path, filename)))
    #sample_img = img
    img = transforms.functional.to_tensor(img)
    img = transforms.functional.resize(img, output_size, interpolation=transforms.InterpolationMode.BILINEAR)
    filename_mask = filename[:-3] + "png"
    mask = np.array(Image.open(os.path.join(masks_path, filename_mask), mode='r'))
    od = (mask==1.).astype(np.float32)
    oc = (mask==2.).astype(np.float32)
    od = torch.from_numpy(od[None,:,:])
    oc = torch.from_numpy(oc[None,:,:])
    od = transforms.functional.resize(od, output_size, interpolation=transforms.InterpolationMode.NEAREST)
    oc = transforms.functional.resize(oc, output_size, interpolation=transforms.InterpolationMode.NEAREST)
    seg = torch.cat([od, oc], dim=0)
    od_boundary = compute_boundary(od)
    oc_boundary = compute_boundary(oc)
    boundary = torch.cat([od_boundary, oc_boundary], dim=0)

    
    return img, seg, boundary

# %%
def get_preds(num):
    filename = image_filenames[num]
    val_mask = resize(np.array(Image.open(os.path.join(masks_path, filename[:-3] + "png"), mode='r')), (256, 256))
    img, gt_seg, boundary = get_seg_img(filename)
    sample_img = img.numpy()
    sample_mask = gt_seg.numpy()
    sample_boundary = boundary.numpy()
    img = torch.unsqueeze(img, 0).to(device)
    gt_seg = torch.unsqueeze(gt_seg, 0).to(device)
    boundary = torch.unsqueeze(boundary, 0).to(device)
    
    logits = loaded_model(img)
    pred_od = refine_seg((logits[:,0,:,:]>=0.5).type(torch.int8).cpu())
    pred_oc = refine_seg((logits[:,1,:,:]>=0.5).type(torch.int8).cpu())
    pred_od_bd = refine_seg((logits[:,2,:,:]>=0.5).type(torch.int8).cpu())
    pred_oc_bd = refine_seg((logits[:,3,:,:]>=0.5).type(torch.int8).cpu())
    gt_od = gt_seg[:,0,:,:].type(torch.int8).cpu()
    gt_oc = gt_seg[:,1,:,:].type(torch.int8).cpu()
    bd_od = boundary[:,0,:,:].type(torch.int8).cpu()
    bd_oc = boundary[:,1,:,:].type(torch.int8).cpu()
    
    return sample_img, sample_mask,sample_boundary, pred_od, pred_oc, pred_od_bd, pred_oc_bd, gt_od, gt_oc,bd_od,bd_oc, val_mask

# %%
from skimage.transform import resize

# Initialize lists to store dice scores
od_dice_scores = []
oc_dice_scores = []

# Loop through all images to calculate dice scores
for idx in range(len(image_filenames)):
    sample_img, sample_mask, sample_boundary, pred_od, pred_oc, pred_od_bd, pred_oc_bd, gt_od, gt_oc, bd_od, bd_oc, val_mask = get_preds(idx)
    od_dice_scores.append(compute_dice_coef(pred_od, gt_od))
    oc_dice_scores.append(compute_dice_coef(pred_oc, gt_oc))
    
plt.figure(figsize=(14, 6))

# Plot for the first array
plt.subplot(1, 2, 1)
plt.hist(od_dice_scores, bins=30, edgecolor='k', alpha=0.7)
plt.title('Distribution of OD_DS')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Plot for the second array
plt.subplot(1, 2, 2)
plt.hist(oc_dice_scores, bins=30, edgecolor='k', alpha=0.7)
plt.title('Distribution of OC_DS')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()


# Calculate mean dice scores
mean_od_dice = np.mean(od_dice_scores)
mean_oc_dice = np.mean(oc_dice_scores)
std_od_dice = np.std(od_dice_scores)
std_oc_dice = np.std(oc_dice_scores)
print(f"OD Seg Dice Score:  {mean_od_dice} ± {std_od_dice}")
print(f"OC Seg Dice Score:  {mean_oc_dice} ± {std_oc_dice}")

# Randomly select 5 images for visualization
random_indices = random.sample(range(len(image_filenames)), 5)
print("Here are 5 random sample visualisations: ")
print('_'*50)
# Visualization
for idx in random_indices:
    sample_img, sample_mask, sample_boundary, pred_od, pred_oc, pred_od_bd, pred_oc_bd, gt_od, gt_oc, bd_od, bd_oc, val_mask = get_preds(idx)
    
    f, axarr = plt.subplots(2, 3, squeeze=False)
    print(f"OD Seg Dice Score:  {compute_dice_coef(pred_od, gt_od)}")
    print(f"OC Seg Dice Score:  {compute_dice_coef(pred_oc, gt_oc)}")

    input_img = np.swapaxes(np.swapaxes(sample_img, 0, 2), 0, 1)
    gt_mask = np.swapaxes(np.swapaxes(sample_mask, 0, 2), 0, 1)
    gt_mask[:, :, 0][gt_mask[:, :, 0] > 0] = 2
    output_mask = gt_mask[:, :, 0] + gt_mask[:, :, 1]
    print(gt_mask.shape, output_mask.shape)
    print(np.max(output_mask))
    pred_od_mask = pred_od.numpy().reshape(256, 256) + (2 * pred_oc.numpy().reshape(256, 256))
    bd_mask = bd_od.numpy().reshape(256, 256) + (2 * bd_oc.numpy().reshape(256, 256))
    pred_od_bd_mask = pred_od_bd.numpy().reshape(256, 256) + (2 * pred_oc_bd.numpy().reshape(256, 256))

    axarr[0][0].imshow(input_img)
    axarr[0][1].imshow(val_mask)
    axarr[0][2].imshow(pred_od_mask)
    axarr[1][1].imshow(bd_mask)
    axarr[1][2].imshow(pred_od_bd_mask)
    plt.show()
# Out:
# OD Seg Dice Score:  0.9200010895729065 ± 0.045033715665340424
# OC Seg Dice Score:  0.8780831694602966 ± 0.06051862612366676
# Here are 5 random sample visualisations:
# __________________________________________________
# OD Seg Dice Score:  0.9225473403930664
# OC Seg Dice Score:  0.9076722264289856
# (256, 256, 2) (256, 256)
# 2.0
# OD Seg Dice Score:  0.9286633729934692
# OC Seg Dice Score:  0.8333678841590881
# (256, 256, 2) (256, 256)
# 2.0
# OD Seg Dice Score:  0.7173601984977722
# OC Seg Dice Score:  0.9059339165687561
# (256, 256, 2) (256, 256)
# 2.0
