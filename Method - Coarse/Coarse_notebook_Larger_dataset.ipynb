# %%
import os
import json
import csv
import random
import pickle
import cv2
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms

from PIL import Image
from torch.utils.data import Dataset, DataLoader
from scipy.ndimage.measurements import label
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve
from skimage.morphology import rectangle, dilation, erosion

import matplotlib.pyplot as plt
import cv2

from keras.preprocessing.image import ImageDataGenerator, load_img, array_to_img, img_to_array
from PIL import Image
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dataset

# %%
class GlaucomaDataset(Dataset):

    def __init__(self, root_dir, split='train', output_size=(256, 256)):
        self.output_size = output_size
        self.root_dir = root_dir
        self.split = split
        self.images = []
        self.segs = []
        self.boundaries = []
        self.image_names = []
        self.structuring_element = rectangle(19, 19)  # Define a rectangular structuring element of size 19x19

        # Load data index
        for direct in self.root_dir:
            if direct == "../input/glaucoma-datasets/G1020":
                self.image_filenames = []
                for path in os.listdir(os.path.join(direct, "Images_Cropped", "img")):
                    if not path.startswith('.'):
                        self.image_filenames.append(path)

                for k in range(len(self.image_filenames)):
                    print(f'Loading {split} image {k + 1}/{len(self.image_filenames)}...', end='\r')
                    img_name = os.path.join(direct, "Images_Cropped", "img", self.image_filenames[k])
                    img = np.array(Image.open(img_name).convert('RGB'))
                    img = transforms.functional.to_tensor(img)
                    img = transforms.functional.resize(img, output_size, interpolation=transforms.InterpolationMode.BILINEAR)
                    name = self.image_filenames[k]
                    self.images.append(img)
                    self.image_names.append(name)  #Name required to create DSI image data later

                if split != 'test':
                    for k in range(len(self.image_filenames)):
                        print(f'Loading {split} segmentation {k + 1}/{len(self.image_filenames)}...', end='\r')
                        seg_name = os.path.join(direct, "Masks_Cropped","img", self.image_filenames[k][:-3] + "png")
                        mask = np.array(Image.open(seg_name, mode='r'))
                        od = (mask == 1.).astype(np.float32)
                        oc = (mask == 2.).astype(np.float32)
                        od = torch.from_numpy(od[None, :, :])
                        oc = torch.from_numpy(oc[None, :, :])
                        od = transforms.functional.resize(od, output_size, interpolation=transforms.InterpolationMode.NEAREST)
                        oc = transforms.functional.resize(oc, output_size, interpolation=transforms.InterpolationMode.NEAREST)
                        self.segs.append(torch.cat([od, oc], dim=0))

                        # Compute boundary for OD and OC
                        od_boundary = self.compute_boundary(od)
                        oc_boundary = self.compute_boundary(oc)
                        boundary = torch.cat([od_boundary, oc_boundary], dim=0)
                        self.boundaries.append(boundary)

                print(f'Successfully loaded {split} dataset.' + ' ' * 50)
            else:
                self.image_filenames = []
                for path in os.listdir(os.path.join(direct, "Images_Cropped")):
                    if not path.startswith('.'):
                        self.image_filenames.append(path)

                for k in range(len(self.image_filenames)):
                    print(f'Loading {split} image {k + 1}/{len(self.image_filenames)}...', end='\r')
                    img_name = os.path.join(direct, "Images_Cropped", self.image_filenames[k])
                    img = np.array(Image.open(img_name).convert('RGB'))
                    img = transforms.functional.to_tensor(img)
                    img = transforms.functional.resize(img, output_size, interpolation=transforms.InterpolationMode.BILINEAR)
                    name = self.image_filenames[k]
                    self.images.append(img)
                    self.image_names.append(name)

                if split != 'test':
                    for k in range(len(self.image_filenames)):
                        print(f'Loading {split} segmentation {k + 1}/{len(self.image_filenames)}...', end='\r')
                        seg_name = os.path.join(direct, "Masks_Cropped", self.image_filenames[k][:-3] + "png")
                        mask = np.array(Image.open(seg_name, mode='r'))
                        od = (mask == 1.).astype(np.float32)
                        oc = (mask == 2.).astype(np.float32)
                        od = torch.from_numpy(od[None, :, :])
                        oc = torch.from_numpy(oc[None, :, :])
                        od = transforms.functional.resize(od, output_size, interpolation=transforms.InterpolationMode.NEAREST)
                        oc = transforms.functional.resize(oc, output_size, interpolation=transforms.InterpolationMode.NEAREST)
                        self.segs.append(torch.cat([od, oc], dim=0))

                        # Compute boundary for OD and OC
                        od_boundary = self.compute_boundary(od)
                        oc_boundary = self.compute_boundary(oc)
                        boundary = torch.cat([od_boundary, oc_boundary], dim=0)
                        self.boundaries.append(boundary)

                print(f'Successfully loaded {split} dataset.' + ' ' * 50)
    def compute_boundary(self, mask):
        dilated_mask = dilation(mask.squeeze().numpy(), self.structuring_element)
        eroded_mask = erosion(mask.squeeze().numpy(), self.structuring_element)
        boundary = dilated_mask - eroded_mask
        boundary = torch.from_numpy(boundary[None, :, :]).float()
        return boundary

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]
        if self.split == 'test':
            return img
        else:
            seg = self.segs[idx]
            boundary = self.boundaries[idx]
            img_name = self.image_names[idx]
            return img, seg, boundary, img_name

# %% [markdown]
# # Metrics

# %%
EPS = 1e-7

def compute_dice_coef(input, target):
    '''
    Compute dice score metric.
    '''
    batch_size = input.shape[0]
    return sum([dice_coef_sample(input[k,:,:], target[k,:,:]) for k in range(batch_size)])/batch_size

def dice_coef_sample(input, target):
    iflat = input.contiguous().view(-1)
    tflat = target.contiguous().view(-1)
    intersection = (iflat * tflat).sum()
    return (2. * intersection) / (iflat.sum() + tflat.sum())


def vertical_diameter(binary_segmentation):
    '''
    Get the vertical diameter from a binary segmentation.
    The vertical diameter is defined as the "fattest" area of the binary_segmentation parameter.
    '''

    # get the sum of the pixels in the vertical axis
    vertical_axis_diameter = np.sum(binary_segmentation, axis=1)

    # pick the maximum value
    diameter = np.max(vertical_axis_diameter, axis=1)

    # return it
    return diameter



def vertical_cup_to_disc_ratio(od, oc):
    '''
    Compute the vertical cup-to-disc ratio from a given labelling map.
    '''
    # compute the cup diameter
    cup_diameter = vertical_diameter(oc)
    # compute the disc diameter
    disc_diameter = vertical_diameter(od)

    return cup_diameter / (disc_diameter + EPS)

def compute_vCDR_error(pred_od, pred_oc, gt_od, gt_oc):
    '''
    Compute vCDR prediction error, along with predicted vCDR and ground truth vCDR.
    '''
    pred_vCDR = vertical_cup_to_disc_ratio(pred_od, pred_oc)
    gt_vCDR = vertical_cup_to_disc_ratio(gt_od, gt_oc)
    vCDR_err = np.mean(np.abs(gt_vCDR - pred_vCDR))
    return vCDR_err, pred_vCDR, gt_vCDR


def classif_eval(classif_preds, classif_gts):
    '''
    Compute AUC classification score.
    '''
    auc = roc_auc_score(classif_gts, classif_preds)
    return auc

# %% [markdown]
# # Post Processing

# %%
def refine_seg(pred):
    '''
    Only retain the biggest connected component of a segmentation map.
    '''
    np_pred = pred.numpy()
        
    largest_ccs = []
    for i in range(np_pred.shape[0]):
        labeled, ncomponents = label(np_pred[i,:,:])
        bincounts = np.bincount(labeled.flat)[1:]
        if len(bincounts) == 0:
            largest_cc = labeled == 0
        else:
            largest_cc = labeled == np.argmax(bincounts)+1
        largest_cc = torch.tensor(largest_cc, dtype=torch.float32)
        largest_ccs.append(largest_cc)
    largest_ccs = torch.stack(largest_ccs)
    
    return largest_ccs

# %% [markdown]
# # Network

# %%
class UNet(nn.Module):
    def __init__(self, n_channels=3, n_classes=4):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.epoch = 0

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        self.down4 = Down(512, 1024)
        self.down5 = Down(1024, 2048)
        factor = 2 
        self.down6 = Down(2048, 4096 // factor)
        self.up1 = Up(4096, 2048 // factor)
        self.up2 = Up(2048, 1024 // factor)
        self.up3 = Up(1024, 512 // factor)
        self.up4 = Up(512, 256 // factor)
        self.up5 = Up(256, 128 // factor)
        self.up6 = Up(128, 64)
        self.output_layer = OutConv(64, n_classes)



    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x6 = self.down5(x5)
        x7 = self.down6(x6)
        out = self.up1(x7, x6)
        out = self.up2(out, x5)
        out = self.up3(out, x4)
        out = self.up4(out, x3)
        out = self.up5(out, x2)
        out = self.up6(out, x1)
        out = self.output_layer(out)
        out = torch.sigmoid(out)
        return out

    
class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
            
        )
        

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
            
        )
        

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()

        # Use the normal convolutions to reduce the number of channels
        self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        


    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)
        


class OutConv(nn.Module):
    '''
    Simple convolution.
    '''
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        

    def forward(self, x):
        return self.conv(x)

# %% [markdown]
# # Settings

# %%
#Data Directories
root_dirs = ["../input/glaucoma-datasets/REFUGE/train", "../input/glaucoma-datasets/REFUGE/val", "../input/glaucoma-datasets/ORIGA"]
val_dir = ["../input/glaucoma-datasets/REFUGE/test"]

# %%
#Params
lr = 1e-4
batch_size = 8
num_workers = 4
total_epoch = 80

# %% [markdown]
# # Load Data

# %%
#DataLoaders
train_set = GlaucomaDataset(root_dirs, 
                          split='train')

val_set = GlaucomaDataset(val_dir, 
                        split='val')

train_loader = DataLoader(train_set, 
                          batch_size=batch_size, 
                          shuffle=True, 
                          num_workers=num_workers,
                          pin_memory=True,
                         )
val_loader = DataLoader(val_set, 
                        batch_size=batch_size, 
                        shuffle=False, 
                        num_workers=num_workers,
                        pin_memory=True,
                        )
# Out:
# Successfully loaded train dataset.
# Successfully loaded train dataset.
# Successfully loaded train dataset.
# Successfully loaded val dataset.

# %% [markdown]
# # Custom Loss Function

# %%
# Custom Dice Loss Function
class DiceLoss(nn.Module):
    def __init__(self, weight_obj=0.5, weight_bnd=0.5):
        super(DiceLoss, self).__init__()
        self.weight_obj = weight_obj
        self.weight_bnd = weight_bnd

    def dice_coef(self, pred, target):
        smooth = 1e-5
        intersection = (pred * target).sum()
        return (2. * intersection + smooth) / (pred.sum() + target.sum() + smooth)

    def forward(self, preds, targets):
        loss = 0.0

        for k in range(2):  # We have 2 objects (OD and OC)
            # Object region
            pred_obj = preds[:, k, :, :]
            target_obj = targets[:, k, :, :]
            dice_obj = self.dice_coef(pred_obj, target_obj)
            loss += self.weight_obj * (1 - dice_obj)

            # Boundary region
            pred_bnd = preds[:, k + 2, :, :]
            target_bnd = targets[:, k + 2, :, :]
            dice_bnd = self.dice_coef(pred_bnd, target_bnd)
            loss += self.weight_bnd * (1 - dice_bnd)

        return loss

# %% [markdown]
# # Init Model

# %%
# Device
device = torch.device("cuda:0")
model = UNet(n_channels=3, n_classes=4).to(device)
dice_loss_fn = DiceLoss(weight_obj=0.5, weight_bnd=0.5)
optimizer = optim.RMSprop(model.parameters(), lr=lr)

# %% [markdown]
# # Train

# %%
# Define parameters
nb_train_batches = len(train_loader)
nb_val_batches = len(val_loader)
nb_iter = 0
best_val_auc = 0.
iters = list(range(1, 10))
val_losses = []
train_losses = []
train_accuracy = []
val_accuracy = []


while model.epoch < total_epoch:
    # Accumulators
    train_vCDRs, val_vCDRs = [], []
    train_loss, val_loss = 0., 0.
    train_dsc_od, val_dsc_od = 0., 0.
    train_dsc_oc, val_dsc_oc = 0., 0.
    train_vCDR_error, val_vCDR_error = 0., 0.
    
    # TRAINING

    model.train()
    train_data = iter(train_loader)
    for k in range(nb_train_batches):
        # Load data
        imgs, seg_gts, boundaries, img_names = train_data.next()
        imgs, seg_gts, boundaries = imgs.to(device), seg_gts.to(device), boundaries.to(device)

        # Combine seg_gts and boundaries into a single tensor for targets
        targets = torch.cat((seg_gts, boundaries), dim=1)

        # Forward pass
        logits = model(imgs)
        loss = dice_loss_fn(logits, targets)
 
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss += loss.item() / nb_train_batches
        
        train_losses.append(train_loss)
        
        with torch.no_grad():
            # Compute segmentation metric for OD and OC regions
            pred_od = refine_seg((logits[:,0,:,:]>=0.5).type(torch.int8).cpu()).to(device)
            pred_oc = refine_seg((logits[:,1,:,:]>=0.5).type(torch.int8).cpu()).to(device)
            gt_od = seg_gts[:,0,:,:].type(torch.int8)
            gt_oc = seg_gts[:,1,:,:].type(torch.int8)

            
            dsc_od = compute_dice_coef(pred_od, gt_od)
            dsc_oc = compute_dice_coef(pred_oc, gt_oc)
            train_dsc_od += dsc_od.item() / nb_train_batches
            train_dsc_oc += dsc_oc.item() / nb_train_batches
            
            # Compute and store vCDRs
            vCDR_error, pred_vCDR, gt_vCDR = compute_vCDR_error(pred_od.cpu().numpy(), pred_oc.cpu().numpy(), gt_od.cpu().numpy(), gt_oc.cpu().numpy())
            train_vCDRs += pred_vCDR.tolist()
            train_vCDR_error += vCDR_error  / nb_train_batches
            

            
        # Increase iterations
        nb_iter += 1
        
        
        print('Epoch {}, iter {}/{}, loss {:.6f}'.format(model.epoch+1, k+1, nb_train_batches, loss.item()) + ' '*20, 
              end='\r')
    

    # VALIDATION 

    model.eval()
    with torch.no_grad():
        val_data = iter(val_loader)
        for k in range(nb_val_batches):
            # Loads data
            imgs, seg_gts, boundaries, img_names = val_data.next()
            imgs, seg_gts, boundaries = imgs.to(device), seg_gts.to(device), boundaries.to(device)
            
            # Combine seg_gts and boundaries into a single tensor for targets
            targets = torch.cat((seg_gts, boundaries), dim=1)
            
            # Forward pass
            logits = model(imgs)
            val_loss += dice_loss_fn(logits, targets).item() / nb_val_batches
            
            val_losses.append(val_loss)

            # Std out
            print('Validation iter {}/{}'.format(k+1, nb_val_batches) + ' '*50, 
                  end='\r')
            
            # Compute segmentation metric for OD and OC regions
            pred_od = refine_seg((logits[:,0,:,:]>=0.5).type(torch.int8).cpu()).to(device)
            pred_oc = refine_seg((logits[:,1,:,:]>=0.5).type(torch.int8).cpu()).to(device)
            gt_od = seg_gts[:,0,:,:].type(torch.int8)
            gt_oc = seg_gts[:,1,:,:].type(torch.int8)

            
            dsc_od = compute_dice_coef(pred_od, gt_od)
            dsc_oc = compute_dice_coef(pred_oc, gt_oc)
            val_dsc_od += dsc_od.item() / nb_val_batches
            val_dsc_oc += dsc_oc.item() / nb_val_batches
            
            
            vCDR_error, pred_vCDR, gt_vCDR = compute_vCDR_error(pred_od.cpu().numpy(), pred_oc.cpu().numpy(), gt_od.cpu().numpy(), gt_oc.cpu().numpy())
            val_vCDRs += pred_vCDR.tolist()
            val_vCDR_error += vCDR_error / nb_val_batches

            
    print('VALIDATION epoch {}'.format(model.epoch+1)+' '*50)
    print('LOSSES: {:.4f} (train), {:.4f} (val)'.format(train_loss, val_loss))
    print('OD segmentation (Dice Score): {:.4f} (train), {:.4f} (val)'.format(train_dsc_od, val_dsc_od))
    print('OC segmentation (Dice Score): {:.4f} (train), {:.4f} (val)'.format(train_dsc_oc, val_dsc_oc))
    print('vCDR error: {:.4f} (train), {:.4f} (val)'.format(train_vCDR_error, val_vCDR_error))
    
#     Save model if best validation AUC is reached
    if dsc_od + dsc_oc > best_val_auc:
        torch.save(model.state_dict(), '/kaggle/working/OD_OC_Coarse_Model.pth')
        best_val_auc = dsc_od + dsc_oc
        print('Best validation AUC reached. Saved model weights.')
    print('_'*50)
    
    
    # End of epoch
    model.epoch += 1
# Out:
# VALIDATION epoch 1
# LOSSES: 0.8559 (train), 0.8199 (val)
# OD segmentation (Dice Score): 0.8344 (train), 0.8695 (val)
# OC segmentation (Dice Score): 0.7322 (train), 0.7211 (val)
# vCDR error: 0.1942 (train), 0.1350 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 2
# LOSSES: 0.7032 (train), 0.6765 (val)
# OD segmentation (Dice Score): 0.8798 (train), 0.8845 (val)
# OC segmentation (Dice Score): 0.8073 (train), 0.8226 (val)
# vCDR error: 0.1393 (train), 0.0940 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 3
# LOSSES: 0.6177 (train), 0.5993 (val)
# OD segmentation (Dice Score): 0.8888 (train), 0.8974 (val)
# OC segmentation (Dice Score): 0.8328 (train), 0.8422 (val)
# vCDR error: 0.1242 (train), 0.0674 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 4
# LOSSES: 0.5448 (train), 0.7600 (val)
# OD segmentation (Dice Score): 0.8973 (train), 0.8054 (val)
# OC segmentation (Dice Score): 0.8514 (train), 0.6530 (val)
# vCDR error: 0.1122 (train), 0.2887 (val)
# __________________________________________________
# VALIDATION epoch 5
# LOSSES: 0.4919 (train), 0.5406 (val)
# OD segmentation (Dice Score): 0.9010 (train), 0.8784 (val)
# OC segmentation (Dice Score): 0.8600 (train), 0.8546 (val)
# vCDR error: 0.1047 (train), 0.0667 (val)
# __________________________________________________
# VALIDATION epoch 6
# LOSSES: 0.4464 (train), 0.6160 (val)
# OD segmentation (Dice Score): 0.9060 (train), 0.8056 (val)
# OC segmentation (Dice Score): 0.8687 (train), 0.7851 (val)
# vCDR error: 0.0992 (train), 0.1533 (val)
# __________________________________________________
# VALIDATION epoch 7
# LOSSES: 0.4178 (train), 0.4361 (val)
# OD segmentation (Dice Score): 0.9078 (train), 0.9079 (val)
# OC segmentation (Dice Score): 0.8718 (train), 0.8546 (val)
# vCDR error: 0.0968 (train), 0.0666 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 8
# LOSSES: 0.3949 (train), 0.3676 (val)
# OD segmentation (Dice Score): 0.9111 (train), 0.9217 (val)
# OC segmentation (Dice Score): 0.8753 (train), 0.8750 (val)
# vCDR error: 0.0954 (train), 0.0582 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 9
# LOSSES: 0.3804 (train), 0.3714 (val)
# OD segmentation (Dice Score): 0.9121 (train), 0.9177 (val)
# OC segmentation (Dice Score): 0.8769 (train), 0.8657 (val)
# vCDR error: 0.0938 (train), 0.0622 (val)
# __________________________________________________
# VALIDATION epoch 10
# LOSSES: 0.3625 (train), 0.4074 (val)
# OD segmentation (Dice Score): 0.9151 (train), 0.8987 (val)
# OC segmentation (Dice Score): 0.8813 (train), 0.8604 (val)
# vCDR error: 0.0892 (train), 0.0710 (val)
# __________________________________________________
# VALIDATION epoch 11
# LOSSES: 0.3572 (train), 0.3937 (val)
# OD segmentation (Dice Score): 0.9139 (train), 0.9082 (val)
# OC segmentation (Dice Score): 0.8817 (train), 0.8608 (val)
# vCDR error: 0.0934 (train), 0.0597 (val)
# __________________________________________________
# VALIDATION epoch 12
# LOSSES: 0.3447 (train), 0.4468 (val)
# OD segmentation (Dice Score): 0.9173 (train), 0.8949 (val)
# OC segmentation (Dice Score): 0.8839 (train), 0.8373 (val)
# vCDR error: 0.0859 (train), 0.1304 (val)
# __________________________________________________
# VALIDATION epoch 13
# LOSSES: 0.3358 (train), 0.3576 (val)
# OD segmentation (Dice Score): 0.9192 (train), 0.9171 (val)
# OC segmentation (Dice Score): 0.8868 (train), 0.8741 (val)
# vCDR error: 0.0824 (train), 0.0584 (val)
# __________________________________________________
# VALIDATION epoch 14
# LOSSES: 0.3317 (train), 0.3617 (val)
# OD segmentation (Dice Score): 0.9201 (train), 0.9138 (val)
# OC segmentation (Dice Score): 0.8881 (train), 0.8695 (val)
# vCDR error: 0.0830 (train), 0.0674 (val)
# __________________________________________________
# VALIDATION epoch 15
# LOSSES: 0.3176 (train), 0.3745 (val)
# OD segmentation (Dice Score): 0.9229 (train), 0.9125 (val)
# OC segmentation (Dice Score): 0.8931 (train), 0.8709 (val)
# vCDR error: 0.0791 (train), 0.0585 (val)
# __________________________________________________
# VALIDATION epoch 16
# LOSSES: 0.3143 (train), 0.3573 (val)
# OD segmentation (Dice Score): 0.9237 (train), 0.9180 (val)
# OC segmentation (Dice Score): 0.8935 (train), 0.8689 (val)
# vCDR error: 0.0774 (train), 0.0625 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 17
# LOSSES: 0.3056 (train), 0.3552 (val)
# OD segmentation (Dice Score): 0.9259 (train), 0.9186 (val)
# OC segmentation (Dice Score): 0.8960 (train), 0.8718 (val)
# vCDR error: 0.0742 (train), 0.0519 (val)
# __________________________________________________
# VALIDATION epoch 18
# LOSSES: 0.3015 (train), 0.3569 (val)
# OD segmentation (Dice Score): 0.9267 (train), 0.9142 (val)
# OC segmentation (Dice Score): 0.8976 (train), 0.8761 (val)
# vCDR error: 0.0733 (train), 0.0562 (val)
# __________________________________________________
# VALIDATION epoch 19
# LOSSES: 0.2921 (train), 0.3451 (val)
# OD segmentation (Dice Score): 0.9290 (train), 0.9212 (val)
# OC segmentation (Dice Score): 0.9011 (train), 0.8761 (val)
# vCDR error: 0.0710 (train), 0.0643 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 20
# LOSSES: 0.2899 (train), 0.3375 (val)
# OD segmentation (Dice Score): 0.9289 (train), 0.9222 (val)
# OC segmentation (Dice Score): 0.9018 (train), 0.8759 (val)
# vCDR error: 0.0700 (train), 0.0597 (val)
# __________________________________________________
# VALIDATION epoch 21
# LOSSES: 0.2798 (train), 0.4208 (val)
# OD segmentation (Dice Score): 0.9310 (train), 0.9007 (val)
# OC segmentation (Dice Score): 0.9055 (train), 0.8471 (val)
# vCDR error: 0.0664 (train), 0.0674 (val)
# __________________________________________________
# VALIDATION epoch 22
# LOSSES: 0.2768 (train), 0.4156 (val)
# OD segmentation (Dice Score): 0.9319 (train), 0.9056 (val)
# OC segmentation (Dice Score): 0.9066 (train), 0.8506 (val)
# vCDR error: 0.0666 (train), 0.0984 (val)
# __________________________________________________
# VALIDATION epoch 23
# LOSSES: 0.2685 (train), 0.3980 (val)
# OD segmentation (Dice Score): 0.9338 (train), 0.9092 (val)
# OC segmentation (Dice Score): 0.9097 (train), 0.8725 (val)
# vCDR error: 0.0626 (train), 0.0673 (val)
# __________________________________________________
# VALIDATION epoch 24
# LOSSES: 0.2641 (train), 0.3439 (val)
# OD segmentation (Dice Score): 0.9345 (train), 0.9226 (val)
# OC segmentation (Dice Score): 0.9109 (train), 0.8761 (val)
# vCDR error: 0.0616 (train), 0.0593 (val)
# __________________________________________________
# VALIDATION epoch 25
# LOSSES: 0.2552 (train), 0.3544 (val)
# OD segmentation (Dice Score): 0.9366 (train), 0.9168 (val)
# OC segmentation (Dice Score): 0.9146 (train), 0.8736 (val)
# vCDR error: 0.0594 (train), 0.0535 (val)
# __________________________________________________
# VALIDATION epoch 26
# LOSSES: 0.2521 (train), 0.3886 (val)
# OD segmentation (Dice Score): 0.9373 (train), 0.9077 (val)
# OC segmentation (Dice Score): 0.9154 (train), 0.8654 (val)
# vCDR error: 0.0580 (train), 0.0653 (val)
# __________________________________________________
# VALIDATION epoch 27
# LOSSES: 0.2492 (train), 0.3354 (val)
# OD segmentation (Dice Score): 0.9379 (train), 0.9244 (val)
# OC segmentation (Dice Score): 0.9164 (train), 0.8796 (val)
# vCDR error: 0.0559 (train), 0.0569 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 28
# LOSSES: 0.2423 (train), 0.3593 (val)
# OD segmentation (Dice Score): 0.9394 (train), 0.9125 (val)
# OC segmentation (Dice Score): 0.9192 (train), 0.8687 (val)
# vCDR error: 0.0545 (train), 0.0690 (val)
# __________________________________________________
# VALIDATION epoch 29
# LOSSES: 0.2384 (train), 0.3368 (val)
# OD segmentation (Dice Score): 0.9401 (train), 0.9242 (val)
# OC segmentation (Dice Score): 0.9209 (train), 0.8782 (val)
# vCDR error: 0.0542 (train), 0.0578 (val)
# __________________________________________________
# VALIDATION epoch 30
# LOSSES: 0.2268 (train), 0.4219 (val)
# OD segmentation (Dice Score): 0.9423 (train), 0.9075 (val)
# OC segmentation (Dice Score): 0.9251 (train), 0.8404 (val)
# vCDR error: 0.0505 (train), 0.0975 (val)
# __________________________________________________
# VALIDATION epoch 31
# LOSSES: 0.2242 (train), 0.3164 (val)
# OD segmentation (Dice Score): 0.9433 (train), 0.9264 (val)
# OC segmentation (Dice Score): 0.9256 (train), 0.8862 (val)
# vCDR error: 0.0494 (train), 0.0580 (val)
# Best validation AUC reached. Saved model weights.
# __________________________________________________
# VALIDATION epoch 32
# LOSSES: 0.2173 (train), 0.3310 (val)
# OD segmentation (Dice Score): 0.9447 (train), 0.9277 (val)
# OC segmentation (Dice Score): 0.9286 (train), 0.8835 (val)
# vCDR error: 0.0480 (train), 0.0566 (val)
# __________________________________________________
# VALIDATION epoch 33
# LOSSES: 0.2123 (train), 0.3276 (val)
# OD segmentation (Dice Score): 0.9460 (train), 0.9180 (val)
# OC segmentation (Dice Score): 0.9298 (train), 0.8902 (val)
# vCDR error: 0.0480 (train), 0.0546 (val)
# __________________________________________________
# VALIDATION epoch 34
# LOSSES: 0.2067 (train), 0.3325 (val)
# OD segmentation (Dice Score): 0.9470 (train), 0.9236 (val)
# OC segmentation (Dice Score): 0.9319 (train), 0.8812 (val)
# vCDR error: 0.0443 (train), 0.0564 (val)
# __________________________________________________
# VALIDATION epoch 35
# LOSSES: 0.2041 (train), 0.4076 (val)
# OD segmentation (Dice Score): 0.9470 (train), 0.8982 (val)
# OC segmentation (Dice Score): 0.9336 (train), 0.8594 (val)
# vCDR error: 0.0452 (train), 0.0628 (val)
# __________________________________________________
# VALIDATION epoch 36
# LOSSES: 0.1996 (train), 0.3191 (val)
# OD segmentation (Dice Score): 0.9485 (train), 0.9275 (val)
# OC segmentation (Dice Score): 0.9350 (train), 0.8849 (val)
# vCDR error: 0.0433 (train), 0.0597 (val)
# __________________________________________________
# VALIDATION epoch 37
# LOSSES: 0.1934 (train), 0.3571 (val)
# OD segmentation (Dice Score): 0.9498 (train), 0.9198 (val)
# OC segmentation (Dice Score): 0.9368 (train), 0.8686 (val)
# vCDR error: 0.0437 (train), 0.0760 (val)
# __________________________________________________
# VALIDATION epoch 38
# LOSSES: 0.1899 (train), 0.3177 (val)
# OD segmentation (Dice Score): 0.9508 (train), 0.9280 (val)
# OC segmentation (Dice Score): 0.9380 (train), 0.8857 (val)
# vCDR error: 0.0406 (train), 0.0596 (val)
# __________________________________________________
# VALIDATION epoch 39
# LOSSES: 0.1838 (train), 0.3360 (val)
# OD segmentation (Dice Score): 0.9517 (train), 0.9203 (val)
# OC segmentation (Dice Score): 0.9411 (train), 0.8808 (val)
# vCDR error: 0.0395 (train), 0.0601 (val)
# __________________________________________________
# VALIDATION epoch 40
# LOSSES: 0.1805 (train), 0.3656 (val)
# OD segmentation (Dice Score): 0.9527 (train), 0.9175 (val)
# OC segmentation (Dice Score): 0.9414 (train), 0.8651 (val)
# vCDR error: 0.0398 (train), 0.0618 (val)
# __________________________________________________
# VALIDATION epoch 41
# LOSSES: 0.1744 (train), 0.6227 (val)
# OD segmentation (Dice Score): 0.9542 (train), 0.9210 (val)
# OC segmentation (Dice Score): 0.9437 (train), 0.4078 (val)
# vCDR error: 0.0366 (train), 0.1878 (val)
# __________________________________________________
# VALIDATION epoch 42
# LOSSES: 0.1737 (train), 0.3409 (val)
# OD segmentation (Dice Score): 0.9543 (train), 0.9219 (val)
# OC segmentation (Dice Score): 0.9424 (train), 0.8813 (val)
# vCDR error: 0.0377 (train), 0.0634 (val)
# __________________________________________________
# VALIDATION epoch 43
# LOSSES: 0.1691 (train), 0.3716 (val)
# OD segmentation (Dice Score): 0.9552 (train), 0.9197 (val)
# OC segmentation (Dice Score): 0.9454 (train), 0.8631 (val)
# vCDR error: 0.0382 (train), 0.0768 (val)
# __________________________________________________
# VALIDATION epoch 44
# LOSSES: 0.1639 (train), 0.3636 (val)
# OD segmentation (Dice Score): 0.9564 (train), 0.9189 (val)
# OC segmentation (Dice Score): 0.9476 (train), 0.8714 (val)
# vCDR error: 0.0360 (train), 0.0711 (val)
# __________________________________________________
# VALIDATION epoch 45
# LOSSES: 0.1623 (train), 0.3513 (val)
# OD segmentation (Dice Score): 0.9567 (train), 0.9238 (val)
# OC segmentation (Dice Score): 0.9481 (train), 0.8722 (val)
# vCDR error: 0.0361 (train), 0.0647 (val)
# __________________________________________________
# VALIDATION epoch 46
# LOSSES: 0.1562 (train), 0.3611 (val)
# OD segmentation (Dice Score): 0.9581 (train), 0.9158 (val)
# OC segmentation (Dice Score): 0.9503 (train), 0.8739 (val)
# vCDR error: 0.0319 (train), 0.0772 (val)
# __________________________________________________
# VALIDATION epoch 47
# LOSSES: 0.1557 (train), 0.3325 (val)
# OD segmentation (Dice Score): 0.9584 (train), 0.9244 (val)
# OC segmentation (Dice Score): 0.9502 (train), 0.8821 (val)
# vCDR error: 0.0346 (train), 0.0626 (val)
# __________________________________________________
# VALIDATION epoch 48
# LOSSES: 0.1510 (train), 0.3565 (val)
# OD segmentation (Dice Score): 0.9597 (train), 0.9160 (val)
# OC segmentation (Dice Score): 0.9519 (train), 0.8783 (val)
# vCDR error: 0.0331 (train), 0.0629 (val)
# __________________________________________________
# VALIDATION epoch 49
# LOSSES: 0.1495 (train), 0.3299 (val)
# OD segmentation (Dice Score): 0.9601 (train), 0.9238 (val)
# OC segmentation (Dice Score): 0.9524 (train), 0.8843 (val)
# vCDR error: 0.0329 (train), 0.0605 (val)
# __________________________________________________
# VALIDATION epoch 50
# LOSSES: 0.1454 (train), 0.3339 (val)
# OD segmentation (Dice Score): 0.9608 (train), 0.9252 (val)
# OC segmentation (Dice Score): 0.9538 (train), 0.8819 (val)
# vCDR error: 0.0324 (train), 0.0643 (val)
# __________________________________________________
# VALIDATION epoch 51
# LOSSES: 0.1409 (train), 0.3406 (val)
# OD segmentation (Dice Score): 0.9622 (train), 0.9202 (val)
# OC segmentation (Dice Score): 0.9550 (train), 0.8805 (val)
# vCDR error: 0.0317 (train), 0.0578 (val)
# __________________________________________________
# VALIDATION epoch 52
# LOSSES: 0.1409 (train), 0.3841 (val)
# OD segmentation (Dice Score): 0.9622 (train), 0.9142 (val)
# OC segmentation (Dice Score): 0.9556 (train), 0.8588 (val)
# vCDR error: 0.0299 (train), 0.0787 (val)
# __________________________________________________
# VALIDATION epoch 53
# LOSSES: 0.1384 (train), 0.3721 (val)
# OD segmentation (Dice Score): 0.9629 (train), 0.9156 (val)
# OC segmentation (Dice Score): 0.9558 (train), 0.8668 (val)
# vCDR error: 0.0308 (train), 0.0782 (val)
# __________________________________________________
# VALIDATION epoch 54
# LOSSES: 0.1345 (train), 0.3503 (val)
# OD segmentation (Dice Score): 0.9637 (train), 0.9228 (val)
# OC segmentation (Dice Score): 0.9574 (train), 0.8731 (val)
# vCDR error: 0.0302 (train), 0.0706 (val)
# __________________________________________________
# VALIDATION epoch 55
# LOSSES: 0.1318 (train), 0.3683 (val)
# OD segmentation (Dice Score): 0.9642 (train), 0.9160 (val)
# OC segmentation (Dice Score): 0.9588 (train), 0.8661 (val)
# vCDR error: 0.0284 (train), 0.0826 (val)
# __________________________________________________
# VALIDATION epoch 56
# LOSSES: 0.1319 (train), 0.3524 (val)
# OD segmentation (Dice Score): 0.9640 (train), 0.9226 (val)
# OC segmentation (Dice Score): 0.9589 (train), 0.8718 (val)
# vCDR error: 0.0288 (train), 0.0684 (val)
# __________________________________________________
# VALIDATION epoch 57
# LOSSES: 0.1290 (train), 0.3945 (val)
# OD segmentation (Dice Score): 0.9649 (train), 0.9076 (val)
# OC segmentation (Dice Score): 0.9599 (train), 0.8634 (val)
# vCDR error: 0.0277 (train), 0.0783 (val)
# __________________________________________________
# VALIDATION epoch 58
# LOSSES: 0.1248 (train), 0.3321 (val)
# OD segmentation (Dice Score): 0.9664 (train), 0.9257 (val)
# OC segmentation (Dice Score): 0.9609 (train), 0.8818 (val)
# vCDR error: 0.0273 (train), 0.0603 (val)
# __________________________________________________
# VALIDATION epoch 59
# LOSSES: 0.1228 (train), 0.3515 (val)
# OD segmentation (Dice Score): 0.9665 (train), 0.9206 (val)
# OC segmentation (Dice Score): 0.9618 (train), 0.8769 (val)
# vCDR error: 0.0272 (train), 0.0663 (val)
# __________________________________________________
# VALIDATION epoch 60
# LOSSES: 0.1206 (train), 0.3826 (val)
# OD segmentation (Dice Score): 0.9672 (train), 0.9142 (val)
# OC segmentation (Dice Score): 0.9624 (train), 0.8634 (val)
# vCDR error: 0.0265 (train), 0.0812 (val)
# __________________________________________________
# VALIDATION epoch 61
# LOSSES: 0.1197 (train), 0.3691 (val)
# OD segmentation (Dice Score): 0.9676 (train), 0.9157 (val)
# OC segmentation (Dice Score): 0.9624 (train), 0.8686 (val)
# vCDR error: 0.0251 (train), 0.0731 (val)
# __________________________________________________
# VALIDATION epoch 62
# LOSSES: 0.1173 (train), 0.3749 (val)
# OD segmentation (Dice Score): 0.9681 (train), 0.9138 (val)
# OC segmentation (Dice Score): 0.9634 (train), 0.8657 (val)
# vCDR error: 0.0260 (train), 0.0766 (val)
# __________________________________________________
# VALIDATION epoch 63
# LOSSES: 0.1164 (train), 0.3886 (val)
# OD segmentation (Dice Score): 0.9683 (train), 0.9121 (val)
# OC segmentation (Dice Score): 0.9636 (train), 0.8621 (val)
# vCDR error: 0.0256 (train), 0.0805 (val)
# __________________________________________________
# VALIDATION epoch 64
# LOSSES: 0.1130 (train), 0.3503 (val)
# OD segmentation (Dice Score): 0.9689 (train), 0.9223 (val)
# OC segmentation (Dice Score): 0.9651 (train), 0.8748 (val)
# vCDR error: 0.0244 (train), 0.0668 (val)
# __________________________________________________
# VALIDATION epoch 65
# LOSSES: 0.1139 (train), 0.3625 (val)
# OD segmentation (Dice Score): 0.9691 (train), 0.9231 (val)
# OC segmentation (Dice Score): 0.9639 (train), 0.8709 (val)
# vCDR error: 0.0246 (train), 0.0687 (val)
# __________________________________________________
# VALIDATION epoch 66
# LOSSES: 0.1109 (train), 0.3902 (val)
# OD segmentation (Dice Score): 0.9699 (train), 0.9083 (val)
# OC segmentation (Dice Score): 0.9653 (train), 0.8653 (val)
# vCDR error: 0.0247 (train), 0.0727 (val)
# __________________________________________________
# VALIDATION epoch 67
# LOSSES: 0.1078 (train), 0.3653 (val)
# OD segmentation (Dice Score): 0.9705 (train), 0.9101 (val)
# OC segmentation (Dice Score): 0.9666 (train), 0.8785 (val)
# vCDR error: 0.0242 (train), 0.0610 (val)
# __________________________________________________
# VALIDATION epoch 68
# LOSSES: 0.1103 (train), 0.3729 (val)
# OD segmentation (Dice Score): 0.9701 (train), 0.9181 (val)
# OC segmentation (Dice Score): 0.9654 (train), 0.8641 (val)
# vCDR error: 0.0242 (train), 0.0786 (val)
# __________________________________________________
# VALIDATION epoch 69
# LOSSES: 0.1068 (train), 0.3570 (val)
# OD segmentation (Dice Score): 0.9708 (train), 0.9169 (val)
# OC segmentation (Dice Score): 0.9666 (train), 0.8741 (val)
# vCDR error: 0.0231 (train), 0.0636 (val)
# __________________________________________________
# VALIDATION epoch 70
# LOSSES: 0.1058 (train), 0.3472 (val)
# OD segmentation (Dice Score): 0.9711 (train), 0.9232 (val)
# OC segmentation (Dice Score): 0.9671 (train), 0.8798 (val)
# vCDR error: 0.0232 (train), 0.0595 (val)
# __________________________________________________
# VALIDATION epoch 71
# LOSSES: 0.1049 (train), 0.3514 (val)
# OD segmentation (Dice Score): 0.9714 (train), 0.9179 (val)
# OC segmentation (Dice Score): 0.9672 (train), 0.8785 (val)
# vCDR error: 0.0227 (train), 0.0604 (val)
# __________________________________________________
# VALIDATION epoch 72
# LOSSES: 0.1043 (train), 0.3558 (val)
# OD segmentation (Dice Score): 0.9716 (train), 0.9210 (val)
# OC segmentation (Dice Score): 0.9678 (train), 0.8709 (val)
# vCDR error: 0.0223 (train), 0.0650 (val)
# __________________________________________________
# VALIDATION epoch 73
# LOSSES: 0.1016 (train), 0.3413 (val)
# OD segmentation (Dice Score): 0.9722 (train), 0.9231 (val)
# OC segmentation (Dice Score): 0.9684 (train), 0.8799 (val)
# vCDR error: 0.0222 (train), 0.0614 (val)
# __________________________________________________
# VALIDATION epoch 74
# LOSSES: 0.1017 (train), 0.3579 (val)
# OD segmentation (Dice Score): 0.9721 (train), 0.9178 (val)
# OC segmentation (Dice Score): 0.9686 (train), 0.8718 (val)
# vCDR error: 0.0221 (train), 0.0672 (val)
# __________________________________________________
# VALIDATION epoch 75
# LOSSES: 0.1007 (train), 0.3573 (val)
# OD segmentation (Dice Score): 0.9725 (train), 0.9201 (val)
# OC segmentation (Dice Score): 0.9690 (train), 0.8713 (val)
# vCDR error: 0.0226 (train), 0.0749 (val)
# __________________________________________________
# VALIDATION epoch 76
# LOSSES: 0.0982 (train), 0.3378 (val)
# OD segmentation (Dice Score): 0.9731 (train), 0.9244 (val)
# OC segmentation (Dice Score): 0.9697 (train), 0.8786 (val)
# vCDR error: 0.0208 (train), 0.0643 (val)
# __________________________________________________
# VALIDATION epoch 77
# LOSSES: 0.0978 (train), 0.3449 (val)
# OD segmentation (Dice Score): 0.9738 (train), 0.9181 (val)
# OC segmentation (Dice Score): 0.9694 (train), 0.8829 (val)
# vCDR error: 0.0210 (train), 0.0607 (val)
# __________________________________________________
# VALIDATION epoch 78
# LOSSES: 0.0958 (train), 0.3625 (val)
# OD segmentation (Dice Score): 0.9737 (train), 0.9140 (val)
# OC segmentation (Dice Score): 0.9703 (train), 0.8753 (val)
# vCDR error: 0.0211 (train), 0.0684 (val)
# __________________________________________________
# VALIDATION epoch 79
# LOSSES: 0.0947 (train), 0.3431 (val)
# OD segmentation (Dice Score): 0.9740 (train), 0.9204 (val)
# OC segmentation (Dice Score): 0.9710 (train), 0.8815 (val)
# vCDR error: 0.0206 (train), 0.0614 (val)
# __________________________________________________
# VALIDATION epoch 80
# LOSSES: 0.0938 (train), 0.3487 (val)
# OD segmentation (Dice Score): 0.9745 (train), 0.9227 (val)
# OC segmentation (Dice Score): 0.9709 (train), 0.8725 (val)
# vCDR error: 0.0204 (train), 0.0617 (val)
# __________________________________________________

# %%
torch.save(model.state_dict(), '/kaggle/working/OD_OC_Coarse_Model_Larger.pth')

# %% [markdown]
# # Vizualize results

# %%
loaded_model = UNet(n_channels=3, n_classes=4)
loaded_model.load_state_dict(torch.load('/kaggle/working/OD_OC_Coarse_Model.pth', map_location=device))
loaded_model.to(device)
loaded_model.eval()
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down5): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down6): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(4096, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(2048, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up4): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up5): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up6): Up(
#     (up): Upsample(scale_factor=2.0, mode=bilinear)
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (output_layer): OutConv(
#     (conv): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
images_path = "../input/glaucoma-datasets/REFUGE/test/Images_Cropped"
masks_path = "../input/glaucoma-datasets/REFUGE/test/Masks_Cropped"
image_filenames = []
for path in os.listdir(images_path):
    image_filenames.append(path)

# %%
output_size = (256, 256)
def compute_boundary(mask):
        dilated_mask = dilation(mask.squeeze().numpy(), rectangle(19, 19))
        eroded_mask = erosion(mask.squeeze().numpy(), rectangle(19, 19))
        boundary = dilated_mask - eroded_mask
        boundary = torch.from_numpy(boundary[None, :, :]).float()
        return boundary
    
def get_seg_img(filename):
    img = np.array(Image.open(os.path.join(images_path, filename)).convert('RGB'))
    #sample_img = img
    img = transforms.functional.to_tensor(img)
    img = transforms.functional.resize(img, output_size, interpolation=transforms.InterpolationMode.BILINEAR)
    filename_mask = filename[:-3] + "png"
    mask = np.array(Image.open(os.path.join(masks_path, filename_mask), mode='r'))
    od = (mask==1.).astype(np.float32)
    oc = (mask==2.).astype(np.float32)
    od = torch.from_numpy(od[None,:,:])
    oc = torch.from_numpy(oc[None,:,:])
    od = transforms.functional.resize(od, output_size, interpolation=transforms.InterpolationMode.NEAREST)
    oc = transforms.functional.resize(oc, output_size, interpolation=transforms.InterpolationMode.NEAREST)
    seg = torch.cat([od, oc], dim=0)
    od_boundary = compute_boundary(od)
    oc_boundary = compute_boundary(oc)
    boundary = torch.cat([od_boundary, oc_boundary], dim=0)

    
    return img, seg, boundary

# %%
def get_preds(num):
    filename = image_filenames[num]
    val_mask = resize(np.array(Image.open(os.path.join(masks_path, filename[:-3] + "png"), mode='r')), (256, 256))
    img, gt_seg, boundary = get_seg_img(filename)
    sample_img = img.numpy()
    sample_mask = gt_seg.numpy()
    sample_boundary = boundary.numpy()
    img = torch.unsqueeze(img, 0).to(device)
    gt_seg = torch.unsqueeze(gt_seg, 0).to(device)
    boundary = torch.unsqueeze(boundary, 0).to(device)
    
    logits = loaded_model(img)
    pred_od = refine_seg((logits[:,0,:,:]>=0.5).type(torch.int8).cpu())
    pred_oc = refine_seg((logits[:,1,:,:]>=0.5).type(torch.int8).cpu())
    pred_od_bd = refine_seg((logits[:,2,:,:]>=0.5).type(torch.int8).cpu())
    pred_oc_bd = refine_seg((logits[:,3,:,:]>=0.5).type(torch.int8).cpu())
    gt_od = gt_seg[:,0,:,:].type(torch.int8).cpu()
    gt_oc = gt_seg[:,1,:,:].type(torch.int8).cpu()
    bd_od = boundary[:,0,:,:].type(torch.int8).cpu()
    bd_oc = boundary[:,1,:,:].type(torch.int8).cpu()
    
    return sample_img, sample_mask,sample_boundary, pred_od, pred_oc, pred_od_bd, pred_oc_bd, gt_od, gt_oc,bd_od,bd_oc, val_mask

# %%
from skimage.transform import resize

# Initialize lists to store dice scores
od_dice_scores = []
oc_dice_scores = []

# Loop through all images to calculate dice scores
for idx in range(len(image_filenames)):
    sample_img, sample_mask, sample_boundary, pred_od, pred_oc, pred_od_bd, pred_oc_bd, gt_od, gt_oc, bd_od, bd_oc, val_mask = get_preds(idx)
    od_dice_scores.append(compute_dice_coef(pred_od, gt_od))
    oc_dice_scores.append(compute_dice_coef(pred_oc, gt_oc))
    
plt.figure(figsize=(14, 6))

# Plot for the first array
plt.subplot(1, 2, 1)
plt.hist(od_dice_scores, bins=30, edgecolor='k', alpha=0.7)
plt.title('Distribution of OD_DS')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Plot for the second array
plt.subplot(1, 2, 2)
plt.hist(oc_dice_scores, bins=30, edgecolor='k', alpha=0.7)
plt.title('Distribution of OC_DS')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()


# Calculate mean dice scores
mean_od_dice = np.mean(od_dice_scores)
mean_oc_dice = np.mean(oc_dice_scores)
std_od_dice = np.std(od_dice_scores)
std_oc_dice = np.std(oc_dice_scores)
print(f"OD Seg Dice Score:  {mean_od_dice} ± {std_od_dice}")
print(f"OC Seg Dice Score:  {mean_oc_dice} ± {std_oc_dice}")

# Randomly select 5 images for visualization
random_indices = random.sample(range(len(image_filenames)), 5)
print("Here are 5 random sample visualisations: ")
print('_'*50)
# Visualization
for idx in random_indices:
    sample_img, sample_mask, sample_boundary, pred_od, pred_oc, pred_od_bd, pred_oc_bd, gt_od, gt_oc, bd_od, bd_oc, val_mask = get_preds(idx)
    
    f, axarr = plt.subplots(2, 3, squeeze=False)
    print(f"OD Seg Dice Score:  {compute_dice_coef(pred_od, gt_od)}")
    print(f"OC Seg Dice Score:  {compute_dice_coef(pred_oc, gt_oc)}")

    input_img = np.swapaxes(np.swapaxes(sample_img, 0, 2), 0, 1)
    gt_mask = np.swapaxes(np.swapaxes(sample_mask, 0, 2), 0, 1)
    gt_mask[:, :, 0][gt_mask[:, :, 0] > 0] = 2
    output_mask = gt_mask[:, :, 0] + gt_mask[:, :, 1]
    print(gt_mask.shape, output_mask.shape)
    print(np.max(output_mask))
    pred_od_mask = pred_od.numpy().reshape(256, 256) + (2 * pred_oc.numpy().reshape(256, 256))
    bd_mask = bd_od.numpy().reshape(256, 256) + (2 * bd_oc.numpy().reshape(256, 256))
    pred_od_bd_mask = pred_od_bd.numpy().reshape(256, 256) + (2 * pred_oc_bd.numpy().reshape(256, 256))

    axarr[0][0].imshow(input_img)
    axarr[0][1].imshow(val_mask)
    axarr[0][2].imshow(pred_od_mask)
    axarr[1][1].imshow(bd_mask)
    axarr[1][2].imshow(pred_od_bd_mask)
    plt.show()
# Out:
# OD Seg Dice Score:  0.9263615608215332 ± 0.04434638470411301
# OC Seg Dice Score:  0.8862114548683167 ± 0.058851927518844604
# Here are 5 random sample visualisations:
# __________________________________________________
# OD Seg Dice Score:  0.9099939465522766
# OC Seg Dice Score:  0.721532940864563
# (256, 256, 2) (256, 256)
# 2.0
# OD Seg Dice Score:  0.9589200615882874
# OC Seg Dice Score:  0.9438202381134033
# (256, 256, 2) (256, 256)
# 2.0
# OD Seg Dice Score:  0.9638252258300781
# OC Seg Dice Score:  0.9498175382614136
# (256, 256, 2) (256, 256)
# 2.0
# OD Seg Dice Score:  0.9536888599395752
# OC Seg Dice Score:  0.9415453672409058
# (256, 256, 2) (256, 256)
# 2.0
# OD Seg Dice Score:  0.9114928841590881
# OC Seg Dice Score:  0.9282947778701782
# (256, 256, 2) (256, 256)
# 2.0

# %% [markdown]
# # Making Distance Synthetic Forms (DSI) of Output Imgs

# %%
def convert_to_distance_map(pred):
    """
    Convert prediction to a distance map using distance transform.
    """
    # Ensure binary image for distance transform
    binary_pred = (pred > 0).astype(np.uint8)
    # Compute the distance transform
    dist_map = cv2.distanceTransform(binary_pred, cv2.DIST_L2, 3)
    return dist_map

def normalize_map(dist_map):
    """
    Normalize the distance map to the range 0-255.
    """
    normalized_map = cv2.normalize(dist_map, None, 0, 255, cv2.NORM_MINMAX)
    return normalized_map.astype(np.uint8)

# %%
def generate_dsi_images(loader, model, output_dir):
    # Set model to evaluation mode
    model.eval()
    
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    with torch.no_grad():
        for imgs, seg_gts, boundaries, img_names in loader:
            # Move data to the appropriate device
            imgs = imgs.to(device)
            
            # Get predictions from the model
            logits = model(imgs)
            pred_od = (logits[:, 0, :, :] >= 0.5).cpu().numpy()
            pred_oc = (logits[:, 1, :, :] >= 0.5).cpu().numpy()
            boundary_pred_od = (logits[:, 2, :, :] >= 0.5).cpu().numpy()
            boundary_pred_oc = (logits[:, 3, :, :] >= 0.5).cpu().numpy()
            
            for idx in range(imgs.shape[0]):
                # Convert predictions to distance maps
                od_dist_map = convert_to_distance_map(pred_od[idx])
                oc_dist_map = convert_to_distance_map(pred_oc[idx])
                boundary_od_dist_map = convert_to_distance_map(boundary_pred_od[idx])
                boundary_oc_dist_map = convert_to_distance_map(boundary_pred_oc[idx])
                
                # Normalize the distance maps
                norm_od_dist_map = normalize_map(od_dist_map)
                norm_oc_dist_map = normalize_map(oc_dist_map)
                norm_boundary_od_dist_map = normalize_map(boundary_od_dist_map)
                norm_boundary_oc_dist_map = normalize_map(boundary_oc_dist_map)
                
                # Sum the normalized distance maps to create the DSI
                dsi = norm_od_dist_map + norm_oc_dist_map + norm_boundary_od_dist_map + norm_boundary_oc_dist_map
                
                # Optionally, you can further normalize the DSI
                final_dsi = normalize_map(dsi)
                
                # Save the DSI image with the same name as the original image
                img_name = img_names[idx]
                output_path = os.path.join(output_dir, f'{img_name}.png')
                cv2.imwrite(output_path, final_dsi)
                
                print(f'Saved DSI image {img_name} to {output_path}')

# %%
print("Data and model loaded. Starting to generate DSI images for training data.")
# Generate and save DSI images for training data
train_output_dir = '/kaggle/working/larger_train_dsi_images'
generate_dsi_images(train_loader, loaded_model, train_output_dir)

print("Finished generating DSI images for training data. Starting to generate DSI images for validation data.")
# Generate and save DSI images for validation data
val_output_dir = '/kaggle/working/larger_val_dsi_images'
generate_dsi_images(val_loader, loaded_model, val_output_dir)

print("Finished generating DSI images for validation data.")
# Out:
# Data and model loaded. Starting to generate DSI images for training data.
# Saved DSI image V0232.jpg to /kaggle/working/larger_train_dsi_images/V0232.jpg.png
# Saved DSI image 446.jpg to /kaggle/working/larger_train_dsi_images/446.jpg.png
# Saved DSI image n0309.jpg to /kaggle/working/larger_train_dsi_images/n0309.jpg.png
# Saved DSI image n0203.jpg to /kaggle/working/larger_train_dsi_images/n0203.jpg.png
# Saved DSI image n0275.jpg to /kaggle/working/larger_train_dsi_images/n0275.jpg.png
# Saved DSI image n0091.jpg to /kaggle/working/larger_train_dsi_images/n0091.jpg.png
# Saved DSI image 646.jpg to /kaggle/working/larger_train_dsi_images/646.jpg.png
# Saved DSI image V0135.jpg to /kaggle/working/larger_train_dsi_images/V0135.jpg.png
# Saved DSI image 617.jpg to /kaggle/working/larger_train_dsi_images/617.jpg.png
# Saved DSI image V0110.jpg to /kaggle/working/larger_train_dsi_images/V0110.jpg.png
# Saved DSI image V0043.jpg to /kaggle/working/larger_train_dsi_images/V0043.jpg.png
# Saved DSI image n0327.jpg to /kaggle/working/larger_train_dsi_images/n0327.jpg.png
# Saved DSI image n0064.jpg to /kaggle/working/larger_train_dsi_images/n0064.jpg.png
# Saved DSI image 429.jpg to /kaggle/working/larger_train_dsi_images/429.jpg.png
# Saved DSI image V0212.jpg to /kaggle/working/larger_train_dsi_images/V0212.jpg.png
# Saved DSI image n0287.jpg to /kaggle/working/larger_train_dsi_images/n0287.jpg.png
# Saved DSI image V0365.jpg to /kaggle/working/larger_train_dsi_images/V0365.jpg.png
# Saved DSI image 021.jpg to /kaggle/working/larger_train_dsi_images/021.jpg.png
# Saved DSI image 232.jpg to /kaggle/working/larger_train_dsi_images/232.jpg.png
# Saved DSI image n0202.jpg to /kaggle/working/larger_train_dsi_images/n0202.jpg.png
# Saved DSI image n0104.jpg to /kaggle/working/larger_train_dsi_images/n0104.jpg.png
# Saved DSI image 010.jpg to /kaggle/working/larger_train_dsi_images/010.jpg.png
# Saved DSI image n0347.jpg to /kaggle/working/larger_train_dsi_images/n0347.jpg.png
# Saved DSI image V0065.jpg to /kaggle/working/larger_train_dsi_images/V0065.jpg.png
# Saved DSI image 386.jpg to /kaggle/working/larger_train_dsi_images/386.jpg.png
# Saved DSI image 648.jpg to /kaggle/working/larger_train_dsi_images/648.jpg.png
# Saved DSI image V0359.jpg to /kaggle/working/larger_train_dsi_images/V0359.jpg.png
# Saved DSI image 593.jpg to /kaggle/working/larger_train_dsi_images/593.jpg.png
# Saved DSI image 007.jpg to /kaggle/working/larger_train_dsi_images/007.jpg.png
# Saved DSI image V0211.jpg to /kaggle/working/larger_train_dsi_images/V0211.jpg.png
# Saved DSI image V0168.jpg to /kaggle/working/larger_train_dsi_images/V0168.jpg.png
# Saved DSI image n0041.jpg to /kaggle/working/larger_train_dsi_images/n0041.jpg.png
# Saved DSI image 360.jpg to /kaggle/working/larger_train_dsi_images/360.jpg.png
# Saved DSI image 244.jpg to /kaggle/working/larger_train_dsi_images/244.jpg.png
# Saved DSI image n0097.jpg to /kaggle/working/larger_train_dsi_images/n0097.jpg.png
# Saved DSI image 623.jpg to /kaggle/working/larger_train_dsi_images/623.jpg.png
# Saved DSI image n0118.jpg to /kaggle/working/larger_train_dsi_images/n0118.jpg.png
# Saved DSI image V0372.jpg to /kaggle/working/larger_train_dsi_images/V0372.jpg.png
# Saved DSI image n0070.jpg to /kaggle/working/larger_train_dsi_images/n0070.jpg.png
# Saved DSI image g0020.jpg to /kaggle/working/larger_train_dsi_images/g0020.jpg.png
# Saved DSI image 047.jpg to /kaggle/working/larger_train_dsi_images/047.jpg.png
# Saved DSI image 092.jpg to /kaggle/working/larger_train_dsi_images/092.jpg.png
# Saved DSI image 566.jpg to /kaggle/working/larger_train_dsi_images/566.jpg.png
# Saved DSI image V0117.jpg to /kaggle/working/larger_train_dsi_images/V0117.jpg.png
# Saved DSI image V0264.jpg to /kaggle/working/larger_train_dsi_images/V0264.jpg.png
# Saved DSI image n0338.jpg to /kaggle/working/larger_train_dsi_images/n0338.jpg.png
# Saved DSI image 029.jpg to /kaggle/working/larger_train_dsi_images/029.jpg.png
# Saved DSI image 079.jpg to /kaggle/working/larger_train_dsi_images/079.jpg.png
# Saved DSI image 124.jpg to /kaggle/working/larger_train_dsi_images/124.jpg.png
# Saved DSI image 179.jpg to /kaggle/working/larger_train_dsi_images/179.jpg.png
# Saved DSI image V0383.jpg to /kaggle/working/larger_train_dsi_images/V0383.jpg.png
# Saved DSI image 277.jpg to /kaggle/working/larger_train_dsi_images/277.jpg.png
# Saved DSI image 128.jpg to /kaggle/working/larger_train_dsi_images/128.jpg.png
# Saved DSI image V0231.jpg to /kaggle/working/larger_train_dsi_images/V0231.jpg.png
# Saved DSI image n0046.jpg to /kaggle/working/larger_train_dsi_images/n0046.jpg.png
# Saved DSI image n0166.jpg to /kaggle/working/larger_train_dsi_images/n0166.jpg.png
# Saved DSI image 180.jpg to /kaggle/working/larger_train_dsi_images/180.jpg.png
# Saved DSI image 116.jpg to /kaggle/working/larger_train_dsi_images/116.jpg.png
# Saved DSI image 256.jpg to /kaggle/working/larger_train_dsi_images/256.jpg.png
# Saved DSI image 436.jpg to /kaggle/working/larger_train_dsi_images/436.jpg.png
# Saved DSI image n0350.jpg to /kaggle/working/larger_train_dsi_images/n0350.jpg.png
# Saved DSI image n0156.jpg to /kaggle/working/larger_train_dsi_images/n0156.jpg.png
# Saved DSI image V0219.jpg to /kaggle/working/larger_train_dsi_images/V0219.jpg.png
# Saved DSI image V0206.jpg to /kaggle/working/larger_train_dsi_images/V0206.jpg.png
# Saved DSI image V0256.jpg to /kaggle/working/larger_train_dsi_images/V0256.jpg.png
# Saved DSI image n0158.jpg to /kaggle/working/larger_train_dsi_images/n0158.jpg.png
# Saved DSI image n0260.jpg to /kaggle/working/larger_train_dsi_images/n0260.jpg.png
# Saved DSI image V0103.jpg to /kaggle/working/larger_train_dsi_images/V0103.jpg.png
# Saved DSI image V0013.jpg to /kaggle/working/larger_train_dsi_images/V0013.jpg.png
# Saved DSI image V0210.jpg to /kaggle/working/larger_train_dsi_images/V0210.jpg.png
# Saved DSI image 200.jpg to /kaggle/working/larger_train_dsi_images/200.jpg.png
# Saved DSI image V0379.jpg to /kaggle/working/larger_train_dsi_images/V0379.jpg.png
# Saved DSI image 637.jpg to /kaggle/working/larger_train_dsi_images/637.jpg.png
# Saved DSI image V0061.jpg to /kaggle/working/larger_train_dsi_images/V0061.jpg.png
# Saved DSI image V0093.jpg to /kaggle/working/larger_train_dsi_images/V0093.jpg.png
# Saved DSI image 038.jpg to /kaggle/working/larger_train_dsi_images/038.jpg.png
# Saved DSI image n0307.jpg to /kaggle/working/larger_train_dsi_images/n0307.jpg.png
# Saved DSI image 393.jpg to /kaggle/working/larger_train_dsi_images/393.jpg.png
# Saved DSI image 241.jpg to /kaggle/working/larger_train_dsi_images/241.jpg.png
# Saved DSI image 523.jpg to /kaggle/working/larger_train_dsi_images/523.jpg.png
# Saved DSI image 457.jpg to /kaggle/working/larger_train_dsi_images/457.jpg.png
# Saved DSI image 570.jpg to /kaggle/working/larger_train_dsi_images/570.jpg.png
# Saved DSI image 577.jpg to /kaggle/working/larger_train_dsi_images/577.jpg.png
# Saved DSI image 596.jpg to /kaggle/working/larger_train_dsi_images/596.jpg.png
# Saved DSI image n0233.jpg to /kaggle/working/larger_train_dsi_images/n0233.jpg.png
# Saved DSI image V0067.jpg to /kaggle/working/larger_train_dsi_images/V0067.jpg.png
# Saved DSI image 503.jpg to /kaggle/working/larger_train_dsi_images/503.jpg.png
# Saved DSI image 030.jpg to /kaggle/working/larger_train_dsi_images/030.jpg.png
# Saved DSI image n0139.jpg to /kaggle/working/larger_train_dsi_images/n0139.jpg.png
# Saved DSI image 217.jpg to /kaggle/working/larger_train_dsi_images/217.jpg.png
# Saved DSI image n0256.jpg to /kaggle/working/larger_train_dsi_images/n0256.jpg.png
# Saved DSI image n0141.jpg to /kaggle/working/larger_train_dsi_images/n0141.jpg.png
# Saved DSI image 219.jpg to /kaggle/working/larger_train_dsi_images/219.jpg.png
# Saved DSI image 147.jpg to /kaggle/working/larger_train_dsi_images/147.jpg.png
# Saved DSI image 052.jpg to /kaggle/working/larger_train_dsi_images/052.jpg.png
# Saved DSI image 332.jpg to /kaggle/working/larger_train_dsi_images/332.jpg.png
# Saved DSI image n0100.jpg to /kaggle/working/larger_train_dsi_images/n0100.jpg.png
# Saved DSI image V0248.jpg to /kaggle/working/larger_train_dsi_images/V0248.jpg.png
# Saved DSI image V0391.jpg to /kaggle/working/larger_train_dsi_images/V0391.jpg.png
# Saved DSI image 451.jpg to /kaggle/working/larger_train_dsi_images/451.jpg.png
# Saved DSI image 555.jpg to /kaggle/working/larger_train_dsi_images/555.jpg.png
# Saved DSI image 050.jpg to /kaggle/working/larger_train_dsi_images/050.jpg.png
# Saved DSI image 278.jpg to /kaggle/working/larger_train_dsi_images/278.jpg.png
# Saved DSI image V0146.jpg to /kaggle/working/larger_train_dsi_images/V0146.jpg.png
# Saved DSI image V0064.jpg to /kaggle/working/larger_train_dsi_images/V0064.jpg.png
# Saved DSI image n0075.jpg to /kaggle/working/larger_train_dsi_images/n0075.jpg.png
# Saved DSI image n0080.jpg to /kaggle/working/larger_train_dsi_images/n0080.jpg.png
# Saved DSI image V0096.jpg to /kaggle/working/larger_train_dsi_images/V0096.jpg.png
# Saved DSI image 410.jpg to /kaggle/working/larger_train_dsi_images/410.jpg.png
# Saved DSI image 489.jpg to /kaggle/working/larger_train_dsi_images/489.jpg.png
# Saved DSI image n0180.jpg to /kaggle/working/larger_train_dsi_images/n0180.jpg.png
# Saved DSI image 136.jpg to /kaggle/working/larger_train_dsi_images/136.jpg.png
# Saved DSI image V0058.jpg to /kaggle/working/larger_train_dsi_images/V0058.jpg.png
# Saved DSI image 185.jpg to /kaggle/working/larger_train_dsi_images/185.jpg.png
# Saved DSI image 505.jpg to /kaggle/working/larger_train_dsi_images/505.jpg.png
# Saved DSI image V0324.jpg to /kaggle/working/larger_train_dsi_images/V0324.jpg.png
# Saved DSI image V0370.jpg to /kaggle/working/larger_train_dsi_images/V0370.jpg.png
# Saved DSI image 435.jpg to /kaggle/working/larger_train_dsi_images/435.jpg.png
# Saved DSI image n0300.jpg to /kaggle/working/larger_train_dsi_images/n0300.jpg.png
# Saved DSI image g0010.jpg to /kaggle/working/larger_train_dsi_images/g0010.jpg.png
# Saved DSI image 605.jpg to /kaggle/working/larger_train_dsi_images/605.jpg.png
# Saved DSI image 101.jpg to /kaggle/working/larger_train_dsi_images/101.jpg.png
# Saved DSI image n0272.jpg to /kaggle/working/larger_train_dsi_images/n0272.jpg.png
# Saved DSI image n0178.jpg to /kaggle/working/larger_train_dsi_images/n0178.jpg.png
# Saved DSI image n0190.jpg to /kaggle/working/larger_train_dsi_images/n0190.jpg.png
# Saved DSI image 341.jpg to /kaggle/working/larger_train_dsi_images/341.jpg.png
# Saved DSI image n0135.jpg to /kaggle/working/larger_train_dsi_images/n0135.jpg.png
# Saved DSI image V0007.jpg to /kaggle/working/larger_train_dsi_images/V0007.jpg.png
# Saved DSI image 297.jpg to /kaggle/working/larger_train_dsi_images/297.jpg.png
# Saved DSI image V0130.jpg to /kaggle/working/larger_train_dsi_images/V0130.jpg.png
# Saved DSI image 599.jpg to /kaggle/working/larger_train_dsi_images/599.jpg.png
# Saved DSI image V0069.jpg to /kaggle/working/larger_train_dsi_images/V0069.jpg.png
# Saved DSI image 132.jpg to /kaggle/working/larger_train_dsi_images/132.jpg.png
# Saved DSI image n0065.jpg to /kaggle/working/larger_train_dsi_images/n0065.jpg.png
# Saved DSI image n0083.jpg to /kaggle/working/larger_train_dsi_images/n0083.jpg.png
# Saved DSI image V0076.jpg to /kaggle/working/larger_train_dsi_images/V0076.jpg.png
# Saved DSI image 325.jpg to /kaggle/working/larger_train_dsi_images/325.jpg.png
# Saved DSI image 068.jpg to /kaggle/working/larger_train_dsi_images/068.jpg.png
# Saved DSI image 071.jpg to /kaggle/working/larger_train_dsi_images/071.jpg.png
# Saved DSI image 264.jpg to /kaggle/working/larger_train_dsi_images/264.jpg.png
# Saved DSI image 616.jpg to /kaggle/working/larger_train_dsi_images/616.jpg.png
# Saved DSI image V0009.jpg to /kaggle/working/larger_train_dsi_images/V0009.jpg.png
# Saved DSI image V0271.jpg to /kaggle/working/larger_train_dsi_images/V0271.jpg.png
# Saved DSI image n0199.jpg to /kaggle/working/larger_train_dsi_images/n0199.jpg.png
# Saved DSI image 215.jpg to /kaggle/working/larger_train_dsi_images/215.jpg.png
# Saved DSI image n0014.jpg to /kaggle/working/larger_train_dsi_images/n0014.jpg.png
# Saved DSI image 291.jpg to /kaggle/working/larger_train_dsi_images/291.jpg.png
# Saved DSI image n0282.jpg to /kaggle/working/larger_train_dsi_images/n0282.jpg.png
# Saved DSI image V0090.jpg to /kaggle/working/larger_train_dsi_images/V0090.jpg.png
# Saved DSI image n0117.jpg to /kaggle/working/larger_train_dsi_images/n0117.jpg.png
# Saved DSI image V0195.jpg to /kaggle/working/larger_train_dsi_images/V0195.jpg.png
# Saved DSI image n0023.jpg to /kaggle/working/larger_train_dsi_images/n0023.jpg.png
# Saved DSI image V0346.jpg to /kaggle/working/larger_train_dsi_images/V0346.jpg.png
# Saved DSI image n0163.jpg to /kaggle/working/larger_train_dsi_images/n0163.jpg.png
# Saved DSI image g0001.jpg to /kaggle/working/larger_train_dsi_images/g0001.jpg.png
# Saved DSI image 404.jpg to /kaggle/working/larger_train_dsi_images/404.jpg.png
# Saved DSI image 098.jpg to /kaggle/working/larger_train_dsi_images/098.jpg.png
# Saved DSI image 629.jpg to /kaggle/working/larger_train_dsi_images/629.jpg.png
# Saved DSI image V0147.jpg to /kaggle/working/larger_train_dsi_images/V0147.jpg.png
# Saved DSI image g0022.jpg to /kaggle/working/larger_train_dsi_images/g0022.jpg.png
# Saved DSI image 405.jpg to /kaggle/working/larger_train_dsi_images/405.jpg.png
# Saved DSI image V0237.jpg to /kaggle/working/larger_train_dsi_images/V0237.jpg.png
# Saved DSI image V0287.jpg to /kaggle/working/larger_train_dsi_images/V0287.jpg.png
# Saved DSI image n0120.jpg to /kaggle/working/larger_train_dsi_images/n0120.jpg.png
# Saved DSI image n0313.jpg to /kaggle/working/larger_train_dsi_images/n0313.jpg.png
# Saved DSI image 388.jpg to /kaggle/working/larger_train_dsi_images/388.jpg.png
# Saved DSI image 347.jpg to /kaggle/working/larger_train_dsi_images/347.jpg.png
# Saved DSI image 597.jpg to /kaggle/working/larger_train_dsi_images/597.jpg.png
# Saved DSI image V0294.jpg to /kaggle/working/larger_train_dsi_images/V0294.jpg.png
# Saved DSI image n0229.jpg to /kaggle/working/larger_train_dsi_images/n0229.jpg.png
# Saved DSI image 434.jpg to /kaggle/working/larger_train_dsi_images/434.jpg.png
# Saved DSI image 159.jpg to /kaggle/working/larger_train_dsi_images/159.jpg.png
# Saved DSI image n0314.jpg to /kaggle/working/larger_train_dsi_images/n0314.jpg.png
# Saved DSI image V0154.jpg to /kaggle/working/larger_train_dsi_images/V0154.jpg.png
# Saved DSI image V0234.jpg to /kaggle/working/larger_train_dsi_images/V0234.jpg.png
# Saved DSI image n0059.jpg to /kaggle/working/larger_train_dsi_images/n0059.jpg.png
# Saved DSI image 603.jpg to /kaggle/working/larger_train_dsi_images/603.jpg.png
# Saved DSI image 188.jpg to /kaggle/working/larger_train_dsi_images/188.jpg.png
# Saved DSI image V0129.jpg to /kaggle/working/larger_train_dsi_images/V0129.jpg.png
# Saved DSI image 260.jpg to /kaggle/working/larger_train_dsi_images/260.jpg.png
# Saved DSI image 356.jpg to /kaggle/working/larger_train_dsi_images/356.jpg.png
# Saved DSI image 536.jpg to /kaggle/working/larger_train_dsi_images/536.jpg.png
# Saved DSI image 313.jpg to /kaggle/working/larger_train_dsi_images/313.jpg.png
# Saved DSI image n0153.jpg to /kaggle/working/larger_train_dsi_images/n0153.jpg.png
# Saved DSI image 522.jpg to /kaggle/working/larger_train_dsi_images/522.jpg.png
# Saved DSI image 408.jpg to /kaggle/working/larger_train_dsi_images/408.jpg.png
# Saved DSI image 636.jpg to /kaggle/working/larger_train_dsi_images/636.jpg.png
# Saved DSI image V0265.jpg to /kaggle/working/larger_train_dsi_images/V0265.jpg.png
# Saved DSI image 420.jpg to /kaggle/working/larger_train_dsi_images/420.jpg.png
# Saved DSI image V0316.jpg to /kaggle/working/larger_train_dsi_images/V0316.jpg.png
# Saved DSI image 035.jpg to /kaggle/working/larger_train_dsi_images/035.jpg.png
# Saved DSI image V0262.jpg to /kaggle/working/larger_train_dsi_images/V0262.jpg.png
# Saved DSI image n0150.jpg to /kaggle/working/larger_train_dsi_images/n0150.jpg.png
# Saved DSI image V0042.jpg to /kaggle/working/larger_train_dsi_images/V0042.jpg.png
# Saved DSI image V0314.jpg to /kaggle/working/larger_train_dsi_images/V0314.jpg.png
# Saved DSI image V0268.jpg to /kaggle/working/larger_train_dsi_images/V0268.jpg.png
# Saved DSI image 134.jpg to /kaggle/working/larger_train_dsi_images/134.jpg.png
# Saved DSI image 568.jpg to /kaggle/working/larger_train_dsi_images/568.jpg.png
# Saved DSI image 061.jpg to /kaggle/working/larger_train_dsi_images/061.jpg.png
# Saved DSI image V0235.jpg to /kaggle/working/larger_train_dsi_images/V0235.jpg.png
# Saved DSI image 491.jpg to /kaggle/working/larger_train_dsi_images/491.jpg.png
# Saved DSI image 251.jpg to /kaggle/working/larger_train_dsi_images/251.jpg.png
# Saved DSI image V0024.jpg to /kaggle/working/larger_train_dsi_images/V0024.jpg.png
# Saved DSI image 477.jpg to /kaggle/working/larger_train_dsi_images/477.jpg.png
# Saved DSI image n0035.jpg to /kaggle/working/larger_train_dsi_images/n0035.jpg.png
# Saved DSI image 053.jpg to /kaggle/working/larger_train_dsi_images/053.jpg.png
# Saved DSI image 140.jpg to /kaggle/working/larger_train_dsi_images/140.jpg.png
# Saved DSI image 127.jpg to /kaggle/working/larger_train_dsi_images/127.jpg.png
# Saved DSI image 270.jpg to /kaggle/working/larger_train_dsi_images/270.jpg.png
# Saved DSI image n0297.jpg to /kaggle/working/larger_train_dsi_images/n0297.jpg.png
# Saved DSI image n0092.jpg to /kaggle/working/larger_train_dsi_images/n0092.jpg.png
# Saved DSI image n0332.jpg to /kaggle/working/larger_train_dsi_images/n0332.jpg.png
# Saved DSI image g0021.jpg to /kaggle/working/larger_train_dsi_images/g0021.jpg.png
# Saved DSI image V0143.jpg to /kaggle/working/larger_train_dsi_images/V0143.jpg.png
# Saved DSI image n0206.jpg to /kaggle/working/larger_train_dsi_images/n0206.jpg.png
# Saved DSI image n0061.jpg to /kaggle/working/larger_train_dsi_images/n0061.jpg.png
# Saved DSI image 266.jpg to /kaggle/working/larger_train_dsi_images/266.jpg.png
# Saved DSI image 428.jpg to /kaggle/working/larger_train_dsi_images/428.jpg.png
# Saved DSI image g0031.jpg to /kaggle/working/larger_train_dsi_images/g0031.jpg.png
# Saved DSI image 460.jpg to /kaggle/working/larger_train_dsi_images/460.jpg.png
# Saved DSI image 226.jpg to /kaggle/working/larger_train_dsi_images/226.jpg.png
# Saved DSI image 206.jpg to /kaggle/working/larger_train_dsi_images/206.jpg.png
# Saved DSI image V0366.jpg to /kaggle/working/larger_train_dsi_images/V0366.jpg.png
# Saved DSI image 073.jpg to /kaggle/working/larger_train_dsi_images/073.jpg.png
# Saved DSI image n0213.jpg to /kaggle/working/larger_train_dsi_images/n0213.jpg.png
# Saved DSI image 519.jpg to /kaggle/working/larger_train_dsi_images/519.jpg.png
# Saved DSI image 380.jpg to /kaggle/working/larger_train_dsi_images/380.jpg.png
# Saved DSI image n0319.jpg to /kaggle/working/larger_train_dsi_images/n0319.jpg.png
# Saved DSI image V0273.jpg to /kaggle/working/larger_train_dsi_images/V0273.jpg.png
# Saved DSI image V0040.jpg to /kaggle/working/larger_train_dsi_images/V0040.jpg.png
# Saved DSI image 609.jpg to /kaggle/working/larger_train_dsi_images/609.jpg.png
# Saved DSI image V0371.jpg to /kaggle/working/larger_train_dsi_images/V0371.jpg.png
# Saved DSI image V0285.jpg to /kaggle/working/larger_train_dsi_images/V0285.jpg.png
# Saved DSI image 105.jpg to /kaggle/working/larger_train_dsi_images/105.jpg.png
# Saved DSI image 584.jpg to /kaggle/working/larger_train_dsi_images/584.jpg.png
# Saved DSI image 023.jpg to /kaggle/working/larger_train_dsi_images/023.jpg.png
# Saved DSI image 450.jpg to /kaggle/working/larger_train_dsi_images/450.jpg.png
# Saved DSI image V0272.jpg to /kaggle/working/larger_train_dsi_images/V0272.jpg.png
# Saved DSI image V0008.jpg to /kaggle/working/larger_train_dsi_images/V0008.jpg.png
# Saved DSI image 640.jpg to /kaggle/working/larger_train_dsi_images/640.jpg.png
# Saved DSI image n0323.jpg to /kaggle/working/larger_train_dsi_images/n0323.jpg.png
# Saved DSI image 643.jpg to /kaggle/working/larger_train_dsi_images/643.jpg.png
# Saved DSI image g0017.jpg to /kaggle/working/larger_train_dsi_images/g0017.jpg.png
# Saved DSI image V0396.jpg to /kaggle/working/larger_train_dsi_images/V0396.jpg.png
# Saved DSI image g0029.jpg to /kaggle/working/larger_train_dsi_images/g0029.jpg.png
# Saved DSI image 456.jpg to /kaggle/working/larger_train_dsi_images/456.jpg.png
# Saved DSI image 649.jpg to /kaggle/working/larger_train_dsi_images/649.jpg.png
# Saved DSI image n0088.jpg to /kaggle/working/larger_train_dsi_images/n0088.jpg.png
# Saved DSI image 077.jpg to /kaggle/working/larger_train_dsi_images/077.jpg.png
# Saved DSI image 395.jpg to /kaggle/working/larger_train_dsi_images/395.jpg.png
# Saved DSI image 412.jpg to /kaggle/working/larger_train_dsi_images/412.jpg.png
# Saved DSI image V0279.jpg to /kaggle/working/larger_train_dsi_images/V0279.jpg.png
# Saved DSI image 284.jpg to /kaggle/working/larger_train_dsi_images/284.jpg.png
# Saved DSI image 170.jpg to /kaggle/working/larger_train_dsi_images/170.jpg.png
# Saved DSI image 512.jpg to /kaggle/working/larger_train_dsi_images/512.jpg.png
# Saved DSI image V0288.jpg to /kaggle/working/larger_train_dsi_images/V0288.jpg.png
# Saved DSI image 498.jpg to /kaggle/working/larger_train_dsi_images/498.jpg.png
# Saved DSI image 195.jpg to /kaggle/working/larger_train_dsi_images/195.jpg.png
# Saved DSI image V0367.jpg to /kaggle/working/larger_train_dsi_images/V0367.jpg.png
# Saved DSI image 067.jpg to /kaggle/working/larger_train_dsi_images/067.jpg.png
# Saved DSI image n0085.jpg to /kaggle/working/larger_train_dsi_images/n0085.jpg.png
# Saved DSI image V0052.jpg to /kaggle/working/larger_train_dsi_images/V0052.jpg.png
# Saved DSI image n0113.jpg to /kaggle/working/larger_train_dsi_images/n0113.jpg.png
# Saved DSI image 407.jpg to /kaggle/working/larger_train_dsi_images/407.jpg.png
# Saved DSI image n0119.jpg to /kaggle/working/larger_train_dsi_images/n0119.jpg.png
# Saved DSI image 578.jpg to /kaggle/working/larger_train_dsi_images/578.jpg.png
# Saved DSI image 396.jpg to /kaggle/working/larger_train_dsi_images/396.jpg.png
# Saved DSI image 201.jpg to /kaggle/working/larger_train_dsi_images/201.jpg.png
# Saved DSI image 308.jpg to /kaggle/working/larger_train_dsi_images/308.jpg.png
# Saved DSI image V0293.jpg to /kaggle/working/larger_train_dsi_images/V0293.jpg.png
# Saved DSI image V0183.jpg to /kaggle/working/larger_train_dsi_images/V0183.jpg.png
# Saved DSI image 245.jpg to /kaggle/working/larger_train_dsi_images/245.jpg.png
# Saved DSI image 608.jpg to /kaggle/working/larger_train_dsi_images/608.jpg.png
# Saved DSI image n0311.jpg to /kaggle/working/larger_train_dsi_images/n0311.jpg.png
# Saved DSI image n0245.jpg to /kaggle/working/larger_train_dsi_images/n0245.jpg.png
# Saved DSI image n0274.jpg to /kaggle/working/larger_train_dsi_images/n0274.jpg.png
# Saved DSI image 194.jpg to /kaggle/working/larger_train_dsi_images/194.jpg.png
# Saved DSI image 184.jpg to /kaggle/working/larger_train_dsi_images/184.jpg.png
# Saved DSI image 372.jpg to /kaggle/working/larger_train_dsi_images/372.jpg.png
# Saved DSI image V0178.jpg to /kaggle/working/larger_train_dsi_images/V0178.jpg.png
# Saved DSI image 572.jpg to /kaggle/working/larger_train_dsi_images/572.jpg.png
# Saved DSI image 221.jpg to /kaggle/working/larger_train_dsi_images/221.jpg.png
# Saved DSI image n0172.jpg to /kaggle/working/larger_train_dsi_images/n0172.jpg.png
# Saved DSI image V0337.jpg to /kaggle/working/larger_train_dsi_images/V0337.jpg.png
# Saved DSI image 078.jpg to /kaggle/working/larger_train_dsi_images/078.jpg.png
# Saved DSI image 303.jpg to /kaggle/working/larger_train_dsi_images/303.jpg.png
# Saved DSI image 535.jpg to /kaggle/working/larger_train_dsi_images/535.jpg.png
# Saved DSI image V0068.jpg to /kaggle/working/larger_train_dsi_images/V0068.jpg.png
# Saved DSI image n0066.jpg to /kaggle/working/larger_train_dsi_images/n0066.jpg.png
# Saved DSI image 259.jpg to /kaggle/working/larger_train_dsi_images/259.jpg.png
# Saved DSI image V0397.jpg to /kaggle/working/larger_train_dsi_images/V0397.jpg.png
# Saved DSI image 017.jpg to /kaggle/working/larger_train_dsi_images/017.jpg.png
# Saved DSI image 049.jpg to /kaggle/working/larger_train_dsi_images/049.jpg.png
# Saved DSI image V0325.jpg to /kaggle/working/larger_train_dsi_images/V0325.jpg.png
# Saved DSI image V0049.jpg to /kaggle/working/larger_train_dsi_images/V0049.jpg.png
# Saved DSI image V0296.jpg to /kaggle/working/larger_train_dsi_images/V0296.jpg.png
# Saved DSI image V0240.jpg to /kaggle/working/larger_train_dsi_images/V0240.jpg.png
# Saved DSI image n0310.jpg to /kaggle/working/larger_train_dsi_images/n0310.jpg.png
# Saved DSI image n0015.jpg to /kaggle/working/larger_train_dsi_images/n0015.jpg.png
# Saved DSI image 163.jpg to /kaggle/working/larger_train_dsi_images/163.jpg.png
# Saved DSI image 461.jpg to /kaggle/working/larger_train_dsi_images/461.jpg.png
# Saved DSI image 592.jpg to /kaggle/working/larger_train_dsi_images/592.jpg.png
# Saved DSI image n0021.jpg to /kaggle/working/larger_train_dsi_images/n0021.jpg.png
# Saved DSI image V0233.jpg to /kaggle/working/larger_train_dsi_images/V0233.jpg.png
# Saved DSI image 196.jpg to /kaggle/working/larger_train_dsi_images/196.jpg.png
# Saved DSI image 112.jpg to /kaggle/working/larger_train_dsi_images/112.jpg.png
# Saved DSI image V0184.jpg to /kaggle/working/larger_train_dsi_images/V0184.jpg.png
# Saved DSI image 462.jpg to /kaggle/working/larger_train_dsi_images/462.jpg.png
# Saved DSI image n0076.jpg to /kaggle/working/larger_train_dsi_images/n0076.jpg.png
# Saved DSI image 024.jpg to /kaggle/working/larger_train_dsi_images/024.jpg.png
# Saved DSI image V0038.jpg to /kaggle/working/larger_train_dsi_images/V0038.jpg.png
# Saved DSI image 095.jpg to /kaggle/working/larger_train_dsi_images/095.jpg.png
# Saved DSI image 520.jpg to /kaggle/working/larger_train_dsi_images/520.jpg.png
# Saved DSI image V0378.jpg to /kaggle/working/larger_train_dsi_images/V0378.jpg.png
# Saved DSI image 515.jpg to /kaggle/working/larger_train_dsi_images/515.jpg.png
# Saved DSI image n0265.jpg to /kaggle/working/larger_train_dsi_images/n0265.jpg.png
# Saved DSI image 081.jpg to /kaggle/working/larger_train_dsi_images/081.jpg.png
# Saved DSI image g0016.jpg to /kaggle/working/larger_train_dsi_images/g0016.jpg.png
# Saved DSI image 085.jpg to /kaggle/working/larger_train_dsi_images/085.jpg.png
# Saved DSI image 494.jpg to /kaggle/working/larger_train_dsi_images/494.jpg.png
# Saved DSI image V0238.jpg to /kaggle/working/larger_train_dsi_images/V0238.jpg.png
# Saved DSI image 509.jpg to /kaggle/working/larger_train_dsi_images/509.jpg.png
# Saved DSI image 014.jpg to /kaggle/working/larger_train_dsi_images/014.jpg.png
# Saved DSI image g0025.jpg to /kaggle/working/larger_train_dsi_images/g0025.jpg.png
# Saved DSI image 331.jpg to /kaggle/working/larger_train_dsi_images/331.jpg.png
# Saved DSI image 046.jpg to /kaggle/working/larger_train_dsi_images/046.jpg.png
# Saved DSI image 339.jpg to /kaggle/working/larger_train_dsi_images/339.jpg.png
# Saved DSI image 604.jpg to /kaggle/working/larger_train_dsi_images/604.jpg.png
# Saved DSI image 169.jpg to /kaggle/working/larger_train_dsi_images/169.jpg.png
# Saved DSI image 444.jpg to /kaggle/working/larger_train_dsi_images/444.jpg.png
# Saved DSI image V0062.jpg to /kaggle/working/larger_train_dsi_images/V0062.jpg.png
# Saved DSI image V0150.jpg to /kaggle/working/larger_train_dsi_images/V0150.jpg.png
# Saved DSI image V0263.jpg to /kaggle/working/larger_train_dsi_images/V0263.jpg.png
# Saved DSI image 366.jpg to /kaggle/working/larger_train_dsi_images/366.jpg.png
# Saved DSI image 149.jpg to /kaggle/working/larger_train_dsi_images/149.jpg.png
# Saved DSI image n0320.jpg to /kaggle/working/larger_train_dsi_images/n0320.jpg.png
# Saved DSI image 165.jpg to /kaggle/working/larger_train_dsi_images/165.jpg.png
# Saved DSI image g0019.jpg to /kaggle/working/larger_train_dsi_images/g0019.jpg.png
# Saved DSI image 506.jpg to /kaggle/working/larger_train_dsi_images/506.jpg.png
# Saved DSI image 058.jpg to /kaggle/working/larger_train_dsi_images/058.jpg.png
# Saved DSI image 375.jpg to /kaggle/working/larger_train_dsi_images/375.jpg.png
# Saved DSI image V0139.jpg to /kaggle/working/larger_train_dsi_images/V0139.jpg.png
# Saved DSI image V0016.jpg to /kaggle/working/larger_train_dsi_images/V0016.jpg.png
# Saved DSI image 167.jpg to /kaggle/working/larger_train_dsi_images/167.jpg.png
# Saved DSI image 154.jpg to /kaggle/working/larger_train_dsi_images/154.jpg.png
# Saved DSI image 109.jpg to /kaggle/working/larger_train_dsi_images/109.jpg.png
# Saved DSI image 246.jpg to /kaggle/working/larger_train_dsi_images/246.jpg.png
# Saved DSI image n0047.jpg to /kaggle/working/larger_train_dsi_images/n0047.jpg.png
# Saved DSI image V0083.jpg to /kaggle/working/larger_train_dsi_images/V0083.jpg.png
# Saved DSI image 479.jpg to /kaggle/working/larger_train_dsi_images/479.jpg.png
# Saved DSI image 263.jpg to /kaggle/working/larger_train_dsi_images/263.jpg.png
# Saved DSI image V0267.jpg to /kaggle/working/larger_train_dsi_images/V0267.jpg.png
# Saved DSI image 321.jpg to /kaggle/working/larger_train_dsi_images/321.jpg.png
# Saved DSI image V0351.jpg to /kaggle/working/larger_train_dsi_images/V0351.jpg.png
# Saved DSI image 089.jpg to /kaggle/working/larger_train_dsi_images/089.jpg.png
# Saved DSI image g0012.jpg to /kaggle/working/larger_train_dsi_images/g0012.jpg.png
# Saved DSI image g0009.jpg to /kaggle/working/larger_train_dsi_images/g0009.jpg.png
# Saved DSI image n0208.jpg to /kaggle/working/larger_train_dsi_images/n0208.jpg.png
# Saved DSI image n0087.jpg to /kaggle/working/larger_train_dsi_images/n0087.jpg.png
# Saved DSI image V0258.jpg to /kaggle/working/larger_train_dsi_images/V0258.jpg.png
# Saved DSI image V0334.jpg to /kaggle/working/larger_train_dsi_images/V0334.jpg.png
# Saved DSI image 033.jpg to /kaggle/working/larger_train_dsi_images/033.jpg.png
# Saved DSI image V0202.jpg to /kaggle/working/larger_train_dsi_images/V0202.jpg.png
# Saved DSI image 508.jpg to /kaggle/working/larger_train_dsi_images/508.jpg.png
# Saved DSI image 485.jpg to /kaggle/working/larger_train_dsi_images/485.jpg.png
# Saved DSI image V0163.jpg to /kaggle/working/larger_train_dsi_images/V0163.jpg.png
# Saved DSI image 018.jpg to /kaggle/working/larger_train_dsi_images/018.jpg.png
# Saved DSI image n0281.jpg to /kaggle/working/larger_train_dsi_images/n0281.jpg.png
# Saved DSI image n0238.jpg to /kaggle/working/larger_train_dsi_images/n0238.jpg.png
# Saved DSI image V0368.jpg to /kaggle/working/larger_train_dsi_images/V0368.jpg.png
# Saved DSI image 036.jpg to /kaggle/working/larger_train_dsi_images/036.jpg.png
# Saved DSI image 538.jpg to /kaggle/working/larger_train_dsi_images/538.jpg.png
# Saved DSI image 299.jpg to /kaggle/working/larger_train_dsi_images/299.jpg.png
# Saved DSI image 027.jpg to /kaggle/working/larger_train_dsi_images/027.jpg.png
# Saved DSI image 228.jpg to /kaggle/working/larger_train_dsi_images/228.jpg.png
# Saved DSI image V0105.jpg to /kaggle/working/larger_train_dsi_images/V0105.jpg.png
# Saved DSI image V0145.jpg to /kaggle/working/larger_train_dsi_images/V0145.jpg.png
# Saved DSI image n0038.jpg to /kaggle/working/larger_train_dsi_images/n0038.jpg.png
# Saved DSI image n0151.jpg to /kaggle/working/larger_train_dsi_images/n0151.jpg.png
# Saved DSI image n0101.jpg to /kaggle/working/larger_train_dsi_images/n0101.jpg.png
# Saved DSI image V0025.jpg to /kaggle/working/larger_train_dsi_images/V0025.jpg.png
# Saved DSI image n0121.jpg to /kaggle/working/larger_train_dsi_images/n0121.jpg.png
# Saved DSI image n0334.jpg to /kaggle/working/larger_train_dsi_images/n0334.jpg.png
# Saved DSI image V0193.jpg to /kaggle/working/larger_train_dsi_images/V0193.jpg.png
# Saved DSI image g0003.jpg to /kaggle/working/larger_train_dsi_images/g0003.jpg.png
# Saved DSI image n0326.jpg to /kaggle/working/larger_train_dsi_images/n0326.jpg.png
# Saved DSI image 417.jpg to /kaggle/working/larger_train_dsi_images/417.jpg.png
# Saved DSI image 571.jpg to /kaggle/working/larger_train_dsi_images/571.jpg.png
# Saved DSI image n0010.jpg to /kaggle/working/larger_train_dsi_images/n0010.jpg.png
# Saved DSI image V0028.jpg to /kaggle/working/larger_train_dsi_images/V0028.jpg.png
# Saved DSI image 424.jpg to /kaggle/working/larger_train_dsi_images/424.jpg.png
# Saved DSI image 507.jpg to /kaggle/working/larger_train_dsi_images/507.jpg.png
# Saved DSI image 304.jpg to /kaggle/working/larger_train_dsi_images/304.jpg.png
# Saved DSI image n0073.jpg to /kaggle/working/larger_train_dsi_images/n0073.jpg.png
# Saved DSI image g0013.jpg to /kaggle/working/larger_train_dsi_images/g0013.jpg.png
# Saved DSI image 530.jpg to /kaggle/working/larger_train_dsi_images/530.jpg.png
# Saved DSI image 534.jpg to /kaggle/working/larger_train_dsi_images/534.jpg.png
# Saved DSI image V0177.jpg to /kaggle/working/larger_train_dsi_images/V0177.jpg.png
# Saved DSI image n0103.jpg to /kaggle/working/larger_train_dsi_images/n0103.jpg.png
# Saved DSI image n0096.jpg to /kaggle/working/larger_train_dsi_images/n0096.jpg.png
# Saved DSI image n0078.jpg to /kaggle/working/larger_train_dsi_images/n0078.jpg.png
# Saved DSI image n0349.jpg to /kaggle/working/larger_train_dsi_images/n0349.jpg.png
# Saved DSI image 273.jpg to /kaggle/working/larger_train_dsi_images/273.jpg.png
# Saved DSI image n0195.jpg to /kaggle/working/larger_train_dsi_images/n0195.jpg.png
# Saved DSI image 276.jpg to /kaggle/working/larger_train_dsi_images/276.jpg.png
# Saved DSI image V0192.jpg to /kaggle/working/larger_train_dsi_images/V0192.jpg.png
# Saved DSI image 628.jpg to /kaggle/working/larger_train_dsi_images/628.jpg.png
# Saved DSI image 268.jpg to /kaggle/working/larger_train_dsi_images/268.jpg.png
# Saved DSI image 204.jpg to /kaggle/working/larger_train_dsi_images/204.jpg.png
# Saved DSI image n0159.jpg to /kaggle/working/larger_train_dsi_images/n0159.jpg.png
# Saved DSI image 249.jpg to /kaggle/working/larger_train_dsi_images/249.jpg.png
# Saved DSI image 103.jpg to /kaggle/working/larger_train_dsi_images/103.jpg.png
# Saved DSI image 624.jpg to /kaggle/working/larger_train_dsi_images/624.jpg.png
# Saved DSI image 574.jpg to /kaggle/working/larger_train_dsi_images/574.jpg.png
# Saved DSI image 203.jpg to /kaggle/working/larger_train_dsi_images/203.jpg.png
# Saved DSI image V0369.jpg to /kaggle/working/larger_train_dsi_images/V0369.jpg.png
# Saved DSI image V0336.jpg to /kaggle/working/larger_train_dsi_images/V0336.jpg.png
# Saved DSI image V0345.jpg to /kaggle/working/larger_train_dsi_images/V0345.jpg.png
# Saved DSI image 272.jpg to /kaggle/working/larger_train_dsi_images/272.jpg.png
# Saved DSI image V0074.jpg to /kaggle/working/larger_train_dsi_images/V0074.jpg.png
# Saved DSI image V0142.jpg to /kaggle/working/larger_train_dsi_images/V0142.jpg.png
# Saved DSI image 416.jpg to /kaggle/working/larger_train_dsi_images/416.jpg.png
# Saved DSI image n0020.jpg to /kaggle/working/larger_train_dsi_images/n0020.jpg.png
# Saved DSI image V0308.jpg to /kaggle/working/larger_train_dsi_images/V0308.jpg.png
# Saved DSI image V0329.jpg to /kaggle/working/larger_train_dsi_images/V0329.jpg.png
# Saved DSI image 290.jpg to /kaggle/working/larger_train_dsi_images/290.jpg.png
# Saved DSI image 486.jpg to /kaggle/working/larger_train_dsi_images/486.jpg.png
# Saved DSI image 229.jpg to /kaggle/working/larger_train_dsi_images/229.jpg.png
# Saved DSI image 318.jpg to /kaggle/working/larger_train_dsi_images/318.jpg.png
# Saved DSI image V0086.jpg to /kaggle/working/larger_train_dsi_images/V0086.jpg.png
# Saved DSI image V0319.jpg to /kaggle/working/larger_train_dsi_images/V0319.jpg.png
# Saved DSI image n0161.jpg to /kaggle/working/larger_train_dsi_images/n0161.jpg.png
# Saved DSI image n0040.jpg to /kaggle/working/larger_train_dsi_images/n0040.jpg.png
# Saved DSI image V0214.jpg to /kaggle/working/larger_train_dsi_images/V0214.jpg.png
# Saved DSI image 210.jpg to /kaggle/working/larger_train_dsi_images/210.jpg.png
# Saved DSI image n0247.jpg to /kaggle/working/larger_train_dsi_images/n0247.jpg.png
# Saved DSI image 532.jpg to /kaggle/working/larger_train_dsi_images/532.jpg.png
# Saved DSI image 220.jpg to /kaggle/working/larger_train_dsi_images/220.jpg.png
# Saved DSI image 114.jpg to /kaggle/working/larger_train_dsi_images/114.jpg.png
# Saved DSI image V0162.jpg to /kaggle/working/larger_train_dsi_images/V0162.jpg.png
# Saved DSI image n0019.jpg to /kaggle/working/larger_train_dsi_images/n0019.jpg.png
# Saved DSI image 546.jpg to /kaggle/working/larger_train_dsi_images/546.jpg.png
# Saved DSI image 261.jpg to /kaggle/working/larger_train_dsi_images/261.jpg.png
# Saved DSI image V0109.jpg to /kaggle/working/larger_train_dsi_images/V0109.jpg.png
# Saved DSI image 521.jpg to /kaggle/working/larger_train_dsi_images/521.jpg.png
# Saved DSI image V0207.jpg to /kaggle/working/larger_train_dsi_images/V0207.jpg.png
# Saved DSI image V0101.jpg to /kaggle/working/larger_train_dsi_images/V0101.jpg.png
# Saved DSI image V0010.jpg to /kaggle/working/larger_train_dsi_images/V0010.jpg.png
# Saved DSI image 090.jpg to /kaggle/working/larger_train_dsi_images/090.jpg.png
# Saved DSI image 627.jpg to /kaggle/working/larger_train_dsi_images/627.jpg.png
# Saved DSI image V0400.jpg to /kaggle/working/larger_train_dsi_images/V0400.jpg.png
# Saved DSI image n0201.jpg to /kaggle/working/larger_train_dsi_images/n0201.jpg.png
# Saved DSI image 471.jpg to /kaggle/working/larger_train_dsi_images/471.jpg.png
# Saved DSI image n0305.jpg to /kaggle/working/larger_train_dsi_images/n0305.jpg.png
# Saved DSI image n0024.jpg to /kaggle/working/larger_train_dsi_images/n0024.jpg.png
# Saved DSI image V0182.jpg to /kaggle/working/larger_train_dsi_images/V0182.jpg.png
# Saved DSI image V0120.jpg to /kaggle/working/larger_train_dsi_images/V0120.jpg.png
# Saved DSI image 190.jpg to /kaggle/working/larger_train_dsi_images/190.jpg.png
# Saved DSI image 497.jpg to /kaggle/working/larger_train_dsi_images/497.jpg.png
# Saved DSI image 575.jpg to /kaggle/working/larger_train_dsi_images/575.jpg.png
# Saved DSI image n0207.jpg to /kaggle/working/larger_train_dsi_images/n0207.jpg.png
# Saved DSI image 398.jpg to /kaggle/working/larger_train_dsi_images/398.jpg.png
# Saved DSI image n0125.jpg to /kaggle/working/larger_train_dsi_images/n0125.jpg.png
# Saved DSI image n0211.jpg to /kaggle/working/larger_train_dsi_images/n0211.jpg.png
# Saved DSI image n0259.jpg to /kaggle/working/larger_train_dsi_images/n0259.jpg.png
# Saved DSI image g0033.jpg to /kaggle/working/larger_train_dsi_images/g0033.jpg.png
# Saved DSI image 208.jpg to /kaggle/working/larger_train_dsi_images/208.jpg.png
# Saved DSI image n0360.jpg to /kaggle/working/larger_train_dsi_images/n0360.jpg.png
# Saved DSI image n0248.jpg to /kaggle/working/larger_train_dsi_images/n0248.jpg.png
# Saved DSI image 207.jpg to /kaggle/working/larger_train_dsi_images/207.jpg.png
# Saved DSI image n0285.jpg to /kaggle/working/larger_train_dsi_images/n0285.jpg.png
# Saved DSI image n0217.jpg to /kaggle/working/larger_train_dsi_images/n0217.jpg.png
# Saved DSI image 115.jpg to /kaggle/working/larger_train_dsi_images/115.jpg.png
# Saved DSI image 285.jpg to /kaggle/working/larger_train_dsi_images/285.jpg.png
# Saved DSI image V0292.jpg to /kaggle/working/larger_train_dsi_images/V0292.jpg.png
# Saved DSI image n0331.jpg to /kaggle/working/larger_train_dsi_images/n0331.jpg.png
# Saved DSI image 615.jpg to /kaggle/working/larger_train_dsi_images/615.jpg.png
# Saved DSI image n0079.jpg to /kaggle/working/larger_train_dsi_images/n0079.jpg.png
# Saved DSI image 527.jpg to /kaggle/working/larger_train_dsi_images/527.jpg.png
# Saved DSI image V0035.jpg to /kaggle/working/larger_train_dsi_images/V0035.jpg.png
# Saved DSI image n0212.jpg to /kaggle/working/larger_train_dsi_images/n0212.jpg.png
# Saved DSI image n0094.jpg to /kaggle/working/larger_train_dsi_images/n0094.jpg.png
# Saved DSI image n0312.jpg to /kaggle/working/larger_train_dsi_images/n0312.jpg.png
# Saved DSI image V0012.jpg to /kaggle/working/larger_train_dsi_images/V0012.jpg.png
# Saved DSI image 082.jpg to /kaggle/working/larger_train_dsi_images/082.jpg.png
# Saved DSI image 441.jpg to /kaggle/working/larger_train_dsi_images/441.jpg.png
# Saved DSI image V0185.jpg to /kaggle/working/larger_train_dsi_images/V0185.jpg.png
# Saved DSI image 075.jpg to /kaggle/working/larger_train_dsi_images/075.jpg.png
# Saved DSI image 326.jpg to /kaggle/working/larger_train_dsi_images/326.jpg.png
# Saved DSI image V0393.jpg to /kaggle/working/larger_train_dsi_images/V0393.jpg.png
# Saved DSI image 448.jpg to /kaggle/working/larger_train_dsi_images/448.jpg.png
# Saved DSI image n0215.jpg to /kaggle/working/larger_train_dsi_images/n0215.jpg.png
# Saved DSI image 647.jpg to /kaggle/working/larger_train_dsi_images/647.jpg.png
# Saved DSI image V0057.jpg to /kaggle/working/larger_train_dsi_images/V0057.jpg.png
# Saved DSI image 585.jpg to /kaggle/working/larger_train_dsi_images/585.jpg.png
# Saved DSI image 202.jpg to /kaggle/working/larger_train_dsi_images/202.jpg.png
# Saved DSI image 387.jpg to /kaggle/working/larger_train_dsi_images/387.jpg.png
# Saved DSI image 142.jpg to /kaggle/working/larger_train_dsi_images/142.jpg.png
# Saved DSI image V0022.jpg to /kaggle/working/larger_train_dsi_images/V0022.jpg.png
# Saved DSI image 309.jpg to /kaggle/working/larger_train_dsi_images/309.jpg.png
# Saved DSI image 097.jpg to /kaggle/working/larger_train_dsi_images/097.jpg.png
# Saved DSI image n0011.jpg to /kaggle/working/larger_train_dsi_images/n0011.jpg.png
# Saved DSI image 463.jpg to /kaggle/working/larger_train_dsi_images/463.jpg.png
# Saved DSI image n0357.jpg to /kaggle/working/larger_train_dsi_images/n0357.jpg.png
# Saved DSI image 334.jpg to /kaggle/working/larger_train_dsi_images/334.jpg.png
# Saved DSI image 531.jpg to /kaggle/working/larger_train_dsi_images/531.jpg.png
# Saved DSI image 433.jpg to /kaggle/working/larger_train_dsi_images/433.jpg.png
# Saved DSI image 614.jpg to /kaggle/working/larger_train_dsi_images/614.jpg.png
# Saved DSI image 317.jpg to /kaggle/working/larger_train_dsi_images/317.jpg.png
# Saved DSI image V0395.jpg to /kaggle/working/larger_train_dsi_images/V0395.jpg.png
# Saved DSI image n0316.jpg to /kaggle/working/larger_train_dsi_images/n0316.jpg.png
# Saved DSI image 552.jpg to /kaggle/working/larger_train_dsi_images/552.jpg.png
# Saved DSI image 496.jpg to /kaggle/working/larger_train_dsi_images/496.jpg.png
# Saved DSI image 186.jpg to /kaggle/working/larger_train_dsi_images/186.jpg.png
# Saved DSI image n0032.jpg to /kaggle/working/larger_train_dsi_images/n0032.jpg.png
# Saved DSI image V0029.jpg to /kaggle/working/larger_train_dsi_images/V0029.jpg.png
# Saved DSI image V0050.jpg to /kaggle/working/larger_train_dsi_images/V0050.jpg.png
# Saved DSI image 548.jpg to /kaggle/working/larger_train_dsi_images/548.jpg.png
# Saved DSI image V0341.jpg to /kaggle/working/larger_train_dsi_images/V0341.jpg.png
# Saved DSI image 346.jpg to /kaggle/working/larger_train_dsi_images/346.jpg.png
# Saved DSI image 315.jpg to /kaggle/working/larger_train_dsi_images/315.jpg.png
# Saved DSI image 065.jpg to /kaggle/working/larger_train_dsi_images/065.jpg.png
# Saved DSI image n0050.jpg to /kaggle/working/larger_train_dsi_images/n0050.jpg.png
# Saved DSI image V0123.jpg to /kaggle/working/larger_train_dsi_images/V0123.jpg.png
# Saved DSI image n0145.jpg to /kaggle/working/larger_train_dsi_images/n0145.jpg.png
# Saved DSI image V0343.jpg to /kaggle/working/larger_train_dsi_images/V0343.jpg.png
# Saved DSI image V0290.jpg to /kaggle/working/larger_train_dsi_images/V0290.jpg.png
# Saved DSI image 563.jpg to /kaggle/working/larger_train_dsi_images/563.jpg.png
# Saved DSI image n0261.jpg to /kaggle/working/larger_train_dsi_images/n0261.jpg.png
# Saved DSI image 419.jpg to /kaggle/working/larger_train_dsi_images/419.jpg.png
# Saved DSI image n0004.jpg to /kaggle/working/larger_train_dsi_images/n0004.jpg.png
# Saved DSI image V0172.jpg to /kaggle/working/larger_train_dsi_images/V0172.jpg.png
# Saved DSI image V0180.jpg to /kaggle/working/larger_train_dsi_images/V0180.jpg.png
# Saved DSI image n0292.jpg to /kaggle/working/larger_train_dsi_images/n0292.jpg.png
# Saved DSI image V0127.jpg to /kaggle/working/larger_train_dsi_images/V0127.jpg.png
# Saved DSI image n0053.jpg to /kaggle/working/larger_train_dsi_images/n0053.jpg.png
# Saved DSI image 106.jpg to /kaggle/working/larger_train_dsi_images/106.jpg.png
# Saved DSI image n0105.jpg to /kaggle/working/larger_train_dsi_images/n0105.jpg.png
# Saved DSI image 262.jpg to /kaggle/working/larger_train_dsi_images/262.jpg.png
# Saved DSI image 342.jpg to /kaggle/working/larger_train_dsi_images/342.jpg.png
# Saved DSI image 252.jpg to /kaggle/working/larger_train_dsi_images/252.jpg.png
# Saved DSI image 565.jpg to /kaggle/working/larger_train_dsi_images/565.jpg.png
# Saved DSI image 062.jpg to /kaggle/working/larger_train_dsi_images/062.jpg.png
# Saved DSI image n0056.jpg to /kaggle/working/larger_train_dsi_images/n0056.jpg.png
# Saved DSI image 365.jpg to /kaggle/working/larger_train_dsi_images/365.jpg.png
# Saved DSI image 475.jpg to /kaggle/working/larger_train_dsi_images/475.jpg.png
# Saved DSI image V0254.jpg to /kaggle/working/larger_train_dsi_images/V0254.jpg.png
# Saved DSI image 361.jpg to /kaggle/working/larger_train_dsi_images/361.jpg.png
# Saved DSI image V0270.jpg to /kaggle/working/larger_train_dsi_images/V0270.jpg.png
# Saved DSI image 580.jpg to /kaggle/working/larger_train_dsi_images/580.jpg.png
# Saved DSI image 327.jpg to /kaggle/working/larger_train_dsi_images/327.jpg.png
# Saved DSI image V0384.jpg to /kaggle/working/larger_train_dsi_images/V0384.jpg.png
# Saved DSI image 487.jpg to /kaggle/working/larger_train_dsi_images/487.jpg.png
# Saved DSI image 113.jpg to /kaggle/working/larger_train_dsi_images/113.jpg.png
# Saved DSI image 193.jpg to /kaggle/working/larger_train_dsi_images/193.jpg.png
# Saved DSI image n0177.jpg to /kaggle/working/larger_train_dsi_images/n0177.jpg.png
# Saved DSI image 490.jpg to /kaggle/working/larger_train_dsi_images/490.jpg.png
# Saved DSI image V0051.jpg to /kaggle/working/larger_train_dsi_images/V0051.jpg.png
# Saved DSI image n0157.jpg to /kaggle/working/larger_train_dsi_images/n0157.jpg.png
# Saved DSI image 096.jpg to /kaggle/working/larger_train_dsi_images/096.jpg.png
# Saved DSI image n0115.jpg to /kaggle/working/larger_train_dsi_images/n0115.jpg.png
# Saved DSI image n0034.jpg to /kaggle/working/larger_train_dsi_images/n0034.jpg.png
# Saved DSI image 473.jpg to /kaggle/working/larger_train_dsi_images/473.jpg.png
# Saved DSI image 607.jpg to /kaggle/working/larger_train_dsi_images/607.jpg.png
# Saved DSI image V0149.jpg to /kaggle/working/larger_train_dsi_images/V0149.jpg.png
# Saved DSI image 459.jpg to /kaggle/working/larger_train_dsi_images/459.jpg.png
# Saved DSI image V0056.jpg to /kaggle/working/larger_train_dsi_images/V0056.jpg.png
# Saved DSI image 611.jpg to /kaggle/working/larger_train_dsi_images/611.jpg.png
# Saved DSI image V0075.jpg to /kaggle/working/larger_train_dsi_images/V0075.jpg.png
# Saved DSI image g0005.jpg to /kaggle/working/larger_train_dsi_images/g0005.jpg.png
# Saved DSI image n0251.jpg to /kaggle/working/larger_train_dsi_images/n0251.jpg.png
# Saved DSI image 175.jpg to /kaggle/working/larger_train_dsi_images/175.jpg.png
# Saved DSI image V0161.jpg to /kaggle/working/larger_train_dsi_images/V0161.jpg.png
# Saved DSI image n0142.jpg to /kaggle/working/larger_train_dsi_images/n0142.jpg.png
# Saved DSI image n0055.jpg to /kaggle/working/larger_train_dsi_images/n0055.jpg.png
# Saved DSI image 182.jpg to /kaggle/working/larger_train_dsi_images/182.jpg.png
# Saved DSI image n0289.jpg to /kaggle/working/larger_train_dsi_images/n0289.jpg.png
# Saved DSI image 622.jpg to /kaggle/working/larger_train_dsi_images/622.jpg.png
# Saved DSI image n0134.jpg to /kaggle/working/larger_train_dsi_images/n0134.jpg.png
# Saved DSI image n0048.jpg to /kaggle/working/larger_train_dsi_images/n0048.jpg.png
# Saved DSI image n0344.jpg to /kaggle/working/larger_train_dsi_images/n0344.jpg.png
# Saved DSI image V0249.jpg to /kaggle/working/larger_train_dsi_images/V0249.jpg.png
# Saved DSI image n0107.jpg to /kaggle/working/larger_train_dsi_images/n0107.jpg.png
# Saved DSI image n0270.jpg to /kaggle/working/larger_train_dsi_images/n0270.jpg.png
# Saved DSI image V0390.jpg to /kaggle/working/larger_train_dsi_images/V0390.jpg.png
# Saved DSI image V0348.jpg to /kaggle/working/larger_train_dsi_images/V0348.jpg.png
# Saved DSI image g0014.jpg to /kaggle/working/larger_train_dsi_images/g0014.jpg.png
# Saved DSI image V0243.jpg to /kaggle/working/larger_train_dsi_images/V0243.jpg.png
# Saved DSI image V0304.jpg to /kaggle/working/larger_train_dsi_images/V0304.jpg.png
# Saved DSI image V0374.jpg to /kaggle/working/larger_train_dsi_images/V0374.jpg.png
# ...
# Saved DSI image T0178.jpg to /kaggle/working/larger_val_dsi_images/T0178.jpg.png
# Saved DSI image T0046.jpg to /kaggle/working/larger_val_dsi_images/T0046.jpg.png
# Saved DSI image T0202.jpg to /kaggle/working/larger_val_dsi_images/T0202.jpg.png
# Saved DSI image T0083.jpg to /kaggle/working/larger_val_dsi_images/T0083.jpg.png
# Saved DSI image T0112.jpg to /kaggle/working/larger_val_dsi_images/T0112.jpg.png
# Saved DSI image T0274.jpg to /kaggle/working/larger_val_dsi_images/T0274.jpg.png
# Saved DSI image T0017.jpg to /kaggle/working/larger_val_dsi_images/T0017.jpg.png
# Saved DSI image T0358.jpg to /kaggle/working/larger_val_dsi_images/T0358.jpg.png
# Saved DSI image T0254.jpg to /kaggle/working/larger_val_dsi_images/T0254.jpg.png
# Saved DSI image T0073.jpg to /kaggle/working/larger_val_dsi_images/T0073.jpg.png
# Saved DSI image T0133.jpg to /kaggle/working/larger_val_dsi_images/T0133.jpg.png
# Saved DSI image T0006.jpg to /kaggle/working/larger_val_dsi_images/T0006.jpg.png
# Saved DSI image T0034.jpg to /kaggle/working/larger_val_dsi_images/T0034.jpg.png
# Saved DSI image T0348.jpg to /kaggle/working/larger_val_dsi_images/T0348.jpg.png
# Saved DSI image T0229.jpg to /kaggle/working/larger_val_dsi_images/T0229.jpg.png
# Saved DSI image T0337.jpg to /kaggle/working/larger_val_dsi_images/T0337.jpg.png
# Saved DSI image T0128.jpg to /kaggle/working/larger_val_dsi_images/T0128.jpg.png
# Saved DSI image T0335.jpg to /kaggle/working/larger_val_dsi_images/T0335.jpg.png
# Saved DSI image T0328.jpg to /kaggle/working/larger_val_dsi_images/T0328.jpg.png
# Saved DSI image T0010.jpg to /kaggle/working/larger_val_dsi_images/T0010.jpg.png
# Saved DSI image T0161.jpg to /kaggle/working/larger_val_dsi_images/T0161.jpg.png
# Saved DSI image T0305.jpg to /kaggle/working/larger_val_dsi_images/T0305.jpg.png
# Saved DSI image T0160.jpg to /kaggle/working/larger_val_dsi_images/T0160.jpg.png
# Saved DSI image T0155.jpg to /kaggle/working/larger_val_dsi_images/T0155.jpg.png
# Saved DSI image T0129.jpg to /kaggle/working/larger_val_dsi_images/T0129.jpg.png
# Saved DSI image T0089.jpg to /kaggle/working/larger_val_dsi_images/T0089.jpg.png
# Saved DSI image T0346.jpg to /kaggle/working/larger_val_dsi_images/T0346.jpg.png
# Saved DSI image T0228.jpg to /kaggle/working/larger_val_dsi_images/T0228.jpg.png
# Saved DSI image T0146.jpg to /kaggle/working/larger_val_dsi_images/T0146.jpg.png
# Saved DSI image T0018.jpg to /kaggle/working/larger_val_dsi_images/T0018.jpg.png
# Saved DSI image T0339.jpg to /kaggle/working/larger_val_dsi_images/T0339.jpg.png
# Saved DSI image T0366.jpg to /kaggle/working/larger_val_dsi_images/T0366.jpg.png
# Saved DSI image T0386.jpg to /kaggle/working/larger_val_dsi_images/T0386.jpg.png
# Saved DSI image T0315.jpg to /kaggle/working/larger_val_dsi_images/T0315.jpg.png
# Saved DSI image T0110.jpg to /kaggle/working/larger_val_dsi_images/T0110.jpg.png
# Saved DSI image T0111.jpg to /kaggle/working/larger_val_dsi_images/T0111.jpg.png
# Saved DSI image T0091.jpg to /kaggle/working/larger_val_dsi_images/T0091.jpg.png
# Saved DSI image T0188.jpg to /kaggle/working/larger_val_dsi_images/T0188.jpg.png
# Saved DSI image T0252.jpg to /kaggle/working/larger_val_dsi_images/T0252.jpg.png
# Saved DSI image T0311.jpg to /kaggle/working/larger_val_dsi_images/T0311.jpg.png
# Saved DSI image T0304.jpg to /kaggle/working/larger_val_dsi_images/T0304.jpg.png
# Saved DSI image T0109.jpg to /kaggle/working/larger_val_dsi_images/T0109.jpg.png
# Saved DSI image T0077.jpg to /kaggle/working/larger_val_dsi_images/T0077.jpg.png
# Saved DSI image T0259.jpg to /kaggle/working/larger_val_dsi_images/T0259.jpg.png
# Saved DSI image T0106.jpg to /kaggle/working/larger_val_dsi_images/T0106.jpg.png
# Saved DSI image T0199.jpg to /kaggle/working/larger_val_dsi_images/T0199.jpg.png
# Saved DSI image T0023.jpg to /kaggle/working/larger_val_dsi_images/T0023.jpg.png
# Saved DSI image T0038.jpg to /kaggle/working/larger_val_dsi_images/T0038.jpg.png
# Saved DSI image T0295.jpg to /kaggle/working/larger_val_dsi_images/T0295.jpg.png
# Saved DSI image T0005.jpg to /kaggle/working/larger_val_dsi_images/T0005.jpg.png
# Saved DSI image T0244.jpg to /kaggle/working/larger_val_dsi_images/T0244.jpg.png
# Saved DSI image T0322.jpg to /kaggle/working/larger_val_dsi_images/T0322.jpg.png
# Saved DSI image T0287.jpg to /kaggle/working/larger_val_dsi_images/T0287.jpg.png
# Saved DSI image T0282.jpg to /kaggle/working/larger_val_dsi_images/T0282.jpg.png
# Saved DSI image T0082.jpg to /kaggle/working/larger_val_dsi_images/T0082.jpg.png
# Saved DSI image T0140.jpg to /kaggle/working/larger_val_dsi_images/T0140.jpg.png
# Saved DSI image T0265.jpg to /kaggle/working/larger_val_dsi_images/T0265.jpg.png
# Saved DSI image T0243.jpg to /kaggle/working/larger_val_dsi_images/T0243.jpg.png
# Saved DSI image T0134.jpg to /kaggle/working/larger_val_dsi_images/T0134.jpg.png
# Saved DSI image T0318.jpg to /kaggle/working/larger_val_dsi_images/T0318.jpg.png
# Saved DSI image T0372.jpg to /kaggle/working/larger_val_dsi_images/T0372.jpg.png
# Saved DSI image T0078.jpg to /kaggle/working/larger_val_dsi_images/T0078.jpg.png
# Saved DSI image T0144.jpg to /kaggle/working/larger_val_dsi_images/T0144.jpg.png
# Saved DSI image T0321.jpg to /kaggle/working/larger_val_dsi_images/T0321.jpg.png
# Saved DSI image T0054.jpg to /kaggle/working/larger_val_dsi_images/T0054.jpg.png
# Saved DSI image T0317.jpg to /kaggle/working/larger_val_dsi_images/T0317.jpg.png
# Saved DSI image T0336.jpg to /kaggle/working/larger_val_dsi_images/T0336.jpg.png
# Saved DSI image T0032.jpg to /kaggle/working/larger_val_dsi_images/T0032.jpg.png
# Saved DSI image T0234.jpg to /kaggle/working/larger_val_dsi_images/T0234.jpg.png
# Saved DSI image T0277.jpg to /kaggle/working/larger_val_dsi_images/T0277.jpg.png
# Saved DSI image T0281.jpg to /kaggle/working/larger_val_dsi_images/T0281.jpg.png
# Saved DSI image T0060.jpg to /kaggle/working/larger_val_dsi_images/T0060.jpg.png
# Saved DSI image T0388.jpg to /kaggle/working/larger_val_dsi_images/T0388.jpg.png
# Saved DSI image T0001.jpg to /kaggle/working/larger_val_dsi_images/T0001.jpg.png
# Saved DSI image T0062.jpg to /kaggle/working/larger_val_dsi_images/T0062.jpg.png
# Saved DSI image T0127.jpg to /kaggle/working/larger_val_dsi_images/T0127.jpg.png
# Saved DSI image T0137.jpg to /kaggle/working/larger_val_dsi_images/T0137.jpg.png
# Saved DSI image T0093.jpg to /kaggle/working/larger_val_dsi_images/T0093.jpg.png
# Saved DSI image T0231.jpg to /kaggle/working/larger_val_dsi_images/T0231.jpg.png
# Saved DSI image T0343.jpg to /kaggle/working/larger_val_dsi_images/T0343.jpg.png
# Saved DSI image T0176.jpg to /kaggle/working/larger_val_dsi_images/T0176.jpg.png
# Saved DSI image T0216.jpg to /kaggle/working/larger_val_dsi_images/T0216.jpg.png
# Saved DSI image T0225.jpg to /kaggle/working/larger_val_dsi_images/T0225.jpg.png
# Saved DSI image T0269.jpg to /kaggle/working/larger_val_dsi_images/T0269.jpg.png
# Saved DSI image T0236.jpg to /kaggle/working/larger_val_dsi_images/T0236.jpg.png
# Saved DSI image T0396.jpg to /kaggle/working/larger_val_dsi_images/T0396.jpg.png
# Saved DSI image T0356.jpg to /kaggle/working/larger_val_dsi_images/T0356.jpg.png
# Saved DSI image T0097.jpg to /kaggle/working/larger_val_dsi_images/T0097.jpg.png
# Saved DSI image T0279.jpg to /kaggle/working/larger_val_dsi_images/T0279.jpg.png
# Saved DSI image T0338.jpg to /kaggle/working/larger_val_dsi_images/T0338.jpg.png
# Saved DSI image T0059.jpg to /kaggle/working/larger_val_dsi_images/T0059.jpg.png
# Saved DSI image T0319.jpg to /kaggle/working/larger_val_dsi_images/T0319.jpg.png
# Saved DSI image T0051.jpg to /kaggle/working/larger_val_dsi_images/T0051.jpg.png
# Saved DSI image T0072.jpg to /kaggle/working/larger_val_dsi_images/T0072.jpg.png
# Saved DSI image T0120.jpg to /kaggle/working/larger_val_dsi_images/T0120.jpg.png
# Saved DSI image T0329.jpg to /kaggle/working/larger_val_dsi_images/T0329.jpg.png
# Saved DSI image T0253.jpg to /kaggle/working/larger_val_dsi_images/T0253.jpg.png
# Saved DSI image T0118.jpg to /kaggle/working/larger_val_dsi_images/T0118.jpg.png
# Saved DSI image T0163.jpg to /kaggle/working/larger_val_dsi_images/T0163.jpg.png
# Saved DSI image T0224.jpg to /kaggle/working/larger_val_dsi_images/T0224.jpg.png
# Saved DSI image T0326.jpg to /kaggle/working/larger_val_dsi_images/T0326.jpg.png
# Saved DSI image T0027.jpg to /kaggle/working/larger_val_dsi_images/T0027.jpg.png
# Saved DSI image T0122.jpg to /kaggle/working/larger_val_dsi_images/T0122.jpg.png
# Saved DSI image T0211.jpg to /kaggle/working/larger_val_dsi_images/T0211.jpg.png
# Saved DSI image T0292.jpg to /kaggle/working/larger_val_dsi_images/T0292.jpg.png
# Saved DSI image T0184.jpg to /kaggle/working/larger_val_dsi_images/T0184.jpg.png
# Saved DSI image T0314.jpg to /kaggle/working/larger_val_dsi_images/T0314.jpg.png
# Saved DSI image T0359.jpg to /kaggle/working/larger_val_dsi_images/T0359.jpg.png
# Saved DSI image T0094.jpg to /kaggle/working/larger_val_dsi_images/T0094.jpg.png
# Saved DSI image T0384.jpg to /kaggle/working/larger_val_dsi_images/T0384.jpg.png
# Saved DSI image T0389.jpg to /kaggle/working/larger_val_dsi_images/T0389.jpg.png
# Saved DSI image T0276.jpg to /kaggle/working/larger_val_dsi_images/T0276.jpg.png
# Saved DSI image T0201.jpg to /kaggle/working/larger_val_dsi_images/T0201.jpg.png
# Saved DSI image T0139.jpg to /kaggle/working/larger_val_dsi_images/T0139.jpg.png
# Saved DSI image T0312.jpg to /kaggle/working/larger_val_dsi_images/T0312.jpg.png
# Saved DSI image T0286.jpg to /kaggle/working/larger_val_dsi_images/T0286.jpg.png
# Saved DSI image T0262.jpg to /kaggle/working/larger_val_dsi_images/T0262.jpg.png
# Saved DSI image T0239.jpg to /kaggle/working/larger_val_dsi_images/T0239.jpg.png
# Saved DSI image T0200.jpg to /kaggle/working/larger_val_dsi_images/T0200.jpg.png
# Saved DSI image T0020.jpg to /kaggle/working/larger_val_dsi_images/T0020.jpg.png
# Saved DSI image T0206.jpg to /kaggle/working/larger_val_dsi_images/T0206.jpg.png
# Saved DSI image T0351.jpg to /kaggle/working/larger_val_dsi_images/T0351.jpg.png
# Saved DSI image T0208.jpg to /kaggle/working/larger_val_dsi_images/T0208.jpg.png
# Saved DSI image T0099.jpg to /kaggle/working/larger_val_dsi_images/T0099.jpg.png
# Saved DSI image T0102.jpg to /kaggle/working/larger_val_dsi_images/T0102.jpg.png
# Saved DSI image T0152.jpg to /kaggle/working/larger_val_dsi_images/T0152.jpg.png
# Saved DSI image T0147.jpg to /kaggle/working/larger_val_dsi_images/T0147.jpg.png
# Saved DSI image T0290.jpg to /kaggle/working/larger_val_dsi_images/T0290.jpg.png
# Saved DSI image T0280.jpg to /kaggle/working/larger_val_dsi_images/T0280.jpg.png
# Saved DSI image T0210.jpg to /kaggle/working/larger_val_dsi_images/T0210.jpg.png
# Saved DSI image T0024.jpg to /kaggle/working/larger_val_dsi_images/T0024.jpg.png
# Saved DSI image T0197.jpg to /kaggle/working/larger_val_dsi_images/T0197.jpg.png
# Saved DSI image T0085.jpg to /kaggle/working/larger_val_dsi_images/T0085.jpg.png
# Saved DSI image T0049.jpg to /kaggle/working/larger_val_dsi_images/T0049.jpg.png
# Saved DSI image T0040.jpg to /kaggle/working/larger_val_dsi_images/T0040.jpg.png
# Saved DSI image T0123.jpg to /kaggle/working/larger_val_dsi_images/T0123.jpg.png
# Saved DSI image T0270.jpg to /kaggle/working/larger_val_dsi_images/T0270.jpg.png
# Saved DSI image T0371.jpg to /kaggle/working/larger_val_dsi_images/T0371.jpg.png
# Saved DSI image T0368.jpg to /kaggle/working/larger_val_dsi_images/T0368.jpg.png
# Saved DSI image T0114.jpg to /kaggle/working/larger_val_dsi_images/T0114.jpg.png
# Saved DSI image T0367.jpg to /kaggle/working/larger_val_dsi_images/T0367.jpg.png
# Saved DSI image T0009.jpg to /kaggle/working/larger_val_dsi_images/T0009.jpg.png
# Saved DSI image T0345.jpg to /kaggle/working/larger_val_dsi_images/T0345.jpg.png
# Saved DSI image T0029.jpg to /kaggle/working/larger_val_dsi_images/T0029.jpg.png
# Saved DSI image T0063.jpg to /kaggle/working/larger_val_dsi_images/T0063.jpg.png
# Saved DSI image T0092.jpg to /kaggle/working/larger_val_dsi_images/T0092.jpg.png
# Saved DSI image T0385.jpg to /kaggle/working/larger_val_dsi_images/T0385.jpg.png
# Saved DSI image T0393.jpg to /kaggle/working/larger_val_dsi_images/T0393.jpg.png
# Saved DSI image T0080.jpg to /kaggle/working/larger_val_dsi_images/T0080.jpg.png
# Saved DSI image T0248.jpg to /kaggle/working/larger_val_dsi_images/T0248.jpg.png
# Saved DSI image T0158.jpg to /kaggle/working/larger_val_dsi_images/T0158.jpg.png
# Saved DSI image T0035.jpg to /kaggle/working/larger_val_dsi_images/T0035.jpg.png
# Saved DSI image T0350.jpg to /kaggle/working/larger_val_dsi_images/T0350.jpg.png
# Saved DSI image T0391.jpg to /kaggle/working/larger_val_dsi_images/T0391.jpg.png
# Saved DSI image T0331.jpg to /kaggle/working/larger_val_dsi_images/T0331.jpg.png
# Saved DSI image T0138.jpg to /kaggle/working/larger_val_dsi_images/T0138.jpg.png
# Saved DSI image T0011.jpg to /kaggle/working/larger_val_dsi_images/T0011.jpg.png
# Saved DSI image T0053.jpg to /kaggle/working/larger_val_dsi_images/T0053.jpg.png
# Saved DSI image T0275.jpg to /kaggle/working/larger_val_dsi_images/T0275.jpg.png
# Saved DSI image T0108.jpg to /kaggle/working/larger_val_dsi_images/T0108.jpg.png
# Saved DSI image T0055.jpg to /kaggle/working/larger_val_dsi_images/T0055.jpg.png
# Saved DSI image T0031.jpg to /kaggle/working/larger_val_dsi_images/T0031.jpg.png
# Saved DSI image T0142.jpg to /kaggle/working/larger_val_dsi_images/T0142.jpg.png
# Saved DSI image T0378.jpg to /kaggle/working/larger_val_dsi_images/T0378.jpg.png
# Saved DSI image T0375.jpg to /kaggle/working/larger_val_dsi_images/T0375.jpg.png
# Saved DSI image T0353.jpg to /kaggle/working/larger_val_dsi_images/T0353.jpg.png
# Saved DSI image T0298.jpg to /kaggle/working/larger_val_dsi_images/T0298.jpg.png
# Saved DSI image T0299.jpg to /kaggle/working/larger_val_dsi_images/T0299.jpg.png
# Saved DSI image T0288.jpg to /kaggle/working/larger_val_dsi_images/T0288.jpg.png
# Saved DSI image T0344.jpg to /kaggle/working/larger_val_dsi_images/T0344.jpg.png
# Saved DSI image T0300.jpg to /kaggle/working/larger_val_dsi_images/T0300.jpg.png
# Saved DSI image T0268.jpg to /kaggle/working/larger_val_dsi_images/T0268.jpg.png
# Saved DSI image T0285.jpg to /kaggle/working/larger_val_dsi_images/T0285.jpg.png
# Saved DSI image T0187.jpg to /kaggle/working/larger_val_dsi_images/T0187.jpg.png
# Saved DSI image T0260.jpg to /kaggle/working/larger_val_dsi_images/T0260.jpg.png
# Saved DSI image T0394.jpg to /kaggle/working/larger_val_dsi_images/T0394.jpg.png
# Saved DSI image T0273.jpg to /kaggle/working/larger_val_dsi_images/T0273.jpg.png
# Saved DSI image T0347.jpg to /kaggle/working/larger_val_dsi_images/T0347.jpg.png
# Saved DSI image T0214.jpg to /kaggle/working/larger_val_dsi_images/T0214.jpg.png
# Saved DSI image T0004.jpg to /kaggle/working/larger_val_dsi_images/T0004.jpg.png
# Saved DSI image T0064.jpg to /kaggle/working/larger_val_dsi_images/T0064.jpg.png
# Saved DSI image T0204.jpg to /kaggle/working/larger_val_dsi_images/T0204.jpg.png
# Saved DSI image T0015.jpg to /kaggle/working/larger_val_dsi_images/T0015.jpg.png
# Saved DSI image T0050.jpg to /kaggle/working/larger_val_dsi_images/T0050.jpg.png
# Saved DSI image T0182.jpg to /kaggle/working/larger_val_dsi_images/T0182.jpg.png
# Saved DSI image T0397.jpg to /kaggle/working/larger_val_dsi_images/T0397.jpg.png
# Saved DSI image T0012.jpg to /kaggle/working/larger_val_dsi_images/T0012.jpg.png
# Saved DSI image T0198.jpg to /kaggle/working/larger_val_dsi_images/T0198.jpg.png
# Saved DSI image T0230.jpg to /kaggle/working/larger_val_dsi_images/T0230.jpg.png
# Saved DSI image T0395.jpg to /kaggle/working/larger_val_dsi_images/T0395.jpg.png
# Saved DSI image T0041.jpg to /kaggle/working/larger_val_dsi_images/T0041.jpg.png
# Saved DSI image T0249.jpg to /kaggle/working/larger_val_dsi_images/T0249.jpg.png
# Saved DSI image T0250.jpg to /kaggle/working/larger_val_dsi_images/T0250.jpg.png
# Saved DSI image T0261.jpg to /kaggle/working/larger_val_dsi_images/T0261.jpg.png
# Saved DSI image T0245.jpg to /kaggle/working/larger_val_dsi_images/T0245.jpg.png
# Saved DSI image T0221.jpg to /kaggle/working/larger_val_dsi_images/T0221.jpg.png
# Finished generating DSI images for validation data.

# %%
import shutil

def zip_directory(folder_path, zip_path):
    shutil.make_archive(zip_path, 'zip', folder_path)
    print(f"Zipped {folder_path} to {zip_path}.zip")

# Specify the directory paths
train_output_dir = '/kaggle/working/larger_train_dsi_images'
val_output_dir = '/kaggle/working/larger_val_dsi_images'

# Specify the paths where the zip files will be saved
train_zip_path = '/kaggle/working/larger_train_dsi_images'
val_zip_path = '/kaggle/working/larger_val_dsi_images'

# Zip the directories
zip_directory(train_output_dir, train_zip_path)
zip_directory(val_output_dir, val_zip_path)
# Out:
# Zipped /kaggle/working/larger_train_dsi_images to /kaggle/working/larger_train_dsi_images.zip
# Zipped /kaggle/working/larger_val_dsi_images to /kaggle/working/larger_val_dsi_images.zip

# %% [markdown]
# # Test DSI Images

# %%
test_dir = ["../input/glaucoma-datasets/REFUGE/test"]

test_set = GlaucomaDataset(test_dir, 
                        split='val')


test_loader = DataLoader(test_set, 
                        batch_size=batch_size, 
                        shuffle=False, 
                        num_workers=num_workers,
                        pin_memory=True,
                        )
# Out:
# Successfully loaded val dataset.

# %%
test_output_dir = '/kaggle/working/larger_test_dsi_images'
generate_dsi_images(test_loader, loaded_model, test_output_dir)

# Specify the directory paths
test_output_dir = '/kaggle/working/larger_test_dsi_images'

# Specify the paths where the zip files will be saved
test_zip_path = '/kaggle/working/larger_test_dsi_images'

# Zip the directories
zip_directory(test_output_dir, test_zip_path)
# Out:
# Saved DSI image T0247.jpg to /kaggle/working/larger_test_dsi_images/T0247.jpg.png
# Saved DSI image T0320.jpg to /kaggle/working/larger_test_dsi_images/T0320.jpg.png
# Saved DSI image T0291.jpg to /kaggle/working/larger_test_dsi_images/T0291.jpg.png
# Saved DSI image T0264.jpg to /kaggle/working/larger_test_dsi_images/T0264.jpg.png
# Saved DSI image T0192.jpg to /kaggle/working/larger_test_dsi_images/T0192.jpg.png
# Saved DSI image T0205.jpg to /kaggle/working/larger_test_dsi_images/T0205.jpg.png
# Saved DSI image T0190.jpg to /kaggle/working/larger_test_dsi_images/T0190.jpg.png
# Saved DSI image T0349.jpg to /kaggle/working/larger_test_dsi_images/T0349.jpg.png
# Saved DSI image T0143.jpg to /kaggle/working/larger_test_dsi_images/T0143.jpg.png
# Saved DSI image T0392.jpg to /kaggle/working/larger_test_dsi_images/T0392.jpg.png
# Saved DSI image T0003.jpg to /kaggle/working/larger_test_dsi_images/T0003.jpg.png
# Saved DSI image T0069.jpg to /kaggle/working/larger_test_dsi_images/T0069.jpg.png
# Saved DSI image T0052.jpg to /kaggle/working/larger_test_dsi_images/T0052.jpg.png
# Saved DSI image T0246.jpg to /kaggle/working/larger_test_dsi_images/T0246.jpg.png
# Saved DSI image T0159.jpg to /kaggle/working/larger_test_dsi_images/T0159.jpg.png
# Saved DSI image T0101.jpg to /kaggle/working/larger_test_dsi_images/T0101.jpg.png
# Saved DSI image T0195.jpg to /kaggle/working/larger_test_dsi_images/T0195.jpg.png
# Saved DSI image T0113.jpg to /kaggle/working/larger_test_dsi_images/T0113.jpg.png
# Saved DSI image T0212.jpg to /kaggle/working/larger_test_dsi_images/T0212.jpg.png
# Saved DSI image T0154.jpg to /kaggle/working/larger_test_dsi_images/T0154.jpg.png
# Saved DSI image T0081.jpg to /kaggle/working/larger_test_dsi_images/T0081.jpg.png
# Saved DSI image T0008.jpg to /kaggle/working/larger_test_dsi_images/T0008.jpg.png
# Saved DSI image T0126.jpg to /kaggle/working/larger_test_dsi_images/T0126.jpg.png
# Saved DSI image T0153.jpg to /kaggle/working/larger_test_dsi_images/T0153.jpg.png
# Saved DSI image T0074.jpg to /kaggle/working/larger_test_dsi_images/T0074.jpg.png
# Saved DSI image T0065.jpg to /kaggle/working/larger_test_dsi_images/T0065.jpg.png
# Saved DSI image T0272.jpg to /kaggle/working/larger_test_dsi_images/T0272.jpg.png
# Saved DSI image T0278.jpg to /kaggle/working/larger_test_dsi_images/T0278.jpg.png
# Saved DSI image T0180.jpg to /kaggle/working/larger_test_dsi_images/T0180.jpg.png
# Saved DSI image T0266.jpg to /kaggle/working/larger_test_dsi_images/T0266.jpg.png
# Saved DSI image T0045.jpg to /kaggle/working/larger_test_dsi_images/T0045.jpg.png
# Saved DSI image T0130.jpg to /kaggle/working/larger_test_dsi_images/T0130.jpg.png
# Saved DSI image T0271.jpg to /kaggle/working/larger_test_dsi_images/T0271.jpg.png
# Saved DSI image T0341.jpg to /kaggle/working/larger_test_dsi_images/T0341.jpg.png
# Saved DSI image T0323.jpg to /kaggle/working/larger_test_dsi_images/T0323.jpg.png
# Saved DSI image T0294.jpg to /kaggle/working/larger_test_dsi_images/T0294.jpg.png
# Saved DSI image T0325.jpg to /kaggle/working/larger_test_dsi_images/T0325.jpg.png
# Saved DSI image T0352.jpg to /kaggle/working/larger_test_dsi_images/T0352.jpg.png
# Saved DSI image T0364.jpg to /kaggle/working/larger_test_dsi_images/T0364.jpg.png
# Saved DSI image T0145.jpg to /kaggle/working/larger_test_dsi_images/T0145.jpg.png
# Saved DSI image T0170.jpg to /kaggle/working/larger_test_dsi_images/T0170.jpg.png
# Saved DSI image T0309.jpg to /kaggle/working/larger_test_dsi_images/T0309.jpg.png
# Saved DSI image T0377.jpg to /kaggle/working/larger_test_dsi_images/T0377.jpg.png
# Saved DSI image T0135.jpg to /kaggle/working/larger_test_dsi_images/T0135.jpg.png
# Saved DSI image T0381.jpg to /kaggle/working/larger_test_dsi_images/T0381.jpg.png
# Saved DSI image T0079.jpg to /kaggle/working/larger_test_dsi_images/T0079.jpg.png
# Saved DSI image T0164.jpg to /kaggle/working/larger_test_dsi_images/T0164.jpg.png
# Saved DSI image T0067.jpg to /kaggle/working/larger_test_dsi_images/T0067.jpg.png
# Saved DSI image T0342.jpg to /kaggle/working/larger_test_dsi_images/T0342.jpg.png
# Saved DSI image T0370.jpg to /kaggle/working/larger_test_dsi_images/T0370.jpg.png
# Saved DSI image T0203.jpg to /kaggle/working/larger_test_dsi_images/T0203.jpg.png
# Saved DSI image T0293.jpg to /kaggle/working/larger_test_dsi_images/T0293.jpg.png
# Saved DSI image T0124.jpg to /kaggle/working/larger_test_dsi_images/T0124.jpg.png
# Saved DSI image T0302.jpg to /kaggle/working/larger_test_dsi_images/T0302.jpg.png
# Saved DSI image T0185.jpg to /kaggle/working/larger_test_dsi_images/T0185.jpg.png
# Saved DSI image T0235.jpg to /kaggle/working/larger_test_dsi_images/T0235.jpg.png
# Saved DSI image T0334.jpg to /kaggle/working/larger_test_dsi_images/T0334.jpg.png
# Saved DSI image T0075.jpg to /kaggle/working/larger_test_dsi_images/T0075.jpg.png
# Saved DSI image T0107.jpg to /kaggle/working/larger_test_dsi_images/T0107.jpg.png
# Saved DSI image T0374.jpg to /kaggle/working/larger_test_dsi_images/T0374.jpg.png
# Saved DSI image T0148.jpg to /kaggle/working/larger_test_dsi_images/T0148.jpg.png
# Saved DSI image T0284.jpg to /kaggle/working/larger_test_dsi_images/T0284.jpg.png
# Saved DSI image T0019.jpg to /kaggle/working/larger_test_dsi_images/T0019.jpg.png
# Saved DSI image T0324.jpg to /kaggle/working/larger_test_dsi_images/T0324.jpg.png
# Saved DSI image T0310.jpg to /kaggle/working/larger_test_dsi_images/T0310.jpg.png
# Saved DSI image T0196.jpg to /kaggle/working/larger_test_dsi_images/T0196.jpg.png
# Saved DSI image T0036.jpg to /kaggle/working/larger_test_dsi_images/T0036.jpg.png
# Saved DSI image T0373.jpg to /kaggle/working/larger_test_dsi_images/T0373.jpg.png
# Saved DSI image T0131.jpg to /kaggle/working/larger_test_dsi_images/T0131.jpg.png
# Saved DSI image T0256.jpg to /kaggle/working/larger_test_dsi_images/T0256.jpg.png
# Saved DSI image T0039.jpg to /kaggle/working/larger_test_dsi_images/T0039.jpg.png
# Saved DSI image T0028.jpg to /kaggle/working/larger_test_dsi_images/T0028.jpg.png
# Saved DSI image T0183.jpg to /kaggle/working/larger_test_dsi_images/T0183.jpg.png
# Saved DSI image T0172.jpg to /kaggle/working/larger_test_dsi_images/T0172.jpg.png
# Saved DSI image T0376.jpg to /kaggle/working/larger_test_dsi_images/T0376.jpg.png
# Saved DSI image T0149.jpg to /kaggle/working/larger_test_dsi_images/T0149.jpg.png
# Saved DSI image T0104.jpg to /kaggle/working/larger_test_dsi_images/T0104.jpg.png
# Saved DSI image T0207.jpg to /kaggle/working/larger_test_dsi_images/T0207.jpg.png
# Saved DSI image T0116.jpg to /kaggle/working/larger_test_dsi_images/T0116.jpg.png
# Saved DSI image T0303.jpg to /kaggle/working/larger_test_dsi_images/T0303.jpg.png
# Saved DSI image T0313.jpg to /kaggle/working/larger_test_dsi_images/T0313.jpg.png
# Saved DSI image T0382.jpg to /kaggle/working/larger_test_dsi_images/T0382.jpg.png
# Saved DSI image T0061.jpg to /kaggle/working/larger_test_dsi_images/T0061.jpg.png
# Saved DSI image T0289.jpg to /kaggle/working/larger_test_dsi_images/T0289.jpg.png
# Saved DSI image T0100.jpg to /kaggle/working/larger_test_dsi_images/T0100.jpg.png
# Saved DSI image T0222.jpg to /kaggle/working/larger_test_dsi_images/T0222.jpg.png
# Saved DSI image T0169.jpg to /kaggle/working/larger_test_dsi_images/T0169.jpg.png
# Saved DSI image T0307.jpg to /kaggle/working/larger_test_dsi_images/T0307.jpg.png
# Saved DSI image T0044.jpg to /kaggle/working/larger_test_dsi_images/T0044.jpg.png
# Saved DSI image T0174.jpg to /kaggle/working/larger_test_dsi_images/T0174.jpg.png
# Saved DSI image T0241.jpg to /kaggle/working/larger_test_dsi_images/T0241.jpg.png
# Saved DSI image T0369.jpg to /kaggle/working/larger_test_dsi_images/T0369.jpg.png
# Saved DSI image T0193.jpg to /kaggle/working/larger_test_dsi_images/T0193.jpg.png
# Saved DSI image T0096.jpg to /kaggle/working/larger_test_dsi_images/T0096.jpg.png
# Saved DSI image T0103.jpg to /kaggle/working/larger_test_dsi_images/T0103.jpg.png
# Saved DSI image T0084.jpg to /kaggle/working/larger_test_dsi_images/T0084.jpg.png
# Saved DSI image T0167.jpg to /kaggle/working/larger_test_dsi_images/T0167.jpg.png
# Saved DSI image T0398.jpg to /kaggle/working/larger_test_dsi_images/T0398.jpg.png
# Saved DSI image T0177.jpg to /kaggle/working/larger_test_dsi_images/T0177.jpg.png
# Saved DSI image T0066.jpg to /kaggle/working/larger_test_dsi_images/T0066.jpg.png
# Saved DSI image T0141.jpg to /kaggle/working/larger_test_dsi_images/T0141.jpg.png
# Saved DSI image T0354.jpg to /kaggle/working/larger_test_dsi_images/T0354.jpg.png
# Saved DSI image T0165.jpg to /kaggle/working/larger_test_dsi_images/T0165.jpg.png
# Saved DSI image T0258.jpg to /kaggle/working/larger_test_dsi_images/T0258.jpg.png
# Saved DSI image T0186.jpg to /kaggle/working/larger_test_dsi_images/T0186.jpg.png
# Saved DSI image T0191.jpg to /kaggle/working/larger_test_dsi_images/T0191.jpg.png
# Saved DSI image T0117.jpg to /kaggle/working/larger_test_dsi_images/T0117.jpg.png
# Saved DSI image T0125.jpg to /kaggle/working/larger_test_dsi_images/T0125.jpg.png
# Saved DSI image T0242.jpg to /kaggle/working/larger_test_dsi_images/T0242.jpg.png
# Saved DSI image T0070.jpg to /kaggle/working/larger_test_dsi_images/T0070.jpg.png
# Saved DSI image T0007.jpg to /kaggle/working/larger_test_dsi_images/T0007.jpg.png
# Saved DSI image T0076.jpg to /kaggle/working/larger_test_dsi_images/T0076.jpg.png
# Saved DSI image T0115.jpg to /kaggle/working/larger_test_dsi_images/T0115.jpg.png
# Saved DSI image T0150.jpg to /kaggle/working/larger_test_dsi_images/T0150.jpg.png
# Saved DSI image T0021.jpg to /kaggle/working/larger_test_dsi_images/T0021.jpg.png
# Saved DSI image T0226.jpg to /kaggle/working/larger_test_dsi_images/T0226.jpg.png
# Saved DSI image T0237.jpg to /kaggle/working/larger_test_dsi_images/T0237.jpg.png
# Saved DSI image T0189.jpg to /kaggle/working/larger_test_dsi_images/T0189.jpg.png
# Saved DSI image T0087.jpg to /kaggle/working/larger_test_dsi_images/T0087.jpg.png
# Saved DSI image T0308.jpg to /kaggle/working/larger_test_dsi_images/T0308.jpg.png
# Saved DSI image T0380.jpg to /kaggle/working/larger_test_dsi_images/T0380.jpg.png
# Saved DSI image T0306.jpg to /kaggle/working/larger_test_dsi_images/T0306.jpg.png
# Saved DSI image T0022.jpg to /kaggle/working/larger_test_dsi_images/T0022.jpg.png
# Saved DSI image T0365.jpg to /kaggle/working/larger_test_dsi_images/T0365.jpg.png
# Saved DSI image T0151.jpg to /kaggle/working/larger_test_dsi_images/T0151.jpg.png
# Saved DSI image T0088.jpg to /kaggle/working/larger_test_dsi_images/T0088.jpg.png
# Saved DSI image T0209.jpg to /kaggle/working/larger_test_dsi_images/T0209.jpg.png
# Saved DSI image T0014.jpg to /kaggle/working/larger_test_dsi_images/T0014.jpg.png
# Saved DSI image T0330.jpg to /kaggle/working/larger_test_dsi_images/T0330.jpg.png
# Saved DSI image T0136.jpg to /kaggle/working/larger_test_dsi_images/T0136.jpg.png
# Saved DSI image T0355.jpg to /kaggle/working/larger_test_dsi_images/T0355.jpg.png
# Saved DSI image T0168.jpg to /kaggle/working/larger_test_dsi_images/T0168.jpg.png
# Saved DSI image T0362.jpg to /kaggle/working/larger_test_dsi_images/T0362.jpg.png
# Saved DSI image T0132.jpg to /kaggle/working/larger_test_dsi_images/T0132.jpg.png
# Saved DSI image T0240.jpg to /kaggle/working/larger_test_dsi_images/T0240.jpg.png
# Saved DSI image T0156.jpg to /kaggle/working/larger_test_dsi_images/T0156.jpg.png
# Saved DSI image T0181.jpg to /kaggle/working/larger_test_dsi_images/T0181.jpg.png
# Saved DSI image T0058.jpg to /kaggle/working/larger_test_dsi_images/T0058.jpg.png
# Saved DSI image T0166.jpg to /kaggle/working/larger_test_dsi_images/T0166.jpg.png
# Saved DSI image T0251.jpg to /kaggle/working/larger_test_dsi_images/T0251.jpg.png
# Saved DSI image T0360.jpg to /kaggle/working/larger_test_dsi_images/T0360.jpg.png
# Saved DSI image T0316.jpg to /kaggle/working/larger_test_dsi_images/T0316.jpg.png
# Saved DSI image T0175.jpg to /kaggle/working/larger_test_dsi_images/T0175.jpg.png
# Saved DSI image T0361.jpg to /kaggle/working/larger_test_dsi_images/T0361.jpg.png
# Saved DSI image T0043.jpg to /kaggle/working/larger_test_dsi_images/T0043.jpg.png
# Saved DSI image T0223.jpg to /kaggle/working/larger_test_dsi_images/T0223.jpg.png
# Saved DSI image T0332.jpg to /kaggle/working/larger_test_dsi_images/T0332.jpg.png
# Saved DSI image T0194.jpg to /kaggle/working/larger_test_dsi_images/T0194.jpg.png
# Saved DSI image T0042.jpg to /kaggle/working/larger_test_dsi_images/T0042.jpg.png
# Saved DSI image T0173.jpg to /kaggle/working/larger_test_dsi_images/T0173.jpg.png
# Saved DSI image T0105.jpg to /kaggle/working/larger_test_dsi_images/T0105.jpg.png
# Saved DSI image T0086.jpg to /kaggle/working/larger_test_dsi_images/T0086.jpg.png
# Saved DSI image T0213.jpg to /kaggle/working/larger_test_dsi_images/T0213.jpg.png
# Saved DSI image T0037.jpg to /kaggle/working/larger_test_dsi_images/T0037.jpg.png
# Saved DSI image T0217.jpg to /kaggle/working/larger_test_dsi_images/T0217.jpg.png
# Saved DSI image T0047.jpg to /kaggle/working/larger_test_dsi_images/T0047.jpg.png
# Saved DSI image T0327.jpg to /kaggle/working/larger_test_dsi_images/T0327.jpg.png
# Saved DSI image T0025.jpg to /kaggle/working/larger_test_dsi_images/T0025.jpg.png
# Saved DSI image T0121.jpg to /kaggle/working/larger_test_dsi_images/T0121.jpg.png
# Saved DSI image T0400.jpg to /kaggle/working/larger_test_dsi_images/T0400.jpg.png
# Saved DSI image T0220.jpg to /kaggle/working/larger_test_dsi_images/T0220.jpg.png
# Saved DSI image T0296.jpg to /kaggle/working/larger_test_dsi_images/T0296.jpg.png
# Saved DSI image T0218.jpg to /kaggle/working/larger_test_dsi_images/T0218.jpg.png
# Saved DSI image T0301.jpg to /kaggle/working/larger_test_dsi_images/T0301.jpg.png
# Saved DSI image T0233.jpg to /kaggle/working/larger_test_dsi_images/T0233.jpg.png
# Saved DSI image T0227.jpg to /kaggle/working/larger_test_dsi_images/T0227.jpg.png
# Saved DSI image T0171.jpg to /kaggle/working/larger_test_dsi_images/T0171.jpg.png
# Saved DSI image T0071.jpg to /kaggle/working/larger_test_dsi_images/T0071.jpg.png
# Saved DSI image T0267.jpg to /kaggle/working/larger_test_dsi_images/T0267.jpg.png
# Saved DSI image T0232.jpg to /kaggle/working/larger_test_dsi_images/T0232.jpg.png
# Saved DSI image T0026.jpg to /kaggle/working/larger_test_dsi_images/T0026.jpg.png
# Saved DSI image T0238.jpg to /kaggle/working/larger_test_dsi_images/T0238.jpg.png
# Saved DSI image T0056.jpg to /kaggle/working/larger_test_dsi_images/T0056.jpg.png
# Saved DSI image T0387.jpg to /kaggle/working/larger_test_dsi_images/T0387.jpg.png
# Saved DSI image T0068.jpg to /kaggle/working/larger_test_dsi_images/T0068.jpg.png
# Saved DSI image T0383.jpg to /kaggle/working/larger_test_dsi_images/T0383.jpg.png
# Saved DSI image T0333.jpg to /kaggle/working/larger_test_dsi_images/T0333.jpg.png
# Saved DSI image T0283.jpg to /kaggle/working/larger_test_dsi_images/T0283.jpg.png
# Saved DSI image T0219.jpg to /kaggle/working/larger_test_dsi_images/T0219.jpg.png
# Saved DSI image T0255.jpg to /kaggle/working/larger_test_dsi_images/T0255.jpg.png
# Saved DSI image T0090.jpg to /kaggle/working/larger_test_dsi_images/T0090.jpg.png
# Saved DSI image T0016.jpg to /kaggle/working/larger_test_dsi_images/T0016.jpg.png
# Saved DSI image T0179.jpg to /kaggle/working/larger_test_dsi_images/T0179.jpg.png
# Saved DSI image T0215.jpg to /kaggle/working/larger_test_dsi_images/T0215.jpg.png
# Saved DSI image T0030.jpg to /kaggle/working/larger_test_dsi_images/T0030.jpg.png
# Saved DSI image T0263.jpg to /kaggle/working/larger_test_dsi_images/T0263.jpg.png
# Saved DSI image T0297.jpg to /kaggle/working/larger_test_dsi_images/T0297.jpg.png
# Saved DSI image T0057.jpg to /kaggle/working/larger_test_dsi_images/T0057.jpg.png
# Saved DSI image T0162.jpg to /kaggle/working/larger_test_dsi_images/T0162.jpg.png
# Saved DSI image T0095.jpg to /kaggle/working/larger_test_dsi_images/T0095.jpg.png
# Saved DSI image T0363.jpg to /kaggle/working/larger_test_dsi_images/T0363.jpg.png
# Saved DSI image T0013.jpg to /kaggle/working/larger_test_dsi_images/T0013.jpg.png
# Saved DSI image T0340.jpg to /kaggle/working/larger_test_dsi_images/T0340.jpg.png
# Saved DSI image T0399.jpg to /kaggle/working/larger_test_dsi_images/T0399.jpg.png
# Saved DSI image T0390.jpg to /kaggle/working/larger_test_dsi_images/T0390.jpg.png
# Saved DSI image T0002.jpg to /kaggle/working/larger_test_dsi_images/T0002.jpg.png
# Saved DSI image T0357.jpg to /kaggle/working/larger_test_dsi_images/T0357.jpg.png
# Saved DSI image T0379.jpg to /kaggle/working/larger_test_dsi_images/T0379.jpg.png
# Saved DSI image T0033.jpg to /kaggle/working/larger_test_dsi_images/T0033.jpg.png
# Saved DSI image T0098.jpg to /kaggle/working/larger_test_dsi_images/T0098.jpg.png
# Saved DSI image T0048.jpg to /kaggle/working/larger_test_dsi_images/T0048.jpg.png
# Saved DSI image T0157.jpg to /kaggle/working/larger_test_dsi_images/T0157.jpg.png
# Saved DSI image T0119.jpg to /kaggle/working/larger_test_dsi_images/T0119.jpg.png
# Saved DSI image T0257.jpg to /kaggle/working/larger_test_dsi_images/T0257.jpg.png
# Saved DSI image T0178.jpg to /kaggle/working/larger_test_dsi_images/T0178.jpg.png
# Saved DSI image T0046.jpg to /kaggle/working/larger_test_dsi_images/T0046.jpg.png
# Saved DSI image T0202.jpg to /kaggle/working/larger_test_dsi_images/T0202.jpg.png
# Saved DSI image T0083.jpg to /kaggle/working/larger_test_dsi_images/T0083.jpg.png
# Saved DSI image T0112.jpg to /kaggle/working/larger_test_dsi_images/T0112.jpg.png
# Saved DSI image T0274.jpg to /kaggle/working/larger_test_dsi_images/T0274.jpg.png
# Saved DSI image T0017.jpg to /kaggle/working/larger_test_dsi_images/T0017.jpg.png
# Saved DSI image T0358.jpg to /kaggle/working/larger_test_dsi_images/T0358.jpg.png
# Saved DSI image T0254.jpg to /kaggle/working/larger_test_dsi_images/T0254.jpg.png
# Saved DSI image T0073.jpg to /kaggle/working/larger_test_dsi_images/T0073.jpg.png
# Saved DSI image T0133.jpg to /kaggle/working/larger_test_dsi_images/T0133.jpg.png
# Saved DSI image T0006.jpg to /kaggle/working/larger_test_dsi_images/T0006.jpg.png
# Saved DSI image T0034.jpg to /kaggle/working/larger_test_dsi_images/T0034.jpg.png
# Saved DSI image T0348.jpg to /kaggle/working/larger_test_dsi_images/T0348.jpg.png
# Saved DSI image T0229.jpg to /kaggle/working/larger_test_dsi_images/T0229.jpg.png
# Saved DSI image T0337.jpg to /kaggle/working/larger_test_dsi_images/T0337.jpg.png
# Saved DSI image T0128.jpg to /kaggle/working/larger_test_dsi_images/T0128.jpg.png
# Saved DSI image T0335.jpg to /kaggle/working/larger_test_dsi_images/T0335.jpg.png
# Saved DSI image T0328.jpg to /kaggle/working/larger_test_dsi_images/T0328.jpg.png
# Saved DSI image T0010.jpg to /kaggle/working/larger_test_dsi_images/T0010.jpg.png
# Saved DSI image T0161.jpg to /kaggle/working/larger_test_dsi_images/T0161.jpg.png
# Saved DSI image T0305.jpg to /kaggle/working/larger_test_dsi_images/T0305.jpg.png
# Saved DSI image T0160.jpg to /kaggle/working/larger_test_dsi_images/T0160.jpg.png
# Saved DSI image T0155.jpg to /kaggle/working/larger_test_dsi_images/T0155.jpg.png
# Saved DSI image T0129.jpg to /kaggle/working/larger_test_dsi_images/T0129.jpg.png
# Saved DSI image T0089.jpg to /kaggle/working/larger_test_dsi_images/T0089.jpg.png
# Saved DSI image T0346.jpg to /kaggle/working/larger_test_dsi_images/T0346.jpg.png
# Saved DSI image T0228.jpg to /kaggle/working/larger_test_dsi_images/T0228.jpg.png
# Saved DSI image T0146.jpg to /kaggle/working/larger_test_dsi_images/T0146.jpg.png
# Saved DSI image T0018.jpg to /kaggle/working/larger_test_dsi_images/T0018.jpg.png
# Saved DSI image T0339.jpg to /kaggle/working/larger_test_dsi_images/T0339.jpg.png
# Saved DSI image T0366.jpg to /kaggle/working/larger_test_dsi_images/T0366.jpg.png
# Saved DSI image T0386.jpg to /kaggle/working/larger_test_dsi_images/T0386.jpg.png
# Saved DSI image T0315.jpg to /kaggle/working/larger_test_dsi_images/T0315.jpg.png
# Saved DSI image T0110.jpg to /kaggle/working/larger_test_dsi_images/T0110.jpg.png
# Saved DSI image T0111.jpg to /kaggle/working/larger_test_dsi_images/T0111.jpg.png
# Saved DSI image T0091.jpg to /kaggle/working/larger_test_dsi_images/T0091.jpg.png
# Saved DSI image T0188.jpg to /kaggle/working/larger_test_dsi_images/T0188.jpg.png
# Saved DSI image T0252.jpg to /kaggle/working/larger_test_dsi_images/T0252.jpg.png
# Saved DSI image T0311.jpg to /kaggle/working/larger_test_dsi_images/T0311.jpg.png
# Saved DSI image T0304.jpg to /kaggle/working/larger_test_dsi_images/T0304.jpg.png
# Saved DSI image T0109.jpg to /kaggle/working/larger_test_dsi_images/T0109.jpg.png
# Saved DSI image T0077.jpg to /kaggle/working/larger_test_dsi_images/T0077.jpg.png
# Saved DSI image T0259.jpg to /kaggle/working/larger_test_dsi_images/T0259.jpg.png
# Saved DSI image T0106.jpg to /kaggle/working/larger_test_dsi_images/T0106.jpg.png
# Saved DSI image T0199.jpg to /kaggle/working/larger_test_dsi_images/T0199.jpg.png
# Saved DSI image T0023.jpg to /kaggle/working/larger_test_dsi_images/T0023.jpg.png
# Saved DSI image T0038.jpg to /kaggle/working/larger_test_dsi_images/T0038.jpg.png
# Saved DSI image T0295.jpg to /kaggle/working/larger_test_dsi_images/T0295.jpg.png
# Saved DSI image T0005.jpg to /kaggle/working/larger_test_dsi_images/T0005.jpg.png
# Saved DSI image T0244.jpg to /kaggle/working/larger_test_dsi_images/T0244.jpg.png
# Saved DSI image T0322.jpg to /kaggle/working/larger_test_dsi_images/T0322.jpg.png
# Saved DSI image T0287.jpg to /kaggle/working/larger_test_dsi_images/T0287.jpg.png
# Saved DSI image T0282.jpg to /kaggle/working/larger_test_dsi_images/T0282.jpg.png
# Saved DSI image T0082.jpg to /kaggle/working/larger_test_dsi_images/T0082.jpg.png
# Saved DSI image T0140.jpg to /kaggle/working/larger_test_dsi_images/T0140.jpg.png
# Saved DSI image T0265.jpg to /kaggle/working/larger_test_dsi_images/T0265.jpg.png
# Saved DSI image T0243.jpg to /kaggle/working/larger_test_dsi_images/T0243.jpg.png
# Saved DSI image T0134.jpg to /kaggle/working/larger_test_dsi_images/T0134.jpg.png
# Saved DSI image T0318.jpg to /kaggle/working/larger_test_dsi_images/T0318.jpg.png
# Saved DSI image T0372.jpg to /kaggle/working/larger_test_dsi_images/T0372.jpg.png
# Saved DSI image T0078.jpg to /kaggle/working/larger_test_dsi_images/T0078.jpg.png
# Saved DSI image T0144.jpg to /kaggle/working/larger_test_dsi_images/T0144.jpg.png
# Saved DSI image T0321.jpg to /kaggle/working/larger_test_dsi_images/T0321.jpg.png
# Saved DSI image T0054.jpg to /kaggle/working/larger_test_dsi_images/T0054.jpg.png
# Saved DSI image T0317.jpg to /kaggle/working/larger_test_dsi_images/T0317.jpg.png
# Saved DSI image T0336.jpg to /kaggle/working/larger_test_dsi_images/T0336.jpg.png
# Saved DSI image T0032.jpg to /kaggle/working/larger_test_dsi_images/T0032.jpg.png
# Saved DSI image T0234.jpg to /kaggle/working/larger_test_dsi_images/T0234.jpg.png
# Saved DSI image T0277.jpg to /kaggle/working/larger_test_dsi_images/T0277.jpg.png
# Saved DSI image T0281.jpg to /kaggle/working/larger_test_dsi_images/T0281.jpg.png
# Saved DSI image T0060.jpg to /kaggle/working/larger_test_dsi_images/T0060.jpg.png
# Saved DSI image T0388.jpg to /kaggle/working/larger_test_dsi_images/T0388.jpg.png
# Saved DSI image T0001.jpg to /kaggle/working/larger_test_dsi_images/T0001.jpg.png
# Saved DSI image T0062.jpg to /kaggle/working/larger_test_dsi_images/T0062.jpg.png
# Saved DSI image T0127.jpg to /kaggle/working/larger_test_dsi_images/T0127.jpg.png
# Saved DSI image T0137.jpg to /kaggle/working/larger_test_dsi_images/T0137.jpg.png
# Saved DSI image T0093.jpg to /kaggle/working/larger_test_dsi_images/T0093.jpg.png
# Saved DSI image T0231.jpg to /kaggle/working/larger_test_dsi_images/T0231.jpg.png
# Saved DSI image T0343.jpg to /kaggle/working/larger_test_dsi_images/T0343.jpg.png
# Saved DSI image T0176.jpg to /kaggle/working/larger_test_dsi_images/T0176.jpg.png
# Saved DSI image T0216.jpg to /kaggle/working/larger_test_dsi_images/T0216.jpg.png
# Saved DSI image T0225.jpg to /kaggle/working/larger_test_dsi_images/T0225.jpg.png
# Saved DSI image T0269.jpg to /kaggle/working/larger_test_dsi_images/T0269.jpg.png
# Saved DSI image T0236.jpg to /kaggle/working/larger_test_dsi_images/T0236.jpg.png
# Saved DSI image T0396.jpg to /kaggle/working/larger_test_dsi_images/T0396.jpg.png
# Saved DSI image T0356.jpg to /kaggle/working/larger_test_dsi_images/T0356.jpg.png
# Saved DSI image T0097.jpg to /kaggle/working/larger_test_dsi_images/T0097.jpg.png
# Saved DSI image T0279.jpg to /kaggle/working/larger_test_dsi_images/T0279.jpg.png
# Saved DSI image T0338.jpg to /kaggle/working/larger_test_dsi_images/T0338.jpg.png
# Saved DSI image T0059.jpg to /kaggle/working/larger_test_dsi_images/T0059.jpg.png
# Saved DSI image T0319.jpg to /kaggle/working/larger_test_dsi_images/T0319.jpg.png
# Saved DSI image T0051.jpg to /kaggle/working/larger_test_dsi_images/T0051.jpg.png
# Saved DSI image T0072.jpg to /kaggle/working/larger_test_dsi_images/T0072.jpg.png
# Saved DSI image T0120.jpg to /kaggle/working/larger_test_dsi_images/T0120.jpg.png
# Saved DSI image T0329.jpg to /kaggle/working/larger_test_dsi_images/T0329.jpg.png
# Saved DSI image T0253.jpg to /kaggle/working/larger_test_dsi_images/T0253.jpg.png
# Saved DSI image T0118.jpg to /kaggle/working/larger_test_dsi_images/T0118.jpg.png
# Saved DSI image T0163.jpg to /kaggle/working/larger_test_dsi_images/T0163.jpg.png
# Saved DSI image T0224.jpg to /kaggle/working/larger_test_dsi_images/T0224.jpg.png
# Saved DSI image T0326.jpg to /kaggle/working/larger_test_dsi_images/T0326.jpg.png
# Saved DSI image T0027.jpg to /kaggle/working/larger_test_dsi_images/T0027.jpg.png
# Saved DSI image T0122.jpg to /kaggle/working/larger_test_dsi_images/T0122.jpg.png
# Saved DSI image T0211.jpg to /kaggle/working/larger_test_dsi_images/T0211.jpg.png
# Saved DSI image T0292.jpg to /kaggle/working/larger_test_dsi_images/T0292.jpg.png
# Saved DSI image T0184.jpg to /kaggle/working/larger_test_dsi_images/T0184.jpg.png
# Saved DSI image T0314.jpg to /kaggle/working/larger_test_dsi_images/T0314.jpg.png
# Saved DSI image T0359.jpg to /kaggle/working/larger_test_dsi_images/T0359.jpg.png
# Saved DSI image T0094.jpg to /kaggle/working/larger_test_dsi_images/T0094.jpg.png
# Saved DSI image T0384.jpg to /kaggle/working/larger_test_dsi_images/T0384.jpg.png
# Saved DSI image T0389.jpg to /kaggle/working/larger_test_dsi_images/T0389.jpg.png
# Saved DSI image T0276.jpg to /kaggle/working/larger_test_dsi_images/T0276.jpg.png
# Saved DSI image T0201.jpg to /kaggle/working/larger_test_dsi_images/T0201.jpg.png
# Saved DSI image T0139.jpg to /kaggle/working/larger_test_dsi_images/T0139.jpg.png
# Saved DSI image T0312.jpg to /kaggle/working/larger_test_dsi_images/T0312.jpg.png
# Saved DSI image T0286.jpg to /kaggle/working/larger_test_dsi_images/T0286.jpg.png
# Saved DSI image T0262.jpg to /kaggle/working/larger_test_dsi_images/T0262.jpg.png
# Saved DSI image T0239.jpg to /kaggle/working/larger_test_dsi_images/T0239.jpg.png
# Saved DSI image T0200.jpg to /kaggle/working/larger_test_dsi_images/T0200.jpg.png
# Saved DSI image T0020.jpg to /kaggle/working/larger_test_dsi_images/T0020.jpg.png
# Saved DSI image T0206.jpg to /kaggle/working/larger_test_dsi_images/T0206.jpg.png
# Saved DSI image T0351.jpg to /kaggle/working/larger_test_dsi_images/T0351.jpg.png
# Saved DSI image T0208.jpg to /kaggle/working/larger_test_dsi_images/T0208.jpg.png
# Saved DSI image T0099.jpg to /kaggle/working/larger_test_dsi_images/T0099.jpg.png
# Saved DSI image T0102.jpg to /kaggle/working/larger_test_dsi_images/T0102.jpg.png
# Saved DSI image T0152.jpg to /kaggle/working/larger_test_dsi_images/T0152.jpg.png
# Saved DSI image T0147.jpg to /kaggle/working/larger_test_dsi_images/T0147.jpg.png
# Saved DSI image T0290.jpg to /kaggle/working/larger_test_dsi_images/T0290.jpg.png
# Saved DSI image T0280.jpg to /kaggle/working/larger_test_dsi_images/T0280.jpg.png
# Saved DSI image T0210.jpg to /kaggle/working/larger_test_dsi_images/T0210.jpg.png
# Saved DSI image T0024.jpg to /kaggle/working/larger_test_dsi_images/T0024.jpg.png
# Saved DSI image T0197.jpg to /kaggle/working/larger_test_dsi_images/T0197.jpg.png
# Saved DSI image T0085.jpg to /kaggle/working/larger_test_dsi_images/T0085.jpg.png
# Saved DSI image T0049.jpg to /kaggle/working/larger_test_dsi_images/T0049.jpg.png
# Saved DSI image T0040.jpg to /kaggle/working/larger_test_dsi_images/T0040.jpg.png
# Saved DSI image T0123.jpg to /kaggle/working/larger_test_dsi_images/T0123.jpg.png
# Saved DSI image T0270.jpg to /kaggle/working/larger_test_dsi_images/T0270.jpg.png
# Saved DSI image T0371.jpg to /kaggle/working/larger_test_dsi_images/T0371.jpg.png
# Saved DSI image T0368.jpg to /kaggle/working/larger_test_dsi_images/T0368.jpg.png
# Saved DSI image T0114.jpg to /kaggle/working/larger_test_dsi_images/T0114.jpg.png
# Saved DSI image T0367.jpg to /kaggle/working/larger_test_dsi_images/T0367.jpg.png
# Saved DSI image T0009.jpg to /kaggle/working/larger_test_dsi_images/T0009.jpg.png
# Saved DSI image T0345.jpg to /kaggle/working/larger_test_dsi_images/T0345.jpg.png
# Saved DSI image T0029.jpg to /kaggle/working/larger_test_dsi_images/T0029.jpg.png
# Saved DSI image T0063.jpg to /kaggle/working/larger_test_dsi_images/T0063.jpg.png
# Saved DSI image T0092.jpg to /kaggle/working/larger_test_dsi_images/T0092.jpg.png
# Saved DSI image T0385.jpg to /kaggle/working/larger_test_dsi_images/T0385.jpg.png
# Saved DSI image T0393.jpg to /kaggle/working/larger_test_dsi_images/T0393.jpg.png
# Saved DSI image T0080.jpg to /kaggle/working/larger_test_dsi_images/T0080.jpg.png
# Saved DSI image T0248.jpg to /kaggle/working/larger_test_dsi_images/T0248.jpg.png
# Saved DSI image T0158.jpg to /kaggle/working/larger_test_dsi_images/T0158.jpg.png
# Saved DSI image T0035.jpg to /kaggle/working/larger_test_dsi_images/T0035.jpg.png
# Saved DSI image T0350.jpg to /kaggle/working/larger_test_dsi_images/T0350.jpg.png
# Saved DSI image T0391.jpg to /kaggle/working/larger_test_dsi_images/T0391.jpg.png
# Saved DSI image T0331.jpg to /kaggle/working/larger_test_dsi_images/T0331.jpg.png
# Saved DSI image T0138.jpg to /kaggle/working/larger_test_dsi_images/T0138.jpg.png
# Saved DSI image T0011.jpg to /kaggle/working/larger_test_dsi_images/T0011.jpg.png
# Saved DSI image T0053.jpg to /kaggle/working/larger_test_dsi_images/T0053.jpg.png
# Saved DSI image T0275.jpg to /kaggle/working/larger_test_dsi_images/T0275.jpg.png
# Saved DSI image T0108.jpg to /kaggle/working/larger_test_dsi_images/T0108.jpg.png
# Saved DSI image T0055.jpg to /kaggle/working/larger_test_dsi_images/T0055.jpg.png
# Saved DSI image T0031.jpg to /kaggle/working/larger_test_dsi_images/T0031.jpg.png
# Saved DSI image T0142.jpg to /kaggle/working/larger_test_dsi_images/T0142.jpg.png
# Saved DSI image T0378.jpg to /kaggle/working/larger_test_dsi_images/T0378.jpg.png
# Saved DSI image T0375.jpg to /kaggle/working/larger_test_dsi_images/T0375.jpg.png
# Saved DSI image T0353.jpg to /kaggle/working/larger_test_dsi_images/T0353.jpg.png
# Saved DSI image T0298.jpg to /kaggle/working/larger_test_dsi_images/T0298.jpg.png
# Saved DSI image T0299.jpg to /kaggle/working/larger_test_dsi_images/T0299.jpg.png
# Saved DSI image T0288.jpg to /kaggle/working/larger_test_dsi_images/T0288.jpg.png
# Saved DSI image T0344.jpg to /kaggle/working/larger_test_dsi_images/T0344.jpg.png
# Saved DSI image T0300.jpg to /kaggle/working/larger_test_dsi_images/T0300.jpg.png
# Saved DSI image T0268.jpg to /kaggle/working/larger_test_dsi_images/T0268.jpg.png
# Saved DSI image T0285.jpg to /kaggle/working/larger_test_dsi_images/T0285.jpg.png
# Saved DSI image T0187.jpg to /kaggle/working/larger_test_dsi_images/T0187.jpg.png
# Saved DSI image T0260.jpg to /kaggle/working/larger_test_dsi_images/T0260.jpg.png
# Saved DSI image T0394.jpg to /kaggle/working/larger_test_dsi_images/T0394.jpg.png
# Saved DSI image T0273.jpg to /kaggle/working/larger_test_dsi_images/T0273.jpg.png
# Saved DSI image T0347.jpg to /kaggle/working/larger_test_dsi_images/T0347.jpg.png
# Saved DSI image T0214.jpg to /kaggle/working/larger_test_dsi_images/T0214.jpg.png
# Saved DSI image T0004.jpg to /kaggle/working/larger_test_dsi_images/T0004.jpg.png
# Saved DSI image T0064.jpg to /kaggle/working/larger_test_dsi_images/T0064.jpg.png
# Saved DSI image T0204.jpg to /kaggle/working/larger_test_dsi_images/T0204.jpg.png
# Saved DSI image T0015.jpg to /kaggle/working/larger_test_dsi_images/T0015.jpg.png
# Saved DSI image T0050.jpg to /kaggle/working/larger_test_dsi_images/T0050.jpg.png
# Saved DSI image T0182.jpg to /kaggle/working/larger_test_dsi_images/T0182.jpg.png
# Saved DSI image T0397.jpg to /kaggle/working/larger_test_dsi_images/T0397.jpg.png
# Saved DSI image T0012.jpg to /kaggle/working/larger_test_dsi_images/T0012.jpg.png
# Saved DSI image T0198.jpg to /kaggle/working/larger_test_dsi_images/T0198.jpg.png
# Saved DSI image T0230.jpg to /kaggle/working/larger_test_dsi_images/T0230.jpg.png
# Saved DSI image T0395.jpg to /kaggle/working/larger_test_dsi_images/T0395.jpg.png
# Saved DSI image T0041.jpg to /kaggle/working/larger_test_dsi_images/T0041.jpg.png
# Saved DSI image T0249.jpg to /kaggle/working/larger_test_dsi_images/T0249.jpg.png
# Saved DSI image T0250.jpg to /kaggle/working/larger_test_dsi_images/T0250.jpg.png
# Saved DSI image T0261.jpg to /kaggle/working/larger_test_dsi_images/T0261.jpg.png
# Saved DSI image T0245.jpg to /kaggle/working/larger_test_dsi_images/T0245.jpg.png
# Saved DSI image T0221.jpg to /kaggle/working/larger_test_dsi_images/T0221.jpg.png
# Zipped /kaggle/working/larger_test_dsi_images to /kaggle/working/larger_test_dsi_images.zip

# %%
# %cd /kaggle/working
from IPython.display import FileLink
FileLink(r'OD_OC_Coarse_Model.pth')
# Out:
# /kaggle/working
# /kaggle/working/OD_OC_Coarse_Model.pth
